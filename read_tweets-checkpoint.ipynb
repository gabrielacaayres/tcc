# %% [markdown]
# Importando as bibliotecas

# %%
import numpy as np
import pandas as pd
from textblob import TextBlob
import tweepy
from os import path
from textblob import TextBlob as tb
from wordcloud import WordCloud,STOPWORDS
stopwords = set(STOPWORDS)
import matplotlib.pyplot as plt
import sys
from importlib import reload
import imp
from textblob.classifiers import NaiveBayesClassifier
import os
import re
import nltk
from nltk import word_tokenize, pos_tag, ne_chunk
from nltk import RegexpParser
from nltk import Tree

# %% [markdown]
# Autenticação no Twitter

# %%
consumer_key = 'Jg95VukOglg6RIqRrqt6GYRoa'
consumer_secret = 'ZvH3Oz7jFN0OvDMXGtRriTqOOykGnUgqxAU0wNKWhMElII0ivq'
access_token = '971179238396227584-KkOSGzCwhzv0lokz55Dkp1wTjyurnkW'
access_token_secret = 'y2NNUWU1tlhQYMOps49aSKgckRqTu7T7dPWpyNbMeXvAA'

# %% [markdown]
# Login na API do Twitter

# %%
def get_all_tweets(screen_name):
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth)
    alltweets = []
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)
    alltweets.extend(new_tweets)
    oldest = alltweets[-1].id - 1
    while len(new_tweets) > 0:
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
        alltweets.extend(new_tweets)
        oldest = alltweets[-1].id - 1
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
    return outtweets

# %% [markdown]
# Recupera todos os tweets

# %%
tweets = get_all_tweets("@falanext")
df = pd.DataFrame(tweets, columns=['id','created_at','text'])
df
# Out:
#                        id          created_at  \
# 0     1056622562191568897 2018-10-28 19:03:44
# 1     1056612182912389122 2018-10-28 18:22:29
# 2     1056607277489250305 2018-10-28 18:03:00
# 3     1056565375406665728 2018-10-28 15:16:30
# 4     1056561844293459968 2018-10-28 15:02:28
# 5     1056542853520941057 2018-10-28 13:47:00
# 6     1056537065603690496 2018-10-28 13:24:00
# 7     1056529370406440961 2018-10-28 12:53:25
# 8     1056514649917657089 2018-10-28 11:54:56
# 9     1056451479811358721 2018-10-28 07:43:55
# 10    1056445209511366656 2018-10-28 07:19:00
# 11    1056431087122112514 2018-10-28 06:22:53
# 12    1056426587539746816 2018-10-28 06:05:00
# 13    1056389341491142656 2018-10-28 03:37:00
# 14    1056379526438096896 2018-10-28 02:58:00
# 15    1056347064475549696 2018-10-28 00:49:00
# 16    1056331963005583360 2018-10-27 23:49:00
# 17    1056313950386749440 2018-10-27 22:37:25
# 18    1056309029134315525 2018-10-27 22:17:52
# 19    1056294691908542464 2018-10-27 21:20:54
# 20    1056289937061019650 2018-10-27 21:02:00
# 21    1056255567184977922 2018-10-27 18:45:26
# 22    1056251639340957696 2018-10-27 18:29:49
# 23    1056249168056991746 2018-10-27 18:20:00
# 24    1056245768762351616 2018-10-27 18:06:30
# 25    1056243332727357441 2018-10-27 17:56:49
# 26    1056239101920399360 2018-10-27 17:40:00
# 27    1056235780937519104 2018-10-27 17:26:48
# 28    1056213797030055937 2018-10-27 15:59:27
# 29    1056211922457186304 2018-10-27 15:52:00
# ...                   ...                 ...
# 3193  1030251613338972160 2018-08-17 00:35:00
# 3194  1030244819908608005 2018-08-17 00:08:00
# 3195  1030243861803806721 2018-08-17 00:04:12
# 3196  1030243035567869954 2018-08-17 00:00:55
# 25    b'@xxgicoxx Eita! Conseguiu resolver a quest\x...
# 26    b'@imhelyan Oi, miu! Tudo bem? A mensagem que ...
# 27    b'@maugusstto Oi, Marcelo! Estamos trabalhando...
# 28    b'@maryfreitass_ Ol\xc3\xa1! Respondi sua DM c...
# 29    b'@lagesrenato Oi, Renato! Tudo bem? Preciso d...
# ...                                                 ...
# 3193  b'@_brunsbr Oi, Bruno! A Dalila te passou algu...
# 3194     b'@floydrumond Ol\xc3\xa1!\nRespondi pela DM.'
# 3195  b'@Vinibel_ Oi!\nEstamos trabalhando para que ...
# 3196  b'@Axcotih Ol\xc3\xa1!\nConseguiu o atendimento?'
# 3197  b'@rodrigoribass Aproveita muito com seu cart\...
# 3198  b'@Mallkavian Oi! Tenta fazer novamente o proc...
# 3199  b'@tecahanson Oi! O mimo da Uber est\xc3\xa1 d...
# 3200                 b'@WGBrasilx Oi! Respondi sua DM!'
# 3201  b'@Claudinho_Netoo Oi! Seja bem-vindo! \xf0\x9...
# 3202  b'@ihduardo Oi! Exclui o app e reinstala, ai m...
# 3203  b'@vinimazzinghy N\xc3\xa3o, Vinicius! Somente...
# 3204  b'@weltonok O valor de R$15,10 est\xc3\xa1 cor...
# 3205  b'@atilarobs Oi, Robson! Estamos trabalhando e...
# 3206  b'@jrdmj2008 \xc3\x89 uma "mensagem direta" \x...
# 3207  b'@raphaelbolinho Oi, Raphael! Pode ser que na...
# 3208                b'@lockhartya Oi! Respondi sua DM!'
# 3209  b'@_flipmiranda Vc pode me chamar por DM? Prec...
# 3210  b'@sxvxn027 Oi!\nVem conhecer a gente \xf0\x9f...
# 3211  b'@JoaoVagner Obrigado pelo teste. Envia uma D...
# 3212  b'@AMonsueto depende do plano que vc escolher,...
# 3213  b'@maelsantoz Oi! Precisamos de alguns dados p...
# 3214  b'@joao_alexandre_ Certo! Qualquer coisa, esta...
# 3215  b'@dthiago_t me chama via DM pfv, vamos verifi...
# 3216  b'@castroevinte Eu vou abrir uma ocorr\xc3\xaa...
# 3217  b'@vinimazzinghy Entendo! Caso queira consulta...
# 3218  b'@jrdmj2008 Vc pode me chamar via DM? Preciso...
# 3219  b'@we1ss_ Vc pode me chamar via DM? Preciso de...
# 3220  b'@Brenndinhave Oi, Breninha! vc tentou fazer ...
# 3221  b'@WebersonRocha Oi, Weberson! A DM que deixou...
# 3222  b'@izabellacn Oi! Vc precisa de qual informa\x...
#
# [3223 rows x 3 columns]

# %%
import HTMLParser
html_parser = HTMLParser.HTMLParser()
tweet = html_parser.unescape(text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-316-e1daa3015dae> in <module>()
# ----> 1 import HTMLParser
#       2 html_parser = HTMLParser.HTMLParser()
#       3 tweet = html_parser.unescape(text)
#
# ModuleNotFoundError: No module named 'HTMLParser'

# %% [markdown]
# Função para limpeza dos dados

# %%
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
combined_pat = r'|'.join((pat1, pat2))
def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()
testing = df.text[:100]
test_result = []
for t in testing:
    test_result.append(tweet_cleaner(t))
test_result
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-304-7185483af336> in <module>()
#      18     words = tok.tokenize(lower_case)
#      19     return (" ".join(words)).strip()
# ---> 20 testing = df.text[:100]
#      21 test_result = []
#      22 for t in testing:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'text'

# %% [markdown]
# Read the whole text

# %%
text = open( 'tweets_noun_phrases.txt').read()
stopwords = set(STOPWORDS)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-151-63300a2782ee> in <module>()
# ----> 1 text = open( 'tweets_noun_phrases.txt').read()
#       2 stopwords = set(STOPWORDS)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tweets_noun_phrases.txt'

# %% [markdown]
# Mostrar a nuvem de palavras

# %%
wordcloud = WordCloud(max_font_size=40,stopwords=STOPWORDS,background_color='white').generate(text)
wordcloud.to_file("nouns_user.png")
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# Variável que irá armazenar todos os Tweets com a palavra escolhida na função search da API

# %%
public_tweets = api.search('@falanext')

# %% [markdown]
# Léxico ReLi - análise de sentimentos em português

# %%
base_path = 'ReLi-Lex'
train = []
files = [os.path.join(base_path, f) for f in os.listdir(base_path)]

# %% [markdown]
# Ler o léxico ReLi na pasta de arquivos

# %%
for file in files:
    t = 'pos' if '_Positivos' in file else 'neg'
    with open(file, 'r') as content_file:
        content = content_file.read()
        all = re.findall('\[.*?\]',content)
        for w in all:
            train.append((w[1:-1], t))

cl = NaiveBayesClassifier(train)

# %% [markdown]
# Imprimir a classificação dos tweets se positivo ou negativo e, em seguida, os tweets

# %%
dados = {}
for tweet in public_tweets:
    blob = tb(tweet.text, classifier=cl)
    for s in blob.sentences:
        print("[%s] %s" % (s.classify(), s))
# Out:
# [pos] @falanext Bob
# [pos] @falanext Olha https://t.co/cY2kqOwH6u
# [pos] @falanext Vai demorar muito para que meu crédito seja disponibilizado?
# [pos] Não trate como @nubank  quem te trata como @falanext ... simples assim https://t.co/Pkkz5YCkRD
# [pos] @falanext @falanext o plano do meu cartão é "na faixa" esse plano impede que eu tenha crédito no cartão?
# [pos] @falanext Mandei no inbox.
# [pos] @falanext Vou tentar fazer isso agora
# [pos] @falanext Faz meses que não consigo fazer nada, a função crédito está bloqueada e ninguém resolve só ficam me enrolando
# [pos] @falanext https://t.co/ycZHrq2Dxn
# [neg] @falanext Não consigo porque aparece o erro 404
# [neg] @falanext sério, o atendimento desse banco é uma bosta, você quer resolver alguma coisa mas só fica falando com aqu… https://t.co/zVDwM6CSZR
# [pos] @falanext Não consigo desbloquear ele :(
# [pos] RT @falanext: next tem conta + cartão de crédito grátis e desconto em Uber, iFood, Cinemark e outras marcas.
# [pos] Baixe o app e vem!
# [pos] https://t.…
# [pos] Galera que tem conta no @falanext, é um bom banco?
# [pos] @falanext vou pensar com carinho hahah

# %% [markdown]
# Print das informações em formato de dataframe

# %% [markdown]
# Consolidação ou contagem de positivos e negativos

# %% [markdown]
# Gráfico da análise de sentimentos, baseado na classificação de Naive-Bayes
