# %% [markdown]
# *Import library's*

# %%
import numpy as np
import pandas as pd
from textblob import TextBlob as tb
import tweepy
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from textblob.classifiers import NaiveBayesClassifier
import os, re, nltk, string
from bs4 import BeautifulSoup
from collections import OrderedDict
from operator import itemgetter

# %%
from nltk.utils import ngrams

def sortFreqDict(freqdict):
    aux = [(freqdict[key], key) for key in freqdict]
    aux.sort()
    aux.reverse()
    return aux
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-2ba370f5c298> in <module>()
# ----> 1 from nltk.utils import ngrams
#       2
#       3 def sortFreqDict(freqdict):
#       4     aux = [(freqdict[key], key) for key in freqdict]
#       5     aux.sort()
#
# ModuleNotFoundError: No module named 'nltk.utils'

# %%
tweets = pd.read_csv('nubank_tweets.csv')
text = " ".join(tweet for tweet in data['text'])

wordlist = text.split()
ngramsSeparated = ngrams(wordlist,1)

ngram_stat = {}

for ngram in ngramsSeparated:
    if not ngram_stat.has_key(ngram):
        ngram_stat.update({ngram:1})
    else:
        ngram_occurrences = ngram_stat[ngram]
        ngram_stat.update({ngram: ngram_occurrences+1})

ngram_stat_sorted = sortFreqDict(ngram_stat)
for thing in ngram_stat_sorted:
    if thing[0] > 20:
        print (str(thing))

# %% [markdown]
# *Twitter authentication*

# %%
consumer_key = 'Jg95VukOglg6RIqRrqt6GYRoa'
consumer_secret = 'ZvH3Oz7jFN0OvDMXGtRriTqOOykGnUgqxAU0wNKWhMElII0ivq'
access_token = '971179238396227584-KkOSGzCwhzv0lokz55Dkp1wTjyurnkW'
access_token_secret = 'y2NNUWU1tlhQYMOps49aSKgckRqTu7T7dPWpyNbMeXvAA'

# %%
def get_all_tweets(screen_name):
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth)
    alltweets = []
    new_tweets = api.search(screen_name)
    alltweets.extend(new_tweets)
    oldest = alltweets[-1].id - 1
    while len(new_tweets) > 0:
        new_tweets = api.search(screen_name, count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest = alltweets[-1].id - 1
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
    return outtweets

# %% [markdown]
# *Get all tweets*

# %%
public_tweets = get_all_tweets('@falanext')
df = pd.DataFrame(public_tweets, columns=['id','created_at','text'])
df
# Out:
#                       id          created_at  \
# 0    1098207722728607745 2019-02-20 13:08:19
# 1    1098207440133414912 2019-02-20 13:07:12
# 2    1098205408479662080 2019-02-20 12:59:07
# 3    1098204374185230337 2019-02-20 12:55:01
# 4    1098200508421074944 2019-02-20 12:39:39
# 5    1098193678609330178 2019-02-20 12:12:31
# 6    1098193288681713664 2019-02-20 12:10:58
# 7    1098192165606510593 2019-02-20 12:06:30
# 8    1098189678967226370 2019-02-20 11:56:37
# 9    1098179972534099968 2019-02-20 11:18:03
# 10   1098139980382253056 2019-02-20 08:39:08
# 11   1098093626805182464 2019-02-20 05:34:56
# 12   1098086658405269504 2019-02-20 05:07:15
# 13   1098070754963410944 2019-02-20 04:04:03
# 14   1098070162593497088 2019-02-20 04:01:42
# 15   1098066621535531013 2019-02-20 03:47:38
# 16   1098060594094190593 2019-02-20 03:23:41
# 17   1098060220553678848 2019-02-20 03:22:12
# 18   1098059046802857984 2019-02-20 03:17:32
# 19   1098048232247185408 2019-02-20 02:34:33
# 20   1098044425564028928 2019-02-20 02:19:26
# 21   1098040657908809730 2019-02-20 02:04:28
# 22   1098040335891091457 2019-02-20 02:03:11
# 23   1098032628098351104 2019-02-20 01:32:33
# 24   1098027709190602752 2019-02-20 01:13:00
# 25   1098026843968552960 2019-02-20 01:09:34
# 26   1098025674290446337 2019-02-20 01:04:55
# 27   1098024201523478528 2019-02-20 00:59:04
# 28   1098019893771943941 2019-02-20 00:41:57
# 29   1098016795599032320 2019-02-20 00:29:38
# ..                   ...                 ...
# 779  1094960712617730048 2019-02-11 14:05:51
# 780  1094960460007424001 2019-02-11 14:04:51
# 781  1094946667802042371 2019-02-11 13:10:03
# 782  1094946218965377024 2019-02-11 13:08:16
# 783  1094945099379892224 2019-02-11 13:03:49
# 784  1094941429091258373 2019-02-11 12:49:14
# 785  1094941107216097280 2019-02-11 12:47:57
# 786  1094940876848226304 2019-02-11 12:47:02
# 787  1094939716288462848 2019-02-11 12:42:26
# 788  1094939126820950016 2019-02-11 12:40:05
# 789  1094938875485712390 2019-02-11 12:39:05
# 790  1094933299653496833 2019-02-11 12:16:56
# 791  1094923155389497345 2019-02-11 11:36:37
# 792  1094922819073396737 2019-02-11 11:35:17
# 793  1094921833491677193 2019-02-11 11:31:22
# 794  1094913032680030208 2019-02-11 10:56:24
# 795  1094884824861556736 2019-02-11 09:04:18
# 796  1094872903731109888 2019-02-11 08:16:56
# 797  1094791154342789120 2019-02-11 02:52:06
# 798  1094767482659835904 2019-02-11 01:18:02
# 799  1094765746616524801 2019-02-11 01:11:08
# 800  1094756335923585024 2019-02-11 00:33:44
# 801  1094753536762626048 2019-02-11 00:22:37
# 802  1094740800121040897 2019-02-10 23:32:00
# 803  1094725373097590785 2019-02-10 22:30:42
# 804  1094724574896406529 2019-02-10 22:27:32
# 805  1094715917844533249 2019-02-10 21:53:08
# 806  1094707222133780480 2019-02-10 21:18:35
# 807  1094686781558145024 2019-02-10 19:57:21
# 808  1094678607321010177 2019-02-10 19:24:52
#
#                                                   text
# 0    b'Notifica\xc3\xa7\xc3\xa3o do @falanext: A ge...
# 1    b'@falanext j\xc3\xa1 utilizo o Next a quase u...
# 2                           b'@falanext Ok, obrigado!'
# 3               b'@falanext Eu tbm j\xc3\xa1 respondi'
# 4                  b'@falanext mandei mensagem na DM.'
# 5                                 b'@falanext Eduardo'
# 6    b'@falanext No Android n\xc3\xa3o aparece nada...
# 7    b'Com 12 minutos de m\xc3\xbasica a gente j\xc...
# 8                    b'@falanext te juro que desisto!'
# 9    b'@falanext Me ajuda pelo menos com a portabil...
# 10                       b'@falanext Chamei l\xc3\xa1'
# 11   b'RT @falanext: V\xc3\xaa um cachorrinho e j\x...
# 12   b'@falanext amores ainda n\xc3\xa3o recebi meu...
# 13   b'@falanext  t\xc3\xa1 dif\xc3\xadcil https://...
# 14   b'@falanext T\xc3\xa1 de brincadeira n\xc3\xa9...
# 15                          b'@falanext Vou mandar DM'
# 16                             b'@falanext Dia 15/02.'
# 17   b'@falanext Mas nossa, nem terminei o cadastro...
# 18   b'E eu que rec\xc3\xa9m recebi o cart\xc3\xa3o...
# 19   b'O @falanext quer se dif\xc3\xadcil de aprova...
# 20        b'@hw_isabella_ @Bancointer Tem o @falanext'
# 21   b'Oi @falanext estou gostando bastante do apli...
# 22   b'@falanext fiz um dep\xc3\xb3sito ontem em ho...
# 23   b'@falanext Quais vantagens em rela\xc3\xa7\xc...
# 24   b'@falanext eu enviei dia 15/2 preciso abrir a...
# 25   b'finalmente chegou meu cart\xc3\xa3o do @fala...
# 26   b'@falanext Achei que iam fazer algo pra ajuda...
# 27   b'@falanext Continua sem acesso. Mandei detalh...
# 28         b'@GiiiGisele @falanext bom d+ top top top'
# 29   b'E a @leader insisti em dizer que eu tenho ca...
# ..                                                 ...
# 779                b'@falanext Como fa\xc3\xa7o isso?'
# 780  b'@falanext Obrigado!! Falei no inbox... Pedir...
# 781  b'@falanext Demora uma eternidade pra aprovar :('
# 782  b'@falanext Como eu fa\xc3\xa7o o tal cart\xc3...
# 783  b'@falanext espero lindas promo\xc3\xa7\xc3\xb...
# 784  b'@falanext @wellpalatinus Voc\xc3\xaas deviam...
# 785      b'@Raconcal @falanext Come\xc3\xa7a assim...'
# 786          b'@falanext Aham https://t.co/uAjrlLTcMT'
# 787  b'@Raconcal @falanext @LollapaloozaBr E digo e...
# 788  b'@lucaaslb @falanext @LollapaloozaBr Tenho qu...
# 789  b'@Raconcal @falanext @LollapaloozaBr Espere a...
# 790  b'@falanext Eu tenho um cart\xc3\xa3o de voc\x...
# 791  b'@proconspoficial @Eneidafarias4 @falanext Re...
# 792  b'@proconspoficial @Eneidafarias4 @falanext Es...
# 793  b'@wellpalatinus @Eneidafarias4 @falanext Bom ...
# 794  b'@DiegoConcesso @Caixa @Bancointer Obrigado, ...
# 795  b'@falanext Minha fatura venceu ontem e o valo...
# 796  b'@falanext  preciso tirar uma d\xc3\xbavida, ...
# 797  b'@falanext @LollapaloozaBr A \xc3\xbanica per...
# 798  b'@ladieleisha @falanext Paga de diferentona e...
# 799  b'@falanext @LollapaloozaBr Esperando a perfor...
# 800  b'RT @falanext: Artistas (incr\xc3\xadveis!) i...
# 801  b'@falanext Por isso desinstalei. Cara de pau ...
# 802  b'To precisando que a central da @falanext me ...
# 803  b'@falanext Sim mo kkkkk passado que me respon...
# 804                             b'@falanext mandei dm'
# 805  b'@falanext poxa me aceita ent\xc3\xa3o \xf0\x...
# 806  b'@falanext Conta s\xc3\xb3 vai funcionar quan...
# 807  b'@falanext como estornar uma compra no cart\x...
# 808  b'@falanext Cad\xc3\xaa o meu ,minha conta sal...
#
# [809 rows x 3 columns]

# %% [markdown]
# *Data Cleaning*

# %%
def cleanTweets(tweetsDF):
    table = str.maketrans(dict.fromkeys(string.punctuation.replace('@','')))
    # essa regex significa:
    # tudo que conter @ OU http OU terminador de linha seguido de uma palavra OU um espaco OU qualquer outro terminador
    # de linha.
    rePattern1 = '(@|http|\\n)(\w+|\s|\S)'
    formattedTweets = []
    for line in tweetsDF['text']:
        formattedStr = line.decode('utf-8').lower()
        formattedStr = formattedStr.translate(table)
        formattedStr = re.sub(rePattern1, "", formattedStr)  
        formattedTweets.append(formattedStr)
    return formattedTweets

formattedTweets = cleanTweets(df)
data = pd.DataFrame(formattedTweets, columns=['text'])
data
# Out:
#                                                   text
# 0    notificação do  a gente acha que você consegue...
# 1     já utilizo o next a quase um ano e posso dize...
# 2                                          ok obrigado
# 3                                   eu tbm já respondi
# 4                                mandei mensagem na dm
# 5                                              eduardo
# 6      no android não aparece nada relativo a cotação
# 7    com 12 minutos de música a gente já sabe que a...
# 8                                  te juro que desisto
# 9     me ajuda pelo menos com a portabilidade e rec...
# 10                                           chamei lá
# 11   rt  vê um cachorrinho e já quer dar o mundo pr...
# 12    amores ainda não recebi meu cartão está parad...
# 13                                         tá difícil
# 14        tá de brincadeira né sempre faço isso e nada
# 15                                       vou mandar dm
# 16                                            dia 1502
# 17    mas nossa nem terminei o cadastro e já fizera...
# 18   e eu que recém recebi o cartão do  e fui assal...
# 19   o  quer se difícil de aprovar o limite de créd...
# 20                                              tem o
# 21   oi  estou gostando bastante do aplicativo e do...
# 22    fiz um depósito ontem em horário comercial em...
# 23    quais vantagens em relação ao bradesco sou ex...
# 24    eu enviei dia 152 preciso abrir a conta ainda...
# 25   finalmente chegou meu cartão do  sério gente o...
# 26    achei que iam fazer algo pra ajudar a causa a...
# 27    continua sem acesso mandei detalhes na dm me ...
# 28                                   bom d top top top
# 29   e a  insisti em dizer que eu tenho cartão lead...
# ..                                                 ...
# 779                                     como faço isso
# 780   obrigado falei no inbox pediram para enviar n...
# 781                 demora uma eternidade pra aprovar
# 782                          como eu faço o tal cartão
# 783   espero lindas promoções pra quem for carregar...
# 784    vocês deviam sentir vergonha de só ficarem p...
# 785                                       começa assim
# 786                                              aham
# 787     e digo e repito nãofaçanext é dor de cabeça...
# 788        tenho que concordar companheiro nãofaçanext
# 789     espere até precisar deles de forma internac...
# 790   eu tenho um cartão de vocês porém só funciona...
# 791     recomendo fazerem alguma coisa porque meu c...
# 792     estou comunicando para fiz de conhecimento ...
# 793     bom dia para melhor análise caso resida no ...
# 794     obrigado querido tô tentando abrir no  já f...
# 795   minha fatura venceu ontem e o valor não foi d...
# 796                 preciso tirar uma dúvida me ajudem
# 797    a única performance que eu queria era voltar...
# 798    paga de diferentona e inovadora mas não pass...
# 799    esperando a performance de atendimento ao cl...
# 800  rt  artistas incríveis indicados ao grammys vã...
# 801   por isso desinstalei cara de pau do banco que...
# 802           to precisando que a central da  me salve
# 803            sim mo kkkkk passado que me responderam
# 804                                          mandei dm
# 805                             poxa me aceita então 😢
# 806   conta só vai funcionar quando pararem com ess...
# 807   como estornar uma compra no cartão de credito...
# 808      cadê o meu minha conta salário sempre no next
#
# [809 rows x 1 columns]

# %% [markdown]
# *Stopwords in portuguese*

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')
# Inclusão de novas stopwords 
stopwords.append('tô')
stopwords.append('tá')
stopwords.append('pra')
stopwords.append('pro')
stopwords.append('é')
stopwords.append('aí')
stopwords.append('ser')
stopwords.append('pq')
stopwords.append('já')
stopwords.append('nao')
stopwords.append('rt')
stopwords.append('porque')
stopwords.append('vai')
stopwords.append('vou')
stopwords.append('faço')
stopwords.append('dm')
stopwords.append('q')
stopwords.append('faz')
stopwords.append('dá')
stopwords.append('assim')
stopwords.append('agora')
stopwords.append('nada')
stopwords.append('tbm')

# %% [markdown]
# *WordCloud*

# %%
text = " ".join(tweet for tweet in data['text'])
plt.style.use('seaborn')
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user.png")
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Tweets WordCloud - atendimento')
# Out:
# Text(0.5,1,'Tweets WordCloud - atendimento')

# %% [markdown]
# *Basic statistics about the data*

# %%
def word_count(str):
    counts = OrderedDict()
    words = str.split()
    for word in words:
        if word not in stopwords:
            if word in counts:
                counts[word] += 1
            else:
                counts[word] = 1
    return counts

print("There are {} words in the combination of all tweets.".format(len(text)))

counts = sorted(word_count(text).items(), key = itemgetter(1), reverse = True)
display(counts)
# Out:
# There are 54897 words in the combination of all tweets.
# [('cartão', 109),
#  ('conta', 91),
#  ('next', 66),
#  ('banco', 50),
#  ('atendimento', 46),
#  ('chat', 40),
#  ('app', 37),
#  ('dia', 35),
#  ('esperando', 31),
#  ('falar', 30),
#  ('crédito', 28),
#  ('dias', 28),
#  ('fazer', 27),
#  ('ainda', 25),
#  ('ter', 24),
#  ('tentando', 24),
#  ('ajuda', 23),
#  ('bradesco', 22),
#  ('oi', 22),
#  ('consigo', 22),
#  ('aqui', 21),
#  ('quero', 20),
#  ('pior', 20),
#  ('fiz', 19),
#  ('resposta', 19),
#  ('minutos', 18),
#  ('cadastro', 18),
#  ('telefone', 18),
#  ('fatura', 17),
#  ('funciona', 17),
#  ('problema', 17),
#  ('hoje', 17),
#  ('mandei', 16),
#  ('dar', 16),
#  ('limite', 16),
#  ('bom', 16),
#  ('débito', 16),
#  ('queria', 16),
#  ('deus', 16),
#  ('preciso', 15),
#  ('abrir', 15),
#  ('chegou', 15),
#  ('pode', 15),
#  ('valor', 15),
#  ('demora', 15),
#  ('gente', 14),
#  ('quanto', 14),
#  ('via', 14),
#  ('tempo', 14),
#  ('obrigado', 13),
#  ('1', 13),
#  ('contato', 13),
#  ('boa', 13),
#  ('ninguém', 13),
#  ('responder', 13),
#  ('mim', 13),
#  ('celular', 13),
#  ('melhor', 12),
#  ('quer', 12),
#  ('ontem', 12),
#  ('semana', 12),
#  ('cliente', 12),
#  ('nunca', 12),
#  ('bem', 12),
#  ('pagar', 12),
#  ('resolver', 12),
#  ('consegui', 12),
#  ('atendido', 12),
#  ('horas', 12),
#  ('email', 12),
#  ('salário', 11),
#  ('né', 11),
#  ('aplicativo', 11),
#  ('vezes', 11),
#  ('meses', 11),
#  ('tudo', 11),
#  ('toda', 11),
#  ('amor', 11),
#  ('saber', 11),
#  ('ta', 11),
#  ('alguém', 11),
#  ('pedir', 11),
#  ('sempre', 10),
#  ('usar', 10),
#  ('ajudar', 10),
#  ('mês', 10),
#  ('péssimo', 10),
#  ('podem', 10),
#  ('ligação', 10),
#  ('atendente', 10),
#  ('bia', 10),
#  ('desde', 10),
#  ('atendida', 10),
#  ('sim', 10),
#  ('dinheiro', 9),
#  ('quase', 9),
#  ('análise', 9),
#  ('tal', 9),
#  ('cancelar', 9),
#  ('segunda', 9),
#  ('4', 9),
#  ('coisa', 9),
#  ('tarde', 9),
#  ('responde', 9),
#  ('2', 9),
#  ('ver', 9),
#  ('fica', 9),
#  ('obrigada', 9),
#  ('mano', 9),
#  ('demais', 9),
#  ('biometria', 9),
#  ('posso', 8),
#  ('atender', 8),
#  ('qu…', 8),
#  ('💚', 8),
#  ('algo', 8),
#  ('acessar', 8),
#  ('cara', 8),
#  ('hora', 8),
#  ('central', 8),
#  ('então', 8),
#  ('3', 8),
#  ('mimos', 8),
#  ('espero', 8),
#  ('função', 8),
#  ('carteira', 8),
#  ('ja', 7),
#  ('ok', 7),
#  ('mensagem', 7),
#  ('pessoa', 7),
#  ('menos', 7),
#  ('vê', 7),
#  ('entende', 7),
#  ('grátis', 7),
#  ('gastar', 7),
#  ('vez', 7),
#  ('aprovar', 7),
#  ('acesso', 7),
#  ('ai', 7),
#  ('enviar', 7),
#  ('conseguir', 7),
#  ('10', 7),
#  ('kkkkk', 7),
#  ('ficar', 7),
#  ('alô', 7),
#  ('olá', 7),
#  ('tão', 7),
#  ('duas', 7),
#  ('outro', 7),
#  ('vão', 7),
#  ('n', 7),
#  ('pagamento', 7),
#  ('recomendo', 7),
#  ('chegar', 7),
#  ('d…', 7),
#  ('compra', 7),
#  ('entrar', 7),
#  ('alguma', 7),
#  ('amiga', 7),
#  ('sabe', 6),
#  ('lá', 6),
#  ('cachorrinho', 6),
#  ('mundo', 6),
#  ('difícil', 6),
#  ('mandar', 6),
#  ('olha', 6),
#  ('todo', 6),
#  ('problemas', 6),
#  ('top', 6),
#  ('paguei', 6),
#  ('aceita', 6),
#  ('tentei', 6),
#  ('abertura', 6),
#  ('entrei', 6),
#  ('lixo', 6),
#  ('raiva', 6),
#  ('horrível', 6),
#  ('mesma', 6),
#  ('dúvida', 6),
#  ('liberar', 6),
#  ('ruim', 6),
#  ('respondem', 6),
#  ('20', 6),
#  ('logo', 6),
#  ('certo', 6),
#  ('onde', 6),
#  ('pois', 6),
#  ('outra', 6),
#  ('receber', 6),
#  ('15', 6),
#  ('acho', 6),
#  ('contas', 6),
#  ('rede', 6),
#  ('manda', 6),
#  ('esperar', 6),
#  ('entendi', 6),
#  ('cheque', 6),
#  ('abri', 6),
#  ('🙄', 6),
#  ('vida', 6),
#  ('tb', 6),
#  ('demorou', 6),
#  ('tava', 6),
#  ('funcionando', 6),
#  ('cadastrar', 6),
#  ('espera', 6),
#  ('melhorar', 6),
#  ('saques', 6),
#  ('depósitos', 6),
#  ('ano', 5),
#  ('recebi', 5),
#  ('depósito', 5),
#  ('inclusive', 5),
#  ('pessoal', 5),
#  ('algum', 5),
#  ('conseguindo', 5),
#  ('semanas', 5),
#  ('proposta', 5),
#  ('ingresso', 5),
#  ('favor', 5),
#  ('opção', 5),
#  ('automático', 5),
#  ('precisa', 5),
#  ('todos', 5),
#  ('existe', 5),
#  ('ajudem', 5),
#  ('aguardo', 5),
#  ('novamente', 5),
#  ('possível', 5),
#  ('quantos', 5),
#  ('foda', 5),
#  ('aguardando', 5),
#  ('tipo', 5),
#  ('merda', 5),
#  ('outubro', 5),
#  ('sendo', 5),
#  ('liguei', 5),
#  ('passei', 5),
#  ('sei', 5),
#  ('impossível', 5),
#  ('código', 5),
#  ('dois', 5),
#  ('nenhum', 5),
#  ('hein', 5),
#  ('cadastra', 5),
#  ('senha', 5),
#  ('nubank', 5),
#  ('novo', 5),
#  ('pena', 5),
#  ('inter', 5),
#  ('forma', 5),
#  ('ceu', 5),
#  ('surtando', 5),
#  ('parabéns', 5),
#  ('direito', 5),
#  ('dizem', 5),
#  ('amo', 5),
#  ('poderiam', 5),
#  ('deu', 5),
#  ('…', 5),
#  ('palma', 5),
#  ('mão', 5),
#  ('acessa', 5),
#  ('atms', 5),
#  ('retira', 5),
#  ('dinheiro…', 5),
#  ('poxa', 5),
#  ('uber', 5),
#  ('consegue', 4),
#  ('música', 4),
#  ('chamei', 4),
#  ('kkk', 4),
#  ('quais', 4),
#  ('enviei', 4),
#  ('sério', 4),
#  ('mimo', 4),
#  ('achei', 4),
#  ('c…', 4),
#  ('tanto', 4),
#  ('documentos', 4),
#  ('brasil', 4),
#  ('façam', 4),
#  ('p', 4),
#  ('chega', 4),
#  ('precisar', 4),
#  ('disseram', 4),
#  ('boleto', 4),
#  ('aproveitar', 4),
#  ('n…', 4),
#  ('todas', 4),
#  ('pedi', 4),
#  ('fico', 4),
#  ('tirar', 4),
#  ('kkkkkkkk', 4),
#  ('fevereiro', 4),
#  ('cada', 4),
#  ('saque', 4),
#  ('atende', 4),
#  ('desbloquear', 4),
#  ('caixa', 4),
#  ('30', 4),
#  ('linha', 4),
#  ('libera', 4),
#  ('serviço', 4),
#  ('valeu', 4),
#  ('levar', 4),
#  ('diz', 4),
#  ('gostaria', 4),
#  ('contra', 4),
#  ('fique', 4),
#  ('pensando', 4),
#  ('cartões', 4),
#  ('bosta', 4),
#  ('pedindo', 4),
#  ('caixas', 4),
#  ('falando', 4),
#  ('pra…', 4),
#  ('digital', 4),
#  ('indo', 4),
#  ('dando', 4),
#  ('porém', 4),
#  ('empresa', 4),
#  ('fala', 4),
#  ('jeito', 4),
#  ('pqp', 4),
#  ('e…', 4),
#  ('deve', 4),
#  ('obg', 4),
#  ('ganhar', 4),
#  ('sac', 4),
#  ('porra', 4),
#  ('comprovante', 4),
#  ('contar', 4),
#  ('cadê', 4),
#  ('guardar', 3),
#  ('colocar', 3),
#  ('t…', 3),
#  ('respondi', 3),
#  ('aparece', 3),
#  ('portabilidade', 3),
#  ('igual', 3),
#  ('informação', 3),
#  ('horário', 3),
#  ('comercial', 3),
#  ('finalmente', 3),
#  ('lembro', 3),
#  ('único', 3),
#  ('credito', 3),
#  ('foto', 3),
#  ('desisti', 3),
#  ('qualquer', 3),
#  ('ouvindo', 3),
#  ('responderam', 3),
#  ('sistema', 3),
#  ('voltar', 3),
#  ('pago', 3),
#  ('vantagem', 3),
#  ('help', 3),
#  ('falei', 3),
#  ('passando', 3),
#  ('c', 3),
#  ('desconto', 3),
#  ('40', 3),
#  ('triste', 3),
#  ('sextafeira', 3),
#  ('somente', 3),
#  ('varias', 3),
#  ('deveria', 3),
#  ('aprovado', 3),
#  ('reclamação', 3),
#  ('antes', 3),
#  ('conversa', 3),
#  ('incrível', 3),
#  ('parece', 3),
#  ('agenda', 3),
#  ('o…', 3),
#  ('etc', 3),
#  ('certeza', 3),
#  ('total', 3),
#  ('vem', 3),
#  ('utilizei', 3),
#  ('sacar', 3),
#  ('propaganda', 3),
#  ('verdade', 3),
#  ('falaram', 3),
#  ('mal', 3),
#  ('exatamente', 3),
#  ('já…', 3),
#  ('fiquei', 3),
#  ('quiser', 3),
#  ('mando', 3),
#  ('aguento', 3),
#  ('deram', 3),
#  ('apenas', 3),
#  ('juros', 3),
#  ('única', 3),
#  ('site', 3),
#  ('criei', 3),
#  ('ia', 3),
#  ('clonado', 3),
#  ('devolvido', 3),
#  ('janeiro', 3),
#  ('super', 3),
#  ('úteis', 3),
#  ('whatsapp', 3),
#  ('espere', 3),
#  ('ligar', 3),
#  ('entrega', 3),
#  ('ir', 3),
#  ('adorei', 3),
#  ('agência', 3),
#  ('resolve', 3),
#  ('twitter', 3),
#  ('nessa', 3),
#  ('ate', 3),
#  ('hj', 3),
#  ('deixa', 3),
#  ('odeio', 3),
#  ('debitado', 3),
#  ('socorro', 3),
#  ('veio', 3),
#  ('tento', 3),
#  ('0800', 3),
#  ('direto', 3),
#  ('paga', 3),
#  ('taxas', 3),
#  ('acontecer', 3),
#  ('so', 3),
#  ('lollapalooza', 3),
#  ('emprego', 3),
#  ('vlw', 3),
#  ('trabalhar', 3),
#  ('lt3', 3),
#  ('querendo', 3),
#  ('1h', 3),
#  ('aconteceu', 3),
#  ('amigo', 3),
#  ('endereço', 3),
#  ('claro', 3),
#  ('fácil', 3),
#  ('podia', 3),
#  ('documento', 3),
#  ('tendo', 3),
#  ('promo', 3),
#  ('serve', 3),
#  ('crush', 3),
#  ('pessoas', 3),
#  ('nesse', 3),
#  ('mandando', 3),
#  ('conseguiu', 3),
#  ('comemorar', 3),
#  ('valentines', 3),
#  ('bloomin’onion', 3),
#  ('kookaburra', 3),
#  ('wings', 3),
#  ('outback', 3),
#  ('cortesia', 3),
#  ('basta', 3),
#  ('aperi…', 3),
#  ('🤔', 3),
#  ('meio', 3),
#  ('ae', 3),
#  ('pfvr', 3),
#  ('sobre', 3),
#  ('pessimo', 3),
#  ('barraco', 3),
#  ('vergonha', 3),
#  ('demoram', 3),
#  ('existente', 3),
#  ('diaspedi', 3),
#  ('2018', 3),
#  ('nã…', 3),
#  ('pediram', 3),
#  ('😢', 3),
#  ('abre', 3),
#  ('acha', 2),
#  ('aproveita', 2),
#  ('dizer', 2),
#  ('android', 2),
#  ('12', 2),
#  ('juro', 2),
#  ('desisto', 2),
#  ('recebo', 2),
#  ('bastante', 2),
#  ('atualmente', 2),
#  ('amar', 2),
#  ('iam', 2),
#  ('mas…', 2),
#  ('continua', 2),
#  ('d', 2),
#  ('visa', 2),
#  ('aparecendo', 2),
#  ('várias', 2),
#  ('erro', 2),
#  ('realmente', 2),
#  ('atenção', 2),
#  ('resolvido', 2),
#  ('musiquinha', 2),
#  ('solicitação', 2),
#  ('voces', 2),
#  ('a…', 2),
#  ('preço', 2),
#  ('pacote', 2),
#  ('migrar', 2),
#  ('please', 2),
#  ('inbox', 2),
#  ('whats', 2),
#  ('rolou', 2),
#  ('meu…', 2),
#  ('prometo', 2),
#  ('pede', 2),
#  ('aguardar', 2),
#  ('última', 2),
#  ('ódio', 2),
#  ('venceu', 2),
#  ('lindos', 2),
#  ('precisando', 2),
#  ('ei', 2),
#  ('chip', 2),
#  ('kkkk', 2),
#  ('carteirinha', 2),
#  ('real', 2),
#  ('viu', 2),
#  ('segundo', 2),
#  ('ficou', 2),
#  ('humano', 2),
#  ('inovador', 2),
#  ('s', 2),
#  ('aprovada', 2),
#  ('poder', 2),
#  ('sera', 2),
#  ('tarifas', 2),
#  ('ted', 2),
#  ('doc', 2),
#  ('arrepender', 2),
#  ('suporte', 2),
#  ('titular', 2),
#  ('incluir', 2),
#  ('gato', 2),
#  ('bb', 2),
#  ('an…', 2),
#  ('comprar', 2),
#  ('cinemark', 2),
#  ('bloqueado', 2),
#  ('errei', 2),
#  ('no…', 2),
#  ('ser…', 2),
#  ('internet', 2),
#  ('entender', 2),
#  ('realizei', 2),
#  ('45min', 2),
#  ('aprova', 2),
#  ('passar', 2),
#  ('setor', 2),
#  ('descontos', 2),
#  ('primeira', 2),
#  ('quinta', 2),
#  ('continuo', 2),
#  ('amanhã', 2),
#  ('usando', 2),
#  ('anos', 2),
#  ('dificuldade', 2),
#  ('fofinho', 2),
#  ('usuário', 2),
#  ('cansei', 2),
#  ('dessa', 2),
#  ('nenhuma', 2),
#  ('enquanto', 2),
#  ('ligo', 2),
#  ('antecipar', 2),
#  ('eita', 2),
#  ('original', 2),
#  ('quantas', 2),
#  ('s…', 2),
#  ('r', 2),
#  ('começo', 2),
#  ('compras', 2),
#  ('reconhece', 2),
#  ('resolveram', 2),
#  ('abrindo', 2),
#  ('processo', 2),
#  ('absurdo', 2),
#  ('robô', 2),
#  ('vive', 2),
#  ('con…', 2),
#  ('cheio', 2),
#  ('além', 2),
#  ('disso', 2),
#  ('movimentação', 2),
#  ('feito', 2),
#  ('experiência', 2),
#  ('rastreamento', 2),
#  ('lindo', 2),
#  ('wpp', 2),
#  ('varios', 2),
#  ('parcelas', 2),
#  ('aberta', 2),
#  ('😅', 2),
#  ('configuração', 2),
#  ('ultimamente', 2),
#  ('demorando', 2),
#  ('sair', 2),
#  ('msm', 2),
#  ('serviços', 2),
#  ('especial', 2),
#  ('lolla', 2),
#  ('faixa', 2),
#  ('mana', 2),
#  ('desse', 2),
#  ('infelizmente', 2),
#  ('sp', 2),
#  ('cartao', 2),
#  ('arrependi', 2),
#  ('acontecendo', 2),
#  ('ap…', 2),
#  ('avaliação', 2),
#  ('kkkkkk', 2),
#  ('uso', 2),
#  ('prefiro', 2),
#  ('👍', 2),
#  ('paulo', 2),
#  ('dor', 2),
#  ('cabeça', 2),
#  ('olhada', 2),
#  ('la', 2),
#  ('aprovação', 2),
#  ('man', 2),
#  ('9', 2),
#  ('sido', 2),
#  ('amore', 2),
#  ('mandarem', 2),
#  ('fazem', 2),
#  ('usei', 2),
#  ('verdinho', 2),
#  ('anjos', 2),
#  ('praticamente', 2),
#  ('muita', 2),
#  ('iai', 2),
#  ('precisam', 2),
#  ('aparentemente', 2),
#  ('apple', 2),
#  ('contratar', 2),
#  ('pensei', 2),
#  ('😊', 2),
#  ('🤦🏽\u200d♀️', 2),
#  ('ah', 2),
#  ('parte', 2),
#  ('ganho', 2),
#  ('promoções', 2),
#  ('coisas', 2),
#  ('acontece', 2),
#  ('faça', 2),
#  ('precise', 2),
#  ('uns', 2),
#  ('reais', 2),
#  ('saldo', 2),
#  ('msg', 2),
#  ('sorte', 2),
#  ('bonita', 2),
#  ('papel', 2),
#  ('chama', 2),
#  ('habilitar', 2),
#  ('envia', 2),
#  ('relacionamento', 2),
#  ('vo', 2),
#  ('fecha', 2),
#  ('responderem', 2),
#  ('30min', 2),
#  ('cupons', 2),
#  ('excelente', 2),
#  ('ótimo', 2),
#  ('desinstalei', 2),
#  ('plano', 2),
#  ('banconext', 2),
#  ('7', 2),
#  ('vi', 2),
#  ('feira', 2),
#  ('urgente', 2),
#  ('daí', 2),
#  ('lindas', 2),
#  ('kkkkkkkkkk', 2),
#  ('dms', 2),
#  ('deixar', 2),
#  ('sinal', 2),
#  ('volta', 2),
#  ('5', 2),
#  ('olhar', 2),
#  ('querido', 2),
#  ('consigo…', 2),
#  ('bemvinda', 2),
#  ('6', 2),
#  ('google', 2),
#  ('está…', 2),
#  ('rejeita', 2),
#  ('salario', 2),
#  ('😒', 2),
#  ('youtube', 2),
#  ('min', 2),
#  ('visto', 2),
#  ('parada', 2),
#  ('resto', 2),
#  ('conte', 2),
#  ('sonho', 2),
#  ('fazendo', 2),
#  ('sem…', 2),
#  ('número', 2),
#  ('um…', 2),
#  ('cobrado', 2),
#  ('cadastrei', 2),
#  ('procedimento', 2),
#  ('abraço', 2),
#  ('eternidade', 2),
#  ('simplesmente', 2),
#  ('funcionar', 2),
#  ('estar', 2),
#  ('devo', 2),
#  ('tomar', 2),
#  ('momento', 2),
#  ('decepção', 2),
#  ('curtir', 2),
#  ('data', 2),
#  ('vencimento', 2),
#  ('obtive', 2),
#  ('retorno', 2),
#  ('ô', 2),
#  ('digo', 2),
#  ('poderia', 2),
#  ('dps', 2),
#  ('desbloqueei', 2),
#  ('apareceu', 2),
#  ('passado', 2),
#  ('finalizar', 2),
#  ('comprei', 2),
#  ('peguei', 2),
#  ('peço', 2),
#  ('reset', 2),
#  ('caso', 2),
#  ('respondendo', 2),
#  ('liberada', 2),
#  ('ridículo', 2),
#  ('promoção', 2),
#  ('desculpas', 2),
#  ('nãofaçanext', 2),
#  ('performance', 2),
#  ('estornar', 2),
#  ('notificação', 1),
#  ('poupança', 1),
#  ('utilizo', 1),
#  ('utilize', 1),
#  ('cobra', 1),
#  ('eduardo', 1),
#  ('relativo', 1),
#  ('cotação', 1),
#  ('corrente', 1),
#  ('fa…', 1),
#  ('amores', 1),
#  ('parado', 1),
#  ('custódia', 1),
#  ('transportadora', 1),
#  ('brincadeira', 1),
#  ('1502', 1),
#  ('terminei', 1),
#  ('fizeram', 1),
#  ('piada', 1),
#  ('recém', 1),
#  ('assaltado', 1),
#  ('kkkkmais', 1),
#  ('tempinho', 1),
#  ('criança', 1),
#  ('movimento…', 1),
#  ('gostando', 1),
#  ('faltando', 1),
#  ('importante…', 1),
#  ('creditado', 1),
#  ('vantagens', 1),
#  ('relação', 1),
#  ('exclusive', 1),
#  ('152', 1),
#  ('causa', 1),
#  ('animal', 1),
#  ('porcentagem', 1),
#  ('doado', 1),
#  ('ongs', 1),
#  ('detalhes', 1),
#  ('causou', 1),
#  ('serios', 1),
#  ('insisti', 1),
#  ('leader', 1),
#  ('tenho…', 1),
#  ('medo', 1),
#  ('descontou', 1),
#  ('alo', 1),
#  ('cartaozinho', 1),
#  ('cnh', 1),
#  ('lugar', 1),
#  ('10min', 1),
#  ('contando', 1),
#  ('motivos…', 1),
#  ('tmj', 1),
#  ('😉👊', 1),
#  ('😔', 1),
#  ('umas', 1),
#  ('atuali…', 1),
#  ('problemana', 1),
#  ('api', 1),
#  ('ar', 1),
#  ('previsão', 1),
#  ('caro', 1),
#  ('linduxos', 1),
#  ('resolução', 1),
#  ('campanha', 1),
#  ('específica', 1),
#  ('😌', 1),
#  ('nisso', 1),
#  ('deixam', 1),
#  ('falar…', 1),
#  ('vindo', 1),
#  ('ps', 1),
#  ('traição', 1),
#  ('❣️', 1),
#  ('aaaaaaaaaaakkkkkkkkkkkkkkkkkkkkkkkkkkkkk', 1),
#  ('todinha', 1),
#  ('alem', 1),
#  ('assisten…', 1),
#  ('rejeitado', 1),
#  ('escolhi', 1),
#  ('pela…', 1),
#  ('parcelado', 1),
#  ('5x', 1),
#  ('j…', 1),
#  ('transferir', 1),
#  ('30m', 1),
#  ('ligação…', 1),
#  ('rapidinho', 1),
#  ('explicar', 1),
#  ('negócio', 1),
#  ('confirmem', 1),
#  ('depositar', 1),
#  ('ja…', 1),
#  ('respondia', 1),
#  ('rapidinhomas', 1),
#  ('coração', 1),
#  ('voces…', 1),
#  ('mensagens', 1),
#  ('pais', 1),
#  ('ligar…', 1),
#  ('tira', 1),
#  ('patrocinadores', 1),
#  ('sobrando', 1),
#  ('budweiserbr…', 1),
#  ('benefícios', 1),
#  ('abra', 1),
#  ('chame', 1),
#  ('pedro', 1),
#  ('vamos', 1),
#  ('perguntas', 1),
#  ('🧡', 1),
#  ('abram', 1),
#  ('defeito', 1),
#  ('respos…', 1),
#  ('menino', 1),
#  ('ngm', 1),
#  ('gt', 1),
#  ('all', 1),
#  ('mocinha', 1),
#  ('diagostaria', 1),
#  ('tirei', 1),
#  ('infor…', 1),
#  ('fiada', 1),
#  ('neh', 1),
#  ('terceira', 1),
#  ('diferenças', 1),
#  ('demai…', 1),
#  ('domingo17', 1),
#  ('22', 1),
#  ('🤦🏼\u200d♀️', 1),
#  ('🌚', 1),
#  ('realizar', 1),
#  ('desbloqueio', 1),
#  ('tomando', 1),
#  ('surra', 1),
#  ('instituição', 1),
#  ('ch…', 1),
#  ('pretende', 1),
#  ('ressentimentos', 1),
#  ('parceria', 1),
#  ('domingo', 1),
#  ('consulto', 1),
#  ('transação', 1),
#  ('enaltecer', 1),
#  ('❤', 1),
#  ('mia', 1),
#  ('affs', 1),
#  ('okbom', 1),
#  ('diao', 1),
#  ('hhaha', 1),
#  ('hb', 1),
#  ('pareça', 1),
#  ('itaú', 1),
#  ('alguns', 1),
#  ('meia', 1),
#  ('😂😂😂', 1),
#  ('experimenta', 1),
#  ('simples', 1),
#  ('cancei', 1),
#  ('reaolver', 1),
#  ('insiste', 1),
#  ('merdaestou', 1),
#  ('reclamo', 1),
#  ('idiotas…', 1),
#  ('três', 1),
#  ('medida', 1),
#  ('“terceiro', 1),
#  ('dia”', 1),
#  ('liberarem', 1),
#  ('descontado', 1),
#  ('piores', 1),
#  ('banking', 1),
#  ('grandes', 1),
#  ('ganha', 1),
#  ('pertence', 1),
#  ('extrato', 1),
#  ('vantage…', 1),
#  ('possiveis', 1),
#  ('detran', 1),
#  ('iptu', 1),
#  ('concessionarias', 1),
#  ('tu…', 1),
#  ('ajeita', 1),
#  ('jornada', 1),
#  ('meros', 1),
#  ('opa', 1),
#  ('4x', 1),
#  ('ligações', 1),
#  ('beiran…', 1),
#  ('situação', 1),
#  ('plataforma', 1),
#  ('hor…', 1),
#  ('enviado', 1),
#  ('buscar', 1),
#  ('beleza', 1),
#  ('ne', 1),
#  ('concorrente…', 1),
#  ('liberou', 1),
#  ('🙄🙄🙄🙄🙄🙄', 1),
#  ('arruma', 1),
#  ('responsável', 1),
#  ('ligaç…', 1),
#  ('especiais', 1),
#  ('bilheteria', 1),
#  ('espaço', 1),
#  ('américas', 1),
#  ('teatro', 1),
#  ('curtir…', 1),
#  ('1hora', 1),
#  ('perdi', 1),
#  ('🤭', 1),
#  ('what', 1),
#  ('td', 1),
#  ('cai', 1),
#  ('disse', 1),
#  ('resolvermos', 1),
#  ('aciona', 1),
#  ('francamente', 1),
#  ('cheguei', 1),
#  ('respaldo', 1),
#  ('jdjeuttayu', 1),
#  ('njjrjud', 1),
#  ('d3d38', 1),
#  ('palhaçada', 1),
#  ('expediente', 1),
#  ('porcaria', 1),
#  ('bichos', 1),
#  ('moeda', 1),
#  ('troca', 1),
#  ('endividar', 1),
#  ('sr', 1),
#  ('feio', 1),
#  ('mel…', 1),
#  ('vish', 1),
#  ('🤣🤣🤣', 1),
#  ('quanta', 1),
#  ('😤', 1),
#  ('facil', 1),
#  ('atendi…', 1),
#  ('irei', 1),
#  ('milhares', 1),
#  ('postura', 1),
#  ('“queremos', 1),
#  ('pro…', 1),
#  ('cansada', 1),
#  ('tantas', 1),
#  ('“desculpas”', 1),
#  ('solução', 1),
#  ('reenviem', 1),
#  ('prim…', 1),
#  ('pendên…', 1),
#  ('anúncio', 1),
#  ('grrrr', 1),
#  ('especialgrana', 1),
#  ...]

# %% [markdown]
# *Transform occurrences in a dataframe*

# %%
wordcount = pd.DataFrame(counts, columns=['word', 'counts'])
top10 = wordcount[:10]
top10

# %% [markdown]
# *Top 10 most used words*

# %%
# Dataset
plt.style.use('seaborn')
height = top10.counts
bars = top10.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words')
 
# Show graphic
plt.show()

# %%
# Save graph into a file
fig.savefig('most_used_words.png', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# *ReLi Lexicon - portuguese sentimental analysis*

# %%
base_path = '/Users/gayr/documents/gabriela/mba/tcc/ReLi-Lex'
allData = []
files = [os.path.join(base_path, f) for f in os.listdir(base_path)]
for file in files:
    t = 'pos' if '_Positivos' in file else 'neg'
    with open(file, 'r', encoding = 'latin-1') as content_file:
        content = content_file.read()
        all = re.findall('\[.*?\]',content)
        for w in all:
            allData.append((w[1:-1], t))
allDataDF = pd.DataFrame(allData, columns=['word', 'sentiment'])

# %% [markdown]
# *Validate the model and avoid overfit*

# %% [markdown]
# Functions

# %%
# Split arrays or matrices into random train and test subsets
from sklearn.model_selection import train_test_split
# A random forest classifier
from sklearn.ensemble import RandomForestClassifier
# A naive bayes classifier
from sklearn.naive_bayes import MultinomialNB
# A boosting classifier
from sklearn.ensemble import AdaBoostClassifier
# Encode labels with value between 0 and n_classes-1
from sklearn.preprocessing import LabelEncoder
# Accuracy classification score
from sklearn.metrics import accuracy_score
# This classifier is useful as a simple baseline to compare with other (real) classifiers
from sklearn.dummy import DummyClassifier

# %% [markdown]
# Original Variables

# %%
X_original = allDataDF.word
Y_original = allDataDF.sentiment

# %% [markdown]
# O sklearn precisa que as variáveis independentes sejam contínuas - por esse motivo precisaremos transformar palavras em números

# %%
le_x = LabelEncoder()
X_labelEncoded = le_x.fit_transform(X_original)
le_y = LabelEncoder()
Y_labelEncoded = le_y.fit_transform(Y_original)

# %%
zippedEncoded = list(zip(X_labelEncoded, Y_labelEncoded))
dfEncoded = pd.DataFrame(zippedEncoded, columns = ['word', 'sentiment'])

# %% [markdown]
# Cross Validation - Divisão da amostra entre treino e teste - scikitlearn

# %%
X_labelEncodedDF = dfEncoded.word
Y_labelEncodedDF = dfEncoded.sentiment
X_train, X_test, y_train, y_test = train_test_split(X_labelEncodedDF, Y_labelEncodedDF, test_size=0.30, random_state = 13)

# %% [markdown]
# *Classification Models*

# %% [markdown]
# Random Forest Classifier

# %%
rf = RandomForestClassifier(n_estimators = 100)
rf.fit(X_train.values.reshape(-1, 1), y_train)
y_pred = rf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Naive Bayes Classifier

# %%
nb = MultinomialNB()
nb.fit(X_train.values.reshape(-1, 1), y_train)
y_nb_pred = nb.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Boosting Classifier

# %%
clf = AdaBoostClassifier(n_estimators=100)
clf.fit(X_train.values.reshape(-1, 1), y_train)
y_clf_pred = clf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Dummy Model

# %%
dm = DummyClassifier()
dm.fit(X_train.values.reshape(-1, 1), y_train)
y_dummy_pred = dm.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# *Model´s Accuracy*

# %%
print('Accuracy random forest on test dataset: {}'.format(round(accuracy_score(y_test, y_pred), 2)))
print('Accuracy naive bayes on test dataset: {}'.format(round(accuracy_score(y_test, y_nb_pred), 2)))
print('Accuracy boosting on test dataset: {}'.format(round(accuracy_score(y_test, y_clf_pred), 2)))
print('Accuracy dummy model on test dataset: {}'.format(round(accuracy_score(y_test, y_dummy_pred), 2)))
# Out:
# Accuracy random forest on test dataset: 0.65
# Accuracy naive bayes on test dataset: 0.58
# Accuracy boosting on test dataset: 0.59
# Accuracy dummy model on test dataset: 0.54

# %% [markdown]
# A seguir, iremos utilizar o algoritmo para classificação Random Forest para a análise de sentimentos, devido ao melhor nível de acurácia apresentado.

# %%
# tweetsDataLabelEncoder = LabelEncoder()
tweet_text = data.text
tweetsEncoded = le_x.fit_transform(tweet_text)
y_pred_total = rf.predict(tweetsEncoded.reshape(-1, 1))
y_pred_total_decoded = le_y.inverse_transform(y_pred_total)
data['sentiment'] = y_pred_total_decoded
display(data[:100])
# Out:
# C:\Users\GAYR\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#                                                  text sentiment
# 0   notificação do  a gente acha que você consegue...       pos
# 1    já utilizo o next a quase um ano e posso dize...       pos
# 2                                         ok obrigado       neg
# 3                                  eu tbm já respondi       pos
# 4                               mandei mensagem na dm       neg
# 5                                             eduardo       neg
# 6     no android não aparece nada relativo a cotação        neg
# 7   com 12 minutos de música a gente já sabe que a...       pos
# 8                                 te juro que desisto       neg
# 9    me ajuda pelo menos com a portabilidade e rec...       neg
# 10                                          chamei lá       pos
# 11  rt  vê um cachorrinho e já quer dar o mundo pr...       pos
# 12   amores ainda não recebi meu cartão está parad...       neg
# 13                                        tá difícil        pos
# 14       tá de brincadeira né sempre faço isso e nada       pos
# 15                                      vou mandar dm       pos
# 16                                           dia 1502       pos
# 17   mas nossa nem terminei o cadastro e já fizera...       neg
# 18  e eu que recém recebi o cartão do  e fui assal...       pos
# 19  o  quer se difícil de aprovar o limite de créd...       pos
# 20                                             tem o        pos
# 21  oi  estou gostando bastante do aplicativo e do...       pos
# 22   fiz um depósito ontem em horário comercial em...       pos
# 23   quais vantagens em relação ao bradesco sou ex...       pos
# 24   eu enviei dia 152 preciso abrir a conta ainda...       neg
# 25  finalmente chegou meu cartão do  sério gente o...       pos
# 26   achei que iam fazer algo pra ajudar a causa a...       neg
# 27   continua sem acesso mandei detalhes na dm me ...       pos
# 28                                  bom d top top top       pos
# 29  e a  insisti em dizer que eu tenho cartão lead...       pos
# ..                                                ...       ...
# 70   pior banco que existe atendimento péssimo não...       neg
# 71   faz 20 dias que eu pedi para cancelar meu car...       pos
# 72                   aceita o cara  menino é bom kkkk       pos
# 73                                     ngm me aceita        pos
# 74                                             gt all       pos
# 75   ajudem essa mocinha que quer uma conta logo 1...       pos
# 76  hoje chegou meu cartão de débito do  em uma ca...       pos
# 77                             certo fico no aguardo        neg
# 78  onde já se viu ficar uma hora pra falar com um...       pos
# 79   bom diagostaria de saber como tirar novamente...       pos
# 80   e  eu só queria falar com um ser humano antes...       pos
# 81                                     conversa fiada       neg
# 82              outra neh já é a terceira as tudo bem       pos
# 83  rt  vê um cachorrinho e já quer dar o mundo pr...       pos
# 84   quais as diferenças pq eu nao achei nada muit...       pos
# 85   oi mandei minha proposta no domingo17 quantos...       pos
# 86   ta foda a mais de um mês para receber se a co...       pos
# 87  22 minutos na ligação aguardando alguém do  🤦🏼...       neg
# 88                      tá mais e a agenda kkkkkkkk 🌚       pos
# 89   e agora o que eu faço vou ficar sem cartão e ...       pos
# 90  tomando uma surra para falar com algum atenden...       pos
# 91           sera que o  pretende me responder um dia       pos
# 92                    olá bom dia  dia 1 de fevereiro       neg
# 93          app do  funciona muito bem no meu android       pos
# 94       fui s ressentimentos p o    q tem parceri...       pos
# 95                                         no domingo       pos
# 96   onde consulto as tarifas de cada tipo de tran...       pos
# 97  vou enaltecer meu banco tenham  ❤ certeza que ...       pos
# 98                 estou com um problema na mia conta       pos
# 99                                                 dm       pos
#
# [100 rows x 2 columns]

# %% [markdown]
# *Counting positives and negatives*

# %%
df = data.groupby('sentiment').count()
df
# Out:
#            text
# sentiment
# neg         232
# pos         577

# %% [markdown]
# *Sentimental Analysis Graph based on Naive-Bayes Classification*

# %%
plt.style.use('seaborn')
pie_pos = df.loc['pos']
pie_neg = df.loc['neg']
fig = plt.figure()

slices = [pie_neg, pie_pos]
tweets = ['Negative', 'Positive']
columns = ['Red', 'Green']

plt.title('Tweets sentimental analysis')
 
plt.pie(slices, labels = tweets, colors = columns, startangle = 90, shadow = True, explode = (0.1, 0), autopct='%1.0f%%')

plt.show()

# %%
# Save graph into a file
fig.savefig("tweets_sentimental_analysis.png")

# %% [markdown]
# *Positive WordCloud*

# %%
# filtrar dataframe com tweets positivos
data_pos_filtered = data[data['sentiment'] == 'pos']
data_pos_filtered

# %% [markdown]
# *Save positive tweets in a csv file*

# %%
data_pos_filtered.to_csv("positive_tweets.csv", index = False, sep=';', encoding='utf-16')

# %% [markdown]
# *Like mask*

# %%
from PIL import Image
like_mask = np.array(Image.open("c:/Users/GAYR/Documents/Gabriela/MBA/tcc/images/like.png"))
like_mask

# %% [markdown]
# *Transform the mask*

# %%
def transform_format(val):
    if val == 0:
        return 255
    else:
        return val

# %%
# Transform your mask into a new one that will work with the function:
transformed_like_mask = np.ndarray((like_mask.shape[0],like_mask.shape[1]), np.int32)

for i in range(len(like_mask)):
    transformed_like_mask[i] = list(map(transform_format, like_mask[i]))

# %%
# Check the expected result of your mask
transformed_like_mask

# %%
# Create a word cloud image
wc = WordCloud(background_color="white", max_words=1000, mask=transformed_like_mask,
               stopwords=stopwords, contour_width=1, contour_color='white')

# %%
# WordCloud
plt.style.use('seaborn')
data_pos_filtered = " ".join(tweet for tweet in data_pos_filtered['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user_pos.png")
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Positive Tweets WordCloud')

# %%
# Generate a wordcloud
wc.generate(text)

# store to file
wc.to_file("c:/Users/GAYR/Documents/Gabriela/MBA/tcc/images/likecloud.png")

# show
plt.figure(figsize=[15,6])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.title('Positive Tweets WordCloud')
plt.show()

# %% [markdown]
# *Top 10 most used words in positive tweets*

# %%
count_pos = sorted(word_count(data_pos_filtered).items(), key = itemgetter(1), reverse = True)
wordcount_pos = pd.DataFrame(count_pos, columns=['word', 'counts'])
top10_pos = wordcount_pos[:10]
top10_pos

# %%
# Dataset
plt.style.use('seaborn')
height = top10_pos.counts
bars = top10_pos.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words in positive tweets')
 
# Show graphic
plt.show()

# %%
# Save graph into a file
fig.savefig("most_used_positive_words.png")

# %% [markdown]
# *Negative WordCloud*

# %%
# filtrar dataframe com tweets positivos
data_neg_filtered = data[data['sentiment'] == 'neg']
data_neg_filtered

# %% [markdown]
# *Save negative tweets in a csv file*

# %%
data_neg_filtered.to_csv("negative_tweets.csv", index = False, sep=';', encoding='utf-16')

# %% [markdown]
# *Dislike mask*

# %%
from PIL import Image
dislike_mask = np.array(Image.open("c:/Users/GAYR/Documents/Gabriela/MBA/tcc/images/dislike.png"))
dislike_mask

# %% [markdown]
# *Transform the mask*

# %%
def transform_format(val):
    if val == 1:
        return 255
    else:
        return val

# %%
# Transform your mask into a new one that will work with the function:
transformed_dislike_mask = np.ndarray((dislike_mask.shape[0],dislike_mask.shape[1]), np.int32)

for i in range(len(dislike_mask)):
    transformed_dislike_mask[i] = list(map(transform_format, dislike_mask[i]))

# %%
# Check the expected result of your mask
transformed_dislike_mask

# %%
# Create a word cloud image
wc_dislike = WordCloud(background_color="white", max_words=1000, mask=transformed_dislike_mask,
               stopwords=stopwords, contour_width=1, contour_color='white')

# %%
# WordCloud
plt.style.use('seaborn')
data_neg_filtered = " ".join(tweet for tweet in data_neg_filtered['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user_neg.png")
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Negative Tweets WordCloud')

# %%
# Generate a wordcloud
wc_dislike.generate(text)

# store to file
wc_dislike.to_file("c:/Users/GAYR/Documents/Gabriela/MBA/tcc/images/dislikecloud.png")

# show
plt.figure(figsize=[12,5])
plt.imshow(wc_dislike, interpolation='bilinear')
plt.axis("off")
plt.title('Negative Tweets WordCloud')
plt.show()

# %% [markdown]
# *Top 10 most used words in negative tweets*

# %%
count_neg = sorted(word_count(data_neg_filtered).items(), key = itemgetter(1), reverse = True)
wordcount_neg = pd.DataFrame(count_neg, columns=['word', 'counts'])
top10_neg = wordcount_neg[:10]
top10_neg

# %%
# Dataset
plt.style.use('seaborn')
height = top10_neg.counts
bars = top10_neg.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words in negative tweets')
 
# Show graphic
plt.show()

# %%
# Save into a file
fig.savefig("most_used_negative_words.png")
