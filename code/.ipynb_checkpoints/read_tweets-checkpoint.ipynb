# %% [markdown]
# *Import library's*

# %%
import numpy as np
import pandas as pd
from textblob import TextBlob as tb
import tweepy
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from textblob.classifiers import NaiveBayesClassifier
import os, re, nltk, string
from bs4 import BeautifulSoup
from collections import OrderedDict
from operator import itemgetter

# %% [markdown]
# *Twitter authentication*

# %%
consumer_key = 'Jg95VukOglg6RIqRrqt6GYRoa'
consumer_secret = 'ZvH3Oz7jFN0OvDMXGtRriTqOOykGnUgqxAU0wNKWhMElII0ivq'
access_token = '971179238396227584-KkOSGzCwhzv0lokz55Dkp1wTjyurnkW'
access_token_secret = 'y2NNUWU1tlhQYMOps49aSKgckRqTu7T7dPWpyNbMeXvAA'

# %%
def get_all_tweets(screen_name):
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth)
    alltweets = []
    new_tweets = api.search(screen_name)
    alltweets.extend(new_tweets)
    oldest = alltweets[-1].id - 1
    while len(new_tweets) > 0:
        new_tweets = api.search(screen_name, count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest = alltweets[-1].id - 1
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
    return outtweets

# %% [markdown]
# *Get all tweets*

# %%
public_tweets = get_all_tweets('@falanext')
df = pd.DataFrame(public_tweets, columns=['id','created_at','text'])
df
# Out:
#                       id          created_at  \
# 0    1061210330192322561 2018-11-10 10:53:53
# 1    1061135761502859264 2018-11-10 05:57:35
# 2    1061111316146995200 2018-11-10 04:20:26
# 3    1061101587916034048 2018-11-10 03:41:47
# 4    1061100614673973248 2018-11-10 03:37:55
# 5    1061095602895966208 2018-11-10 03:18:00
# 6    1061091060292747264 2018-11-10 02:59:57
# 7    1061090925429039104 2018-11-10 02:59:25
# 8    1061089146498879488 2018-11-10 02:52:21
# 9    1061089035320483840 2018-11-10 02:51:54
# 10   1061080529091600386 2018-11-10 02:18:06
# 11   1061075274333372416 2018-11-10 01:57:13
# 12   1061061342306725889 2018-11-10 01:01:52
# 13   1061057190851764224 2018-11-10 00:45:22
# 14   1061056812391297024 2018-11-10 00:43:52
# 15   1061056736239476738 2018-11-10 00:43:34
# 16   1061056190950633472 2018-11-10 00:41:24
# 17   1061040202439950338 2018-11-09 23:37:52
# 18   1061029846338494469 2018-11-09 22:56:43
# 19   1061028028346744833 2018-11-09 22:49:29
# 20   1061024588644212736 2018-11-09 22:35:49
# 21   1061020745441177601 2018-11-09 22:20:33
# 22   1061020708405415937 2018-11-09 22:20:24
# 23   1061020518097342464 2018-11-09 22:19:38
# 24   1061015666784985089 2018-11-09 22:00:22
# 25   1061013059223937024 2018-11-09 21:50:00
# 26   1061012841568845824 2018-11-09 21:49:08
# 27   1061012694277480448 2018-11-09 21:48:33
# 28   1061012605869940736 2018-11-09 21:48:12
# 29   1061012382225481729 2018-11-09 21:47:19
# ..                   ...                 ...
# 633  1057661343023673345 2018-10-31 15:51:29
# 634  1057655168123199488 2018-10-31 15:26:57
# 635  1057646505518084096 2018-10-31 14:52:31
# 636  1057645256651563009 2018-10-31 14:47:33
# 637  1057637418432528384 2018-10-31 14:16:25
# 638  1057619523845664768 2018-10-31 13:05:18
# 639  1057614299127013376 2018-10-31 12:44:33
# 640  1057613231924088833 2018-10-31 12:40:18
# 641  1057613003259109376 2018-10-31 12:39:24
# 642  1057602280848048128 2018-10-31 11:56:47
# 643  1057600551154827264 2018-10-31 11:49:55
# 644  1057574278189797376 2018-10-31 10:05:31
# 645  1057524735310000134 2018-10-31 06:48:39
# 646  1057483637149577217 2018-10-31 04:05:20
# 647  1057473595394396160 2018-10-31 03:25:26
# 648  1057465948721033216 2018-10-31 02:55:03
# 649  1057462401518440448 2018-10-31 02:40:57
# 650  1057445284781977600 2018-10-31 01:32:56
# 651  1057420936549412864 2018-10-30 23:56:11
# 652  1057412553247207429 2018-10-30 23:22:53
# 653  1057398556036874241 2018-10-30 22:27:15
# 654  1057398044826701824 2018-10-30 22:25:14
# 655  1057379230676332545 2018-10-30 21:10:28
# 656  1057373929499738118 2018-10-30 20:49:24
# 657  1057371932620976129 2018-10-30 20:41:28
# 658  1057363594197827585 2018-10-30 20:08:20
# 659  1057363164650790912 2018-10-30 20:06:37
# 660  1057360632218116096 2018-10-30 19:56:34
# 661  1057357080913477632 2018-10-30 19:42:27
# 662  1057350518593478658 2018-10-30 19:16:22
#
#                                                   text
# 0                   b'@falanext RESPONDE MEU PROBLEMA'
# 1    b'N\xc3\xa3o t\xc3\xb4 conseguindo acessar min...
# 2    b'@itau @Itaucard @credicard Aprendam com o @f...
# 3    b'RT @falanext: J\xc3\xa1 pode come\xc3\xa7ar ...
# 4    b'Mais um nen\xc3\xa9m para acabar com a minha...
# 5          b'@falanext mtv world stage pq me matastes'
# 6    b'@_unmAsked @falanext n\xc3\xa3o fui \xe2\x80...
# 7       b'@_unmAsked @falanext eu comprei o meu assim'
# 8    b'Al\xc3\xb4 @falanext cad\xc3\xaa meu limite ...
# 9                             b'@falanext @AndrezzaAl'
# 10   b'@falanext Fico feliz que estajam trabalhando...
# 11   b'Ae @nubank enquanto vc rejeita td mundo a @A...
# 12   b'@falanext V\xc3\xa3o ignorar um cliente de v...
# 13   b'Vai entender... A @falanext me aprovou a mai...
# 14            b'@crlim4s @falanext Hahahhahahahahahha'
# 15   b'@marcellinho27 @falanext Por isso amo o next...
# 16                               b'@falanext @crlim4s'
# 17   b'@picpay @Zanfa @TeletonOficial Bora @Nubank ...
# 18   b'Isto \xc3\xa9 o que chamo de @falanext \nDem...
# 19   b'Hey, @falanext! J\xc3\xa1 pensou em usar ess...
# 20   b'Resumo dos bancos digitais mais famosos: @Ba...
# 21   b'@CostaFe_ @nubank @falanext ACEITA ELE @nubank'
# 22   b'@falanext Eu envio e voc\xc3\xaas n\xc3\xa3o...
# 23   b'@falanext Me emprega que eu trago o meu sal\...
# 24   b'O banco Next \xc3\xa9 o pior banco quando se...
# 25   b'@falanext Eles roubam seu sal\xc3\xa1rio, n\...
# 26   b'@falanext @dyegocs_ N\xc3\xa3o adianta chama...
# 27   b'@falanext @pisamen9s E a segunda via que vc ...
# 28   b'@jacquess91 @falanext Fiquei trinta o lindo ...
# 29      b'@morais_sampa @falanext EXATAMENTE CARALHO!'
# ..                                                 ...
# 633                                  b'@falanext Sim!'
# 634  b'@falanext Desculpa minha ignor\xc3\xa2ncia m...
# 635  b'@falanext @falanext DM \xf0\x9f\x98\xa1\xf0\...
# 636  b'RT @angelicamari: Digital bank @falanext, ow...
# 637              b'@falanext vejam minha dm por favor'
# 638  b'o meu limite no @falanext sumiu ap\xc3\xb3s ...
# 639  b'RT @falanext: next tem conta + cart\xc3\xa3o...
# 640  b'RT @angelicamari: Digital bank @falanext, ow...
# 641  b'RT @angelicamari: Digital bank @falanext, ow...
# 642  b'@falanext Queria fazer portabilidade do meu ...
# 643  b'@falanext e ainda ganha uma carteirinha de p...
# 644  b'@falanext \xc3\x89 a \xc3\xbaltima vers\xc3\...
# 645  b'@falanext Uma vergonha que essa conta n\xc3\...
# 646  b'@aquelecaioIa @falanext vantagens: mimos, de...
# 647                   b'@opeterquill @falanext Olouco'
# 648  b'@falanext At\xc3\xa9 o momento n\xc3\xa3o, f...
# 649  b'qse 10 dias uteis e nada do meu cartao @fala...
# 650  b'atendimento do @falanext \xc3\xa9 muito ruim...
# 651  b'@falanext Ol\xc3\xa1 pessoal Next. Preciso e...
# 652  b'RT @falanext: @GiovaniMota Ol\xc3\xa1! Respo...
# 653                                    b'@falanext DM'
# 654  b'@falanext Oi, tive um probleminha ao desbloq...
# 655  b'@falanext at\xc3\xa9 no twitter next\nto jog...
# 656  b'@falanext em quanto tempo expira uma propost...
# 657                                  b'@falanext help'
# 658  b'@sami_oliveira @acpedrotti @itau @falanext @...
# 659  b'RT @falanext: @linomarneto23 Conta com a gen...
# 660  b'@acpedrotti @itau a vontade de ir para  @fal...
# 661  b'@falanext N\xc3\xa3o vou enviar print nenhum...
# 662  b'@falanext quando vai chegar o app da Next pr...
#
# [663 rows x 3 columns]

# %% [markdown]
# *Data Cleaning*

# %%
def cleanTweets(tweetsDF):
    table = str.maketrans(dict.fromkeys(string.punctuation.replace('@','')))
    # essa regex significa:
    # tudo que conter @ OU http OU terminador de linha seguido de uma palavra OU um espaco OU qualquer outro terminador
    # de linha.
    rePattern1 = '(@|http|\\n)(\w+|\s|\S)'
    formattedTweets = []
    for line in tweetsDF['text']:
        formattedStr = line.decode('utf-8').lower()
        formattedStr = formattedStr.translate(table)
        formattedStr = re.sub(rePattern1, "", formattedStr)  
        formattedTweets.append(formattedStr)
    return formattedTweets

formattedTweets = cleanTweets(df)
data = pd.DataFrame(formattedTweets, columns=['text'])
data
# Out:
#                                                   text
# 0                                responde meu problema
# 1    não tô conseguindo acessar minha conta do   er...
# 2       aprendam com o   e lançem uma atualização c...
# 3    rt  já pode começar a fazer os planos pra abri...
# 4    mais um neném para acabar com a minha vida jun...
# 5                       mtv world stage pq me matastes
# 6                             não fui “eu” mas foi kkk
# 7                               eu comprei o meu assim
# 8    alô  cadê meu limite de crédito que não libera...
# 9
# 10    fico feliz que estajam trabalhando nessas mel...
# 11   ae  enquanto vc rejeita td mundo a  até lançou...
# 12         vão ignorar um cliente de vocês serio isso
# 13   vai entender a  me aprovou a mais de dois mese...
# 14                                  hahahhahahahahahha
# 15                  por isso amo o next thank u next 💚
# 16
# 17                                        bora
# 18   isto é o que chamo de   tudo isso para ser ate...
# 19   hey  já pensou em usar esse som na publi de vo...
# 20   resumo dos bancos digitais mais famosos   e  r...
# 21                                         aceita ele
# 22                   eu envio e vocês não me respondem
# 23    me emprega que eu trago o meu salário pro nex...
# 24   o banco next é o pior banco quando se precisa ...
# 25    eles roubam seu salário não consegue nem tran...
# 26     não adianta chamar gerente nenhum eles estão...
# 27     e a segunda via que vc nao consegue pedir de...
# 28     fiquei trinta o lindo do atendente desligou ...
# 29                                  exatamente caralho
# ..                                                 ...
# 633                                                sim
# 634   desculpa minha ignorância mas não sei do que ...
# 635                                              dm 😡🤬
# 636  rt  digital bank  owned by brazilian banking g...
# 637                           vejam minha dm por favor
# 638  o meu limite no  sumiu após 3 dias de conta pa...
# 639  rt  next tem conta  cartão de crédito grátis e...
# 640  rt  digital bank  owned by brazilian banking g...
# 641  rt  digital bank  owned by brazilian banking g...
# 642   queria fazer portabilidade do meu salário pro...
# 643   e ainda ganha uma carteirinha de papel que nã...
# 644   é a última versão fiz o download na quinta fe...
# 645   uma vergonha que essa conta não possa ser mov...
# 646    vantagens mimos depósitos pelos caixas do br...
# 647                                             olouco
# 648   até o momento não faz 33 horas que enviei a m...
# 649  qse 10 dias uteis e nada do meu cartao  chegar...
# 650  atendimento do  é muito ruim não atendem chat ...
# 651   olá pessoal next preciso enviar as fotos para...
# 652                           rt   olá respondi sua dm
# 653                                                 dm
# 654   oi tive um probleminha ao desbloquear meu cartão
# 655   até no twitter next jogando aparece o next as...
# 656   em quanto tempo expira uma proposta que ficou...
# 657                                               help
# 658                        o que falavam no comunicado
# 659                           rt   conta com a gente 💚
# 660    a vontade de ir para    ou   aumentou muitoo...
# 661   não vou enviar print nenhum da última vez men...
# 662   quando vai chegar o app da next pra plataform...
#
# [663 rows x 1 columns]

# %% [markdown]
# *Stopwords in portuguese*

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')
# Inclusão de novas stopwords 
stopwords.append('tô')
stopwords.append('pra')
stopwords.append('pro')
stopwords.append('é')
stopwords.append('aí')
stopwords.append('ser')
stopwords.append('pq')

# %% [markdown]
# *WordCloud*

# %%
text = " ".join(tweet for tweet in data['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user.png")
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# *Basic statistics about the data*

# %%
def word_count(str):
    counts = OrderedDict()
    words = str.split()
    for word in words:
        if word not in stopwords:
            if word in counts:
                counts[word] += 1
            else:
                counts[word] = 1
    return counts

print("There are {} words in the combination of all tweets.".format(len(text)))

counts = sorted(word_count(text).items(), key = itemgetter(1), reverse = True)
display(counts[:10])
# Out:
# There are 43488 words in the combination of all tweets.
# [('cartão', 108),
#  ('conta', 65),
#  ('next', 63),
#  ('app', 40),
#  ('banco', 34),
#  ('atendimento', 34),
#  ('rt', 28),
#  ('crédito', 28),
#  ('dm', 28),
#  ('ainda', 25)]

# %% [markdown]
# *Transform occurrences in a dataframe*

# %%
wordcount = pd.DataFrame(counts, columns=['word', 'counts'])
top10 = wordcount[:10]
top10
# Out:
#           word  counts
# 0       cartão     108
# 1        conta      65
# 2         next      63
# 3          app      40
# 4        banco      34
# 5  atendimento      34
# 6           rt      28
# 7      crédito      28
# 8           dm      28
# 9        ainda      25

# %% [markdown]
# *Top 10 most used words*

# %%
# Dataset
height = top10.counts
bars = top10.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words')
 
# Show graphic
plt.show()

# %%
# Save into a file
fig.savefig('most_used_words.png', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# *ReLi Lexicon - portuguese sentimental analysis*

# %%
base_path = '/Users/gayr/documents/gabriela/mba/tcc/ReLi-Lex'
allData = []
files = [os.path.join(base_path, f) for f in os.listdir(base_path)]
for file in files:
    t = 'pos' if '_Positivos' in file else 'neg'
    with open(file, 'r', encoding = 'latin-1') as content_file:
        content = content_file.read()
        all = re.findall('\[.*?\]',content)
        for w in all:
            allData.append((w[1:-1], t))
allDataDF = pd.DataFrame(allData, columns=['word', 'sentiment'])
allDataDF
# Out:
#                 word sentiment
# 0        aborrecente       neg
# 1         anacrônico       neg
# 2          arrombado       neg
# 3              besta       neg
# 4            bizarro       neg
# 5               bobo       neg
# 6              burro       neg
# 7          cansativo       neg
# 8              chato       neg
# 9           chocante       neg
# 10             chulo       neg
# 11            clichê       neg
# 12           confuso       neg
# 13     decepcionante       neg
# 14        defeituoso       neg
# 15        deplorável       neg
# 16        depressivo       neg
# 17        deprimente       neg
# 18      desagradável       neg
# 19         desconexo       neg
# 20       desgastante       neg
# 21   desinteressante       neg
# 22     desnecessário       neg
# 23       desprezível       neg
# 24           difícil       neg
# 25       dispensável       neg
# 26           doentio       neg
# 27           egoísta       neg
# 28         enfadonho       neg
# 29           enjoado       neg
# ..               ...       ...
# 580      destacar-se       pos
# 581         divertir       pos
# 582        emocionar       pos
# 583         emplacar       pos
# 584         empolgar       pos
# 585         encantar       pos
# 586       enternecer       pos
# 587         entreter       pos
# 588        facilitar       pos
# 589         fascinar       pos
# 590            fluir       pos
# 591           gostar       pos
# 592      identificar       pos
# 593     impressionar       pos
# 594           inovar       pos
# 595       recomendar       pos
# 596     sensibilizar       pos
# 597       simpatizar       pos
# 598        valorizar       pos
# 599           vibrar       pos
# 600           viciar       pos
# 601         apavorar       pos
# 602          brilhar       pos
# 603          comover       pos
# 604          devorar       pos
# 605          prender       pos
# 606              rir       pos
# 607         saborear       pos
# 608      surpreender       pos
# 609            tocar       pos
#
# [610 rows x 2 columns]

# %% [markdown]
# *Validate the model and avoid overfit*

# %% [markdown]
# Functions

# %%
# Split arrays or matrices into random train and test subsets
from sklearn.model_selection import train_test_split
# A random forest classifier
from sklearn.ensemble import RandomForestClassifier
# A naive bayes classifier
from sklearn.naive_bayes import MultinomialNB
# Encode labels with value between 0 and n_classes-1
from sklearn.preprocessing import LabelEncoder
# Accuracy classification score
from sklearn.metrics import accuracy_score
# This classifier is useful as a simple baseline to compare with other (real) classifiers
from sklearn.dummy import DummyClassifier

# %% [markdown]
# Original Variables

# %%
X_original = allDataDF.word
Y_original = allDataDF.sentiment

# %% [markdown]
# O Naive Bayes do sklearn precisa que as variáveis independentes sejam contínuas - por esse motivo precisaremos transformar palavras em números

# %%
le_x = LabelEncoder()
X_labelEncoded = le_x.fit_transform(X_original)
le_y = LabelEncoder()
Y_labelEncoded = le_y.fit_transform(Y_original)

# %%
zippedEncoded = list(zip(X_labelEncoded, Y_labelEncoded))
dfEncoded = pd.DataFrame(zippedEncoded, columns = ['word', 'sentiment'])

# %% [markdown]
# Cross Validation - Divisão da amostra entre treino e teste - scikitlearn

# %%
X_labelEncodedDF = dfEncoded.word
Y_labelEncodedDF = dfEncoded.sentiment
X_train, X_test, y_train, y_test = train_test_split(X_labelEncodedDF, Y_labelEncodedDF, test_size=0.30, random_state = 13)

# %% [markdown]
# Random Forest Classifier

# %%
rf = RandomForestClassifier(n_estimators = 100)
rf.fit(X_train.values.reshape(-1, 1), y_train)
y_pred = rf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Naive Bayes Classifier

# %%
nb = MultinomialNB()
nb.fit(X_train.values.reshape(-1, 1), y_train)
y_nb_pred = rf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Dummy Model

# %%
dm = DummyClassifier()
dm.fit(X_train.values.reshape(-1, 1), y_train)
y_dummy_pred = dm.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Acurácia dos modelos

# %%
print('Accuracy random forest on test dataset: {}'.format(round(accuracy_score(y_test, y_pred), 2)))
print('Accuracy naive bayes on test dataset: {}'.format(round(accuracy_score(y_test, y_nb_pred), 2)))
print('Accuracy dummy model on test dataset: {}'.format(round(accuracy_score(y_test, y_dummy_pred), 2)))
# Out:
# Accuracy random forest on test dataset: 0.7
# Accuracy naive bayes on test dataset: 0.7
# Accuracy dummy model on test dataset: 0.46

# %% [markdown]
# O nível de acurácia do Random Forest foi igual a Naive Bayes e melhor que o Dummy, por esse motivo iremos utilizar o Random Forest para a análise de sentimentos

# %%
# tweetsDataLabelEncoder = LabelEncoder()
tweet_text = data.text
tweetsEncoded = le_x.fit_transform(tweet_text)
y_pred_total = rf.predict(tweetsEncoded.reshape(-1, 1))
y_pred_total_decoded = le_y.inverse_transform(y_pred_total)
data['sentiment'] = y_pred_total_decoded
data
# Out:
# C:\Users\GAYR\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#                                                   text sentiment
# 0                                responde meu problema       neg
# 1    não tô conseguindo acessar minha conta do   er...       pos
# 2       aprendam com o   e lançem uma atualização c...       pos
# 3    rt  já pode começar a fazer os planos pra abri...       pos
# 4    mais um neném para acabar com a minha vida jun...       pos
# 5                       mtv world stage pq me matastes       pos
# 6                             não fui “eu” mas foi kkk       pos
# 7                               eu comprei o meu assim       pos
# 8    alô  cadê meu limite de crédito que não libera...       neg
# 9                                                            pos
# 10    fico feliz que estajam trabalhando nessas mel...       neg
# 11   ae  enquanto vc rejeita td mundo a  até lançou...       pos
# 12         vão ignorar um cliente de vocês serio isso        neg
# 13   vai entender a  me aprovou a mais de dois mese...       pos
# 14                                  hahahhahahahahahha       neg
# 15                  por isso amo o next thank u next 💚       pos
# 16                                                           pos
# 17                                        bora               pos
# 18   isto é o que chamo de   tudo isso para ser ate...       pos
# 19   hey  já pensou em usar esse som na publi de vo...       pos
# 20   resumo dos bancos digitais mais famosos   e  r...       pos
# 21                                         aceita ele        pos
# 22                   eu envio e vocês não me respondem       neg
# 23    me emprega que eu trago o meu salário pro nex...       pos
# 24   o banco next é o pior banco quando se precisa ...       pos
# 25    eles roubam seu salário não consegue nem tran...       neg
# 26     não adianta chamar gerente nenhum eles estão...       pos
# 27     e a segunda via que vc nao consegue pedir de...       neg
# 28     fiquei trinta o lindo do atendente desligou ...       pos
# 29                                  exatamente caralho       pos
# ..                                                 ...       ...
# 633                                                sim       neg
# 634   desculpa minha ignorância mas não sei do que ...       neg
# 635                                              dm 😡🤬       neg
# 636  rt  digital bank  owned by brazilian banking g...       pos
# 637                           vejam minha dm por favor       neg
# 638  o meu limite no  sumiu após 3 dias de conta pa...       neg
# 639  rt  next tem conta  cartão de crédito grátis e...       pos
# 640  rt  digital bank  owned by brazilian banking g...       pos
# 641  rt  digital bank  owned by brazilian banking g...       pos
# 642   queria fazer portabilidade do meu salário pro...       neg
# 643   e ainda ganha uma carteirinha de papel que nã...       pos
# 644   é a última versão fiz o download na quinta fe...       neg
# 645   uma vergonha que essa conta não possa ser mov...       neg
# 646    vantagens mimos depósitos pelos caixas do br...       pos
# 647                                             olouco       pos
# 648   até o momento não faz 33 horas que enviei a m...       neg
# 649  qse 10 dias uteis e nada do meu cartao  chegar...       pos
# 650  atendimento do  é muito ruim não atendem chat ...       neg
# 651   olá pessoal next preciso enviar as fotos para...       pos
# 652                           rt   olá respondi sua dm       pos
# 653                                                 dm       pos
# 654   oi tive um probleminha ao desbloquear meu cartão       pos
# 655   até no twitter next jogando aparece o next as...       neg
# 656   em quanto tempo expira uma proposta que ficou...       neg
# 657                                               help       pos
# 658                        o que falavam no comunicado       pos
# 659                           rt   conta com a gente 💚       pos
# 660    a vontade de ir para    ou   aumentou muitoo...       pos
# 661   não vou enviar print nenhum da última vez men...       pos
# 662   quando vai chegar o app da next pra plataform...       neg
#
# [663 rows x 2 columns]

# %% [markdown]
# *Counting positives and negatives*

# %%
df = data.groupby('sentiment').count()
df
# Out:
#            text
# sentiment
# neg         216
# pos         447

# %% [markdown]
# *Sentimental Analysis Graph based on Naive-Bayes Classification*

# %%
pie_pos = df.loc['pos']
pie_neg = df.loc['neg']

slices = [pie_neg, pie_pos]
tweets = ['Negative', 'Positive']
columns = ['Red', 'Green']
 
plt.pie(slices, labels = tweets, colors = columns, startangle = 90, shadow = True, explode = (0.1, 0), autopct='%1.0f%%')

plt.show()

# %% [markdown]
# *Positive WordCloud*

# %%
# filtrar dataframe com tweets positivos
data_pos_filtered = data[data['sentiment'] == 'pos']

# %%
# WordCloud
data_pos_filtered = " ".join(tweet for tweet in data_pos_filtered['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user_pos.png")
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# *Top 10 most used words in positive tweets*

# %%
count_pos = sorted(word_count(data_pos_filtered).items(), key = itemgetter(1), reverse = True)
wordcount_pos = pd.DataFrame(count_pos, columns=['word', 'counts'])
top10_pos = wordcount_pos[:10]
top10_pos
# Out:
#           word  counts
# 0       cartão      80
# 1        conta      45
# 2         next      41
# 3          app      30
# 4        banco      28
# 5           rt      27
# 6      crédito      22
# 7           dm      19
# 8        fazer      18
# 9  atendimento      18

# %%
# Dataset
height = top10_pos.counts
bars = top10_pos.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words in positive tweets')
 
# Show graphic
plt.show()

# %%
# Save into a file
fig.savefig("most_used_positive_words.png")

# %% [markdown]
# *Negative WordCloud*

# %%
# filtrar dataframe com tweets positivos
data_neg_filtered = data[data['sentiment'] == 'neg']

# %%
# WordCloud
data_neg_filtered = " ".join(tweet for tweet in data_neg_filtered['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user_neg.png")
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# *Top 10 most used words in negative tweets*

# %%
count_neg = sorted(word_count(data_neg_filtered).items(), key = itemgetter(1), reverse = True)
wordcount_neg = pd.DataFrame(count_neg, columns=['word', 'counts'])
top10_neg = wordcount_neg[:10]
top10_neg
# Out:
#           word  counts
# 0       cartão      28
# 1         next      22
# 2        conta      20
# 3  atendimento      16
# 4         chat      10
# 5          app      10
# 6          sim      10
# 7       fatura      10
# 8         nada       9
# 9          dia       9

# %%
# Dataset
height = top10_neg.counts
bars = top10_neg.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words in negative tweets')
 
# Show graphic
plt.show()

# %%
# Save into a file
fig.savefig("most_used_negative_words.png")
