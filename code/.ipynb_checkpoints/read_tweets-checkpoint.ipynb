# %% [markdown]
# *Import library's*

# %%
import numpy as np
import pandas as pd
from textblob import TextBlob as tb
import tweepy
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from textblob.classifiers import NaiveBayesClassifier
import os, re, nltk, string
from bs4 import BeautifulSoup
from collections import OrderedDict
from operator import itemgetter

# %% [markdown]
# *Twitter authentication*

# %%
consumer_key = 'Jg95VukOglg6RIqRrqt6GYRoa'
consumer_secret = 'ZvH3Oz7jFN0OvDMXGtRriTqOOykGnUgqxAU0wNKWhMElII0ivq'
access_token = '971179238396227584-KkOSGzCwhzv0lokz55Dkp1wTjyurnkW'
access_token_secret = 'y2NNUWU1tlhQYMOps49aSKgckRqTu7T7dPWpyNbMeXvAA'

# %%
def get_all_tweets(screen_name):
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth)
    alltweets = []
    new_tweets = api.search(screen_name)
    alltweets.extend(new_tweets)
    oldest = alltweets[-1].id - 1
    while len(new_tweets) > 0:
        new_tweets = api.search(screen_name, count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest = alltweets[-1].id - 1
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
    return outtweets

# %% [markdown]
# *Get all tweets*

# %%
public_tweets = get_all_tweets('@falanext')
df = pd.DataFrame(public_tweets, columns=['id','created_at','text'])
df
# Out:
#                       id          created_at  \
# 0    1061407084548374528 2018-11-10 23:55:43
# 1    1061389946567696384 2018-11-10 22:47:37
# 2    1061383171747520512 2018-11-10 22:20:42
# 3    1061360390309904390 2018-11-10 20:50:10
# 4    1061347012031918080 2018-11-10 19:57:01
# 5    1061322332814434304 2018-11-10 18:18:57
# 6    1061315771664687104 2018-11-10 17:52:52
# 7    1061302424709877760 2018-11-10 16:59:50
# 8    1061300724003454976 2018-11-10 16:53:05
# 9    1061284631926972416 2018-11-10 15:49:08
# 10   1061279100705402882 2018-11-10 15:27:09
# 11   1061277578651164672 2018-11-10 15:21:06
# 12   1061276305008791554 2018-11-10 15:16:03
# 13   1061271219905933312 2018-11-10 14:55:50
# 14   1061271207348236288 2018-11-10 14:55:47
# 15   1061271168546734080 2018-11-10 14:55:38
# 16   1061268242000474112 2018-11-10 14:44:00
# 17   1061264146300354560 2018-11-10 14:27:44
# 18   1061263805911568386 2018-11-10 14:26:23
# 19   1061257763467247616 2018-11-10 14:02:22
# 20   1061251286711091200 2018-11-10 13:36:38
# 21   1061246559327846400 2018-11-10 13:17:51
# 22   1061242117404741632 2018-11-10 13:00:12
# 23   1061236574699114496 2018-11-10 12:38:10
# 24   1061234466352496645 2018-11-10 12:29:48
# 25   1061210330192322561 2018-11-10 10:53:53
# 26   1061135761502859264 2018-11-10 05:57:35
# 27   1061111316146995200 2018-11-10 04:20:26
# 28   1061101587916034048 2018-11-10 03:41:47
# 29   1061100614673973248 2018-11-10 03:37:55
# ..                   ...                 ...
# 642  1057813230884659200 2018-11-01 01:55:02
# 643  1057805763324850182 2018-11-01 01:25:21
# 644  1057785209406533633 2018-11-01 00:03:41
# 645  1057783930592677889 2018-10-31 23:58:36
# 646  1057783159620804613 2018-10-31 23:55:32
# 647  1057778550403710976 2018-10-31 23:37:13
# 648  1057768100375023616 2018-10-31 22:55:42
# 649  1057763659508842496 2018-10-31 22:38:03
# 650  1057753154643783680 2018-10-31 21:56:18
# 651  1057748990173822978 2018-10-31 21:39:45
# 652  1057741696811892750 2018-10-31 21:10:47
# 653  1057737894213804032 2018-10-31 20:55:40
# 654  1057709707492814848 2018-10-31 19:03:40
# 655  1057703970481860608 2018-10-31 18:40:52
# 656  1057698785076355073 2018-10-31 18:20:16
# 657  1057694867164446720 2018-10-31 18:04:42
# 658  1057692179081109504 2018-10-31 17:54:01
# 659  1057690679361634304 2018-10-31 17:48:03
# 660  1057661437500370944 2018-10-31 15:51:51
# 661  1057661343023673345 2018-10-31 15:51:29
# 662  1057655168123199488 2018-10-31 15:26:57
# 663  1057646505518084096 2018-10-31 14:52:31
# 664  1057645256651563009 2018-10-31 14:47:33
# 665  1057637418432528384 2018-10-31 14:16:25
# 666  1057619523845664768 2018-10-31 13:05:18
# 667  1057614299127013376 2018-10-31 12:44:33
# 668  1057613231924088833 2018-10-31 12:40:18
# 669  1057613003259109376 2018-10-31 12:39:24
# 670  1057602280848048128 2018-10-31 11:56:47
# 671  1057600551154827264 2018-10-31 11:49:55
#
#                                                   text
# 0    b'@falanext Pr\xc3\xb3xima semana ainda? Voc\x...
# 1    b'@falanext Chamei. Tamb\xc3\xa9m j\xc3\xa1 ti...
# 2    b'@falanext Cr\xc3\xa9dito n\xc3\xa3o sei pra ...
# 3                                         b'@falanext'
# 4    b'@falanext minha fatura do cartao vence hoje....
# 5    b'@tatafragoso22 T\xc3\xa1 fazendo feio, @fala...
# 6    b'@falanext Oi! Como fa\xc3\xa7o para aumentar...
# 7    b'RT @falanext: next tem conta + cart\xc3\xa3o...
# 8    b'@dulcetti @NickEllis Caras... to usando o @f...
# 9    b'Eai @falanext e o apple pay que ia sair em o...
# 10   b'@falanext Tava com duvida de onde pedir! Obr...
# 11   b'@falanext Boa tarde! J\xc3\xa1 faz quase 5 d...
# 12   b'@falanext estou com duvidas com os servi\xc3...
# 13   b'finalmente meu cartao do @falanext chegou aa...
# 14                                  b'@falanext Atoa*'
# 15   b'@falanext Foi respondida mas voc\xc3\xaas su...
# 16   b'@falanext paguei minha fatura e o limite n\x...
# 17   b'@falanext o atendimento pelo aplicativo \xc3...
# 18   b'No silencio da noite fico imaginando o quant...
# 19   b'@falanext na op\xc3\xa7\xc3\xa3o de recarga ...
# 20   b'@falanext J\xc3\xa1 tem mais de 10 dias \xc3...
# 21       b'alo @falanext da uma aten\xc3\xa7\xc3\xa3o'
# 22   b'@falanext \xf0\x9f\x98\x88 https://t.co/bobt...
# 23                                     b'@falanext DM'
# 24   b'@falanext espero q sim. estou sendo cobrada ...
# 25                  b'@falanext RESPONDE MEU PROBLEMA'
# 26   b'N\xc3\xa3o t\xc3\xb4 conseguindo acessar min...
# 27   b'@itau @Itaucard @credicard Aprendam com o @f...
# 28   b'RT @falanext: J\xc3\xa1 pode come\xc3\xa7ar ...
# 29   b'Mais um nen\xc3\xa9m para acabar com a minha...
# ..                                                 ...
# 642                            b'@falanext ajuda euuu'
# 643  b'Depois de 62 dias sem cart\xc3\xa3o consegui...
# 644  b'Gente o @falanext \xc3\xa9 horr\xc3\xadvel, ...
# 645  b'@falanext qual a mensagem de halloween? Cheg...
# 646                                    b'@falanext Ok'
# 647  b'@falanext Percebi isso hoje \xf0\x9f\x98\xaa...
# 648  b'@raphaeldsmaia @falanext @Bancointer Como as...
# 649  b'@falanext Quais os perks de trazer o sal\xc3...
# 650  b'@falanext J\xc3\xa1 foi enviado!!!\n\nObriga...
# 651  b'@falanext mandei direct pra voc\xc3\xaas! Me...
# 652  b'@falanext isso n \xc3\xa9 coisa de millenium...
# 653  b'OOOOHHHH @falanext ta dif\xc3\xadcil hein! N...
# 654  b'@ThaisLora s\xc3\xb3 o @falanext pra fazer u...
# 655  b'@1NADAsobreTUDO @meudigio @timeneon @nubank ...
# 656  b'desisto, obg @falanext pelos 30 mun mais bem...
# 657  b'@falanext , j\xc3\xa1 estou h\xc3\xa1 10 min...
# 658  b'@falanext eu s\xc3\xb3 queria fechar minha c...
# 659  b'Seria bom se o @falanext aceitasse dep\xc3\x...
# 660        b'@falanext Ok, Obrigado!!!\n\nChamarei...'
# 661                                  b'@falanext Sim!'
# 662  b'@falanext Desculpa minha ignor\xc3\xa2ncia m...
# 663  b'@falanext @falanext DM \xf0\x9f\x98\xa1\xf0\...
# 664  b'RT @angelicamari: Digital bank @falanext, ow...
# 665              b'@falanext vejam minha dm por favor'
# 666  b'o meu limite no @falanext sumiu ap\xc3\xb3s ...
# 667  b'RT @falanext: next tem conta + cart\xc3\xa3o...
# 668  b'RT @angelicamari: Digital bank @falanext, ow...
# 669  b'RT @angelicamari: Digital bank @falanext, ow...
# 670  b'@falanext Queria fazer portabilidade do meu ...
# 671  b'@falanext e ainda ganha uma carteirinha de p...
#
# [672 rows x 3 columns]

# %% [markdown]
# *Data Cleaning*

# %%
def cleanTweets(tweetsDF):
    table = str.maketrans(dict.fromkeys(string.punctuation.replace('@','')))
    # essa regex significa:
    # tudo que conter @ OU http OU terminador de linha seguido de uma palavra OU um espaco OU qualquer outro terminador
    # de linha.
    rePattern1 = '(@|http|\\n)(\w+|\s|\S)'
    formattedTweets = []
    for line in tweetsDF['text']:
        formattedStr = line.decode('utf-8').lower()
        formattedStr = formattedStr.translate(table)
        formattedStr = re.sub(rePattern1, "", formattedStr)  
        formattedTweets.append(formattedStr)
    return formattedTweets

formattedTweets = cleanTweets(df)
data = pd.DataFrame(formattedTweets, columns=['text'])
data
# Out:
#                                                   text
# 0     próxima semana ainda vocês me prometeram que ...
# 1     chamei também já tinha chamado no whats na qu...
# 2     crédito não sei pra quem porque tenho cartão ...
# 3
# 4     minha fatura do cartao vence hoje agendei o p...
# 5                                     tá fazendo feio
# 6     oi como faço para aumentar o limite quero com...
# 7    rt  next tem conta  cartão de crédito grátis e...
# 8      caras to usando o  e to curtindo da pra migr...
# 9            eai  e o apple pay que ia sair em outubro
# 10      tava com duvida de onde pedir obrigadao next 😘
# 11    boa tarde já faz quase 5 dias que efetuei o c...
# 12          estou com duvidas com os serviços de conta
# 13   finalmente meu cartao do  chegou aaaaaaobg a m...
# 14                                                atoa
# 15    foi respondida mas vocês sumiram né pelo amor...
# 16    paguei minha fatura e o limite não foi libera...
# 17    o atendimento pelo aplicativo é muito ruim qu...
# 18   no silencio da noite fico imaginando o quanto ...
# 19    na opção de recarga de celular podia ter a op...
# 20      já tem mais de 10 dias úteis mais de 2 semanas
# 21                                 alo  da uma atenção
# 22                                                  😈
# 23                                                  dm
# 24    espero q sim estou sendo cobrada por tarifas ...
# 25                               responde meu problema
# 26   não tô conseguindo acessar minha conta do   er...
# 27      aprendam com o   e lançem uma atualização c...
# 28   rt  já pode começar a fazer os planos pra abri...
# 29   mais um neném para acabar com a minha vida jun...
# ..                                                 ...
# 642                                         ajuda euuu
# 643  depois de 62 dias sem cartão consegui receber ...
# 644  gente o  é horrível aplicativo ruim horas pra ...
# 645   qual a mensagem de halloween chegou a notific...
# 646                                                 ok
# 647   percebi isso hoje 😪😥 tive que ir na boca do c...
# 648         como assim banco que não tem extrato 🤷🏽‍♂️
# 649   quais os perks de trazer o salário pro next s...
# 650                já foi enviadoobrigado pela atenção
# 651   mandei direct pra vocês me da essa força gale...
# 652                       isso n é coisa de millenium
# 653  oooohhhh  ta difícil hein não tem extrato da c...
# 654              só o  pra fazer uma fofura dessas lt3
# 655       nubank e digio são os melhores dessas opções
# 656  desisto obg  pelos 30 mun mais bem gastos da m...
# 657    já estou há 10 min na ligação ouvindo musiqu...
# 658   eu só queria fechar minha conta e não pagar o...
# 659  seria bom se o  aceitasse depósito imediato no...
# 660                                ok obrigadochamarei
# 661                                                sim
# 662   desculpa minha ignorância mas não sei do que ...
# 663                                              dm 😡🤬
# 664  rt  digital bank  owned by brazilian banking g...
# 665                           vejam minha dm por favor
# 666  o meu limite no  sumiu após 3 dias de conta pa...
# 667  rt  next tem conta  cartão de crédito grátis e...
# 668  rt  digital bank  owned by brazilian banking g...
# 669  rt  digital bank  owned by brazilian banking g...
# 670   queria fazer portabilidade do meu salário pro...
# 671   e ainda ganha uma carteirinha de papel que nã...
#
# [672 rows x 1 columns]

# %% [markdown]
# *Stopwords in portuguese*

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')
# Inclusão de novas stopwords 
stopwords.append('tô')
stopwords.append('tá')
stopwords.append('pra')
stopwords.append('pro')
stopwords.append('é')
stopwords.append('aí')
stopwords.append('ser')
stopwords.append('pq')
stopwords.append('já')
stopwords.append('nao')
stopwords.append('rt')
stopwords.append('porque')
stopwords.append('vai')
stopwords.append('vou')
stopwords.append('faço')
stopwords.append('dm')
stopwords.append('q')

# %% [markdown]
# *WordCloud*

# %%
text = " ".join(tweet for tweet in data['text'])
plt.style.use('seaborn')
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user.png")
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Tweets WordCloud')
# Out:
# Text(0.5,1,'Tweets WordCloud')

# %% [markdown]
# *Basic statistics about the data*

# %%
def word_count(str):
    counts = OrderedDict()
    words = str.split()
    for word in words:
        if word not in stopwords:
            if word in counts:
                counts[word] += 1
            else:
                counts[word] = 1
    return counts

print("There are {} words in the combination of all tweets.".format(len(text)))

counts = sorted(word_count(text).items(), key = itemgetter(1), reverse = True)
display(counts[:10])
# Out:
# There are 44162 words in the combination of all tweets.
# [('cartão', 109),
#  ('conta', 66),
#  ('next', 60),
#  ('app', 39),
#  ('atendimento', 35),
#  ('banco', 34),
#  ('crédito', 31),
#  ('ainda', 29),
#  ('dia', 24),
#  ('cancelar', 22)]

# %% [markdown]
# *Transform occurrences in a dataframe*

# %%
wordcount = pd.DataFrame(counts, columns=['word', 'counts'])
top10 = wordcount[:10]
top10
# Out:
#           word  counts
# 0       cartão     109
# 1        conta      66
# 2         next      60
# 3          app      39
# 4  atendimento      35
# 5        banco      34
# 6      crédito      31
# 7        ainda      29
# 8          dia      24
# 9     cancelar      22

# %% [markdown]
# *Top 10 most used words*

# %%
# Dataset
plt.style.use('seaborn')
height = top10.counts
bars = top10.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words')
 
# Show graphic
plt.show()

# %%
# Save graph into a file
fig.savefig('most_used_words.png', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# *ReLi Lexicon - portuguese sentimental analysis*

# %%
base_path = '/Users/gayr/documents/gabriela/mba/tcc/ReLi-Lex'
allData = []
files = [os.path.join(base_path, f) for f in os.listdir(base_path)]
for file in files:
    t = 'pos' if '_Positivos' in file else 'neg'
    with open(file, 'r', encoding = 'latin-1') as content_file:
        content = content_file.read()
        all = re.findall('\[.*?\]',content)
        for w in all:
            allData.append((w[1:-1], t))
allDataDF = pd.DataFrame(allData, columns=['word', 'sentiment'])
allDataDF
# Out:
#                 word sentiment
# 0        aborrecente       neg
# 1         anacrônico       neg
# 2          arrombado       neg
# 3              besta       neg
# 4            bizarro       neg
# 5               bobo       neg
# 6              burro       neg
# 7          cansativo       neg
# 8              chato       neg
# 9           chocante       neg
# 10             chulo       neg
# 11            clichê       neg
# 12           confuso       neg
# 13     decepcionante       neg
# 14        defeituoso       neg
# 15        deplorável       neg
# 16        depressivo       neg
# 17        deprimente       neg
# 18      desagradável       neg
# 19         desconexo       neg
# 20       desgastante       neg
# 21   desinteressante       neg
# 22     desnecessário       neg
# 23       desprezível       neg
# 24           difícil       neg
# 25       dispensável       neg
# 26           doentio       neg
# 27           egoísta       neg
# 28         enfadonho       neg
# 29           enjoado       neg
# ..               ...       ...
# 580      destacar-se       pos
# 581         divertir       pos
# 582        emocionar       pos
# 583         emplacar       pos
# 584         empolgar       pos
# 585         encantar       pos
# 586       enternecer       pos
# 587         entreter       pos
# 588        facilitar       pos
# 589         fascinar       pos
# 590            fluir       pos
# 591           gostar       pos
# 592      identificar       pos
# 593     impressionar       pos
# 594           inovar       pos
# 595       recomendar       pos
# 596     sensibilizar       pos
# 597       simpatizar       pos
# 598        valorizar       pos
# 599           vibrar       pos
# 600           viciar       pos
# 601         apavorar       pos
# 602          brilhar       pos
# 603          comover       pos
# 604          devorar       pos
# 605          prender       pos
# 606              rir       pos
# 607         saborear       pos
# 608      surpreender       pos
# 609            tocar       pos
#
# [610 rows x 2 columns]

# %% [markdown]
# *Validate the model and avoid overfit*

# %% [markdown]
# Functions

# %%
# Split arrays or matrices into random train and test subsets
from sklearn.model_selection import train_test_split
# A random forest classifier
from sklearn.ensemble import RandomForestClassifier
# A naive bayes classifier
from sklearn.naive_bayes import MultinomialNB
# A boosting classifier
from sklearn.ensemble import AdaBoostClassifier
# Encode labels with value between 0 and n_classes-1
from sklearn.preprocessing import LabelEncoder
# Accuracy classification score
from sklearn.metrics import accuracy_score
# This classifier is useful as a simple baseline to compare with other (real) classifiers
from sklearn.dummy import DummyClassifier
# Out:
# C:\Users\GAYR\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# Original Variables

# %%
X_original = allDataDF.word
Y_original = allDataDF.sentiment

# %% [markdown]
# O sklearn precisa que as variáveis independentes sejam contínuas - por esse motivo precisaremos transformar palavras em números

# %%
le_x = LabelEncoder()
X_labelEncoded = le_x.fit_transform(X_original)
le_y = LabelEncoder()
Y_labelEncoded = le_y.fit_transform(Y_original)

# %%
zippedEncoded = list(zip(X_labelEncoded, Y_labelEncoded))
dfEncoded = pd.DataFrame(zippedEncoded, columns = ['word', 'sentiment'])

# %% [markdown]
# Cross Validation - Divisão da amostra entre treino e teste - scikitlearn

# %%
X_labelEncodedDF = dfEncoded.word
Y_labelEncodedDF = dfEncoded.sentiment
X_train, X_test, y_train, y_test = train_test_split(X_labelEncodedDF, Y_labelEncodedDF, test_size=0.30, random_state = 13)

# %% [markdown]
# *Classification Models*

# %% [markdown]
# Random Forest Classifier

# %%
rf = RandomForestClassifier(n_estimators = 100)
rf.fit(X_train.values.reshape(-1, 1), y_train)
y_pred = rf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Naive Bayes Classifier

# %%
nb = MultinomialNB()
nb.fit(X_train.values.reshape(-1, 1), y_train)
y_nb_pred = nb.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Boosting Classifier

# %%
clf = AdaBoostClassifier(n_estimators=100)
clf.fit(X_train.values.reshape(-1, 1), y_train)
y_clf_pred = clf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Dummy Model

# %%
dm = DummyClassifier()
dm.fit(X_train.values.reshape(-1, 1), y_train)
y_dummy_pred = dm.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# *Model´s Accuracy*

# %%
print('Accuracy random forest on test dataset: {}'.format(round(accuracy_score(y_test, y_pred), 2)))
print('Accuracy naive bayes on test dataset: {}'.format(round(accuracy_score(y_test, y_nb_pred), 2)))
print('Accuracy boosting on test dataset: {}'.format(round(accuracy_score(y_test, y_clf_pred), 2)))
print('Accuracy dummy model on test dataset: {}'.format(round(accuracy_score(y_test, y_dummy_pred), 2)))
# Out:
# Accuracy random forest on test dataset: 0.7
# Accuracy naive bayes on test dataset: 0.63
# Accuracy boosting on test dataset: 0.66
# Accuracy dummy model on test dataset: 0.55

# %% [markdown]
# A seguir, iremos utilizar o algoritmo para classificação Random Forest para a análise de sentimentos, devido ao melhor nível de acurácia apresentado.

# %%
# tweetsDataLabelEncoder = LabelEncoder()
tweet_text = data.text
tweetsEncoded = le_x.fit_transform(tweet_text)
y_pred_total = rf.predict(tweetsEncoded.reshape(-1, 1))
y_pred_total_decoded = le_y.inverse_transform(y_pred_total)
data['sentiment'] = y_pred_total_decoded
data
# Out:
# C:\Users\GAYR\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#                                                   text sentiment
# 0     próxima semana ainda vocês me prometeram que ...       pos
# 1     chamei também já tinha chamado no whats na qu...       pos
# 2     crédito não sei pra quem porque tenho cartão ...       pos
# 3                                                            pos
# 4     minha fatura do cartao vence hoje agendei o p...       neg
# 5                                     tá fazendo feio        neg
# 6     oi como faço para aumentar o limite quero com...       pos
# 7    rt  next tem conta  cartão de crédito grátis e...       pos
# 8      caras to usando o  e to curtindo da pra migr...       pos
# 9            eai  e o apple pay que ia sair em outubro       pos
# 10      tava com duvida de onde pedir obrigadao next 😘       pos
# 11    boa tarde já faz quase 5 dias que efetuei o c...       neg
# 12          estou com duvidas com os serviços de conta       neg
# 13   finalmente meu cartao do  chegou aaaaaaobg a m...       pos
# 14                                                atoa       pos
# 15    foi respondida mas vocês sumiram né pelo amor...       pos
# 16    paguei minha fatura e o limite não foi libera...       pos
# 17    o atendimento pelo aplicativo é muito ruim qu...       neg
# 18   no silencio da noite fico imaginando o quanto ...       neg
# 19    na opção de recarga de celular podia ter a op...       neg
# 20      já tem mais de 10 dias úteis mais de 2 semanas       pos
# 21                                 alo  da uma atenção       neg
# 22                                                  😈        pos
# 23                                                  dm       pos
# 24    espero q sim estou sendo cobrada por tarifas ...       pos
# 25                               responde meu problema       pos
# 26   não tô conseguindo acessar minha conta do   er...       pos
# 27      aprendam com o   e lançem uma atualização c...       pos
# 28   rt  já pode começar a fazer os planos pra abri...       pos
# 29   mais um neném para acabar com a minha vida jun...       pos
# ..                                                 ...       ...
# 642                                         ajuda euuu       neg
# 643  depois de 62 dias sem cartão consegui receber ...       pos
# 644  gente o  é horrível aplicativo ruim horas pra ...       neg
# 645   qual a mensagem de halloween chegou a notific...       neg
# 646                                                 ok       pos
# 647   percebi isso hoje 😪😥 tive que ir na boca do c...       pos
# 648         como assim banco que não tem extrato 🤷🏽‍♂️       pos
# 649   quais os perks de trazer o salário pro next s...       neg
# 650                já foi enviadoobrigado pela atenção       neg
# 651   mandei direct pra vocês me da essa força gale...       pos
# 652                       isso n é coisa de millenium        pos
# 653  oooohhhh  ta difícil hein não tem extrato da c...       pos
# 654              só o  pra fazer uma fofura dessas lt3       pos
# 655       nubank e digio são os melhores dessas opções       pos
# 656  desisto obg  pelos 30 mun mais bem gastos da m...       pos
# 657    já estou há 10 min na ligação ouvindo musiqu...       neg
# 658   eu só queria fechar minha conta e não pagar o...       pos
# 659  seria bom se o  aceitasse depósito imediato no...       pos
# 660                                ok obrigadochamarei       pos
# 661                                                sim       neg
# 662   desculpa minha ignorância mas não sei do que ...       neg
# 663                                              dm 😡🤬       neg
# 664  rt  digital bank  owned by brazilian banking g...       pos
# 665                           vejam minha dm por favor       neg
# 666  o meu limite no  sumiu após 3 dias de conta pa...       pos
# 667  rt  next tem conta  cartão de crédito grátis e...       pos
# 668  rt  digital bank  owned by brazilian banking g...       pos
# 669  rt  digital bank  owned by brazilian banking g...       pos
# 670   queria fazer portabilidade do meu salário pro...       neg
# 671   e ainda ganha uma carteirinha de papel que nã...       pos
#
# [672 rows x 2 columns]

# %% [markdown]
# *Counting positives and negatives*

# %%
df = data.groupby('sentiment').count()
df
# Out:
#            text
# sentiment
# neg         218
# pos         454

# %% [markdown]
# *Sentimental Analysis Graph based on Naive-Bayes Classification*

# %%
plt.style.use('seaborn')
pie_pos = df.loc['pos']
pie_neg = df.loc['neg']
fig = plt.figure()

slices = [pie_neg, pie_pos]
tweets = ['Negative', 'Positive']
columns = ['Red', 'Green']

plt.title('Tweets sentimental analysis')
 
plt.pie(slices, labels = tweets, colors = columns, startangle = 90, shadow = True, explode = (0.1, 0), autopct='%1.0f%%')

plt.show()

# %%
# Save graph into a file
fig.savefig("tweets_sentimental_analysis.png")

# %% [markdown]
# *Positive WordCloud*

# %%
# filtrar dataframe com tweets positivos
data_pos_filtered = data[data['sentiment'] == 'pos']

# %%
# WordCloud
plt.style.use('seaborn')
data_pos_filtered = " ".join(tweet for tweet in data_pos_filtered['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user_pos.png")
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Positive Tweets WordCloud')
# Out:
# Text(0.5,1,'Positive Tweets WordCloud')

# %% [markdown]
# *Top 10 most used words in positive tweets*

# %%
count_pos = sorted(word_count(data_pos_filtered).items(), key = itemgetter(1), reverse = True)
wordcount_pos = pd.DataFrame(count_pos, columns=['word', 'counts'])
top10_pos = wordcount_pos[:10]
top10_pos
# Out:
#           word  counts
# 0       cartão      73
# 1        conta      47
# 2         next      40
# 3          app      31
# 4      crédito      23
# 5        banco      22
# 6  atendimento      21
# 7        ainda      20
# 8          dia      19
# 9     desconto      17

# %%
# Dataset
plt.style.use('seaborn')
height = top10_pos.counts
bars = top10_pos.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words in positive tweets')
 
# Show graphic
plt.show()

# %%
# Save graph into a file
fig.savefig("most_used_positive_words.png")

# %% [markdown]
# *Negative WordCloud*

# %%
# filtrar dataframe com tweets positivos
data_neg_filtered = data[data['sentiment'] == 'neg']
data_neg_filtered
# Out:
#                                                   text sentiment
# 4     minha fatura do cartao vence hoje agendei o p...       neg
# 5                                     tá fazendo feio        neg
# 11    boa tarde já faz quase 5 dias que efetuei o c...       neg
# 12          estou com duvidas com os serviços de conta       neg
# 17    o atendimento pelo aplicativo é muito ruim qu...       neg
# 18   no silencio da noite fico imaginando o quanto ...       neg
# 19    na opção de recarga de celular podia ter a op...       neg
# 21                                 alo  da uma atenção       neg
# 30                      mtv world stage pq me matastes       neg
# 35    fico feliz que estajam trabalhando nessas mel...       neg
# 37         vão ignorar um cliente de vocês serio isso        neg
# 39                                  hahahhahahahahahha       neg
# 47                   eu envio e vocês não me respondem       neg
# 50    eles roubam seu salário não consegue nem tran...       neg
# 52     e a segunda via que vc nao consegue pedir de...       neg
# 55                        pior conta digital não façam       neg
# 62     vezes não dá para fazer compra com cartão dé...       neg
# 68      acabei de ter um encontro com a gata obrigadoo       neg
# 73                                             olha dm       neg
# 76                puta falta de sacanagem desses caras       neg
# 77            vocês bem que podiam entregar meu cartão       neg
# 79    vocês tem support pro   to fazendo minha migr...       neg
# 84   ei   precisamos bater um papo porém não tô con...       neg
# 85    ainda não liguei hoje também e não me atender...       neg
# 86                                      só fica assim        neg
# 92                                        misericórdia       neg
# 98    belê liberem logo porque é muito pratico usar...       neg
# 104   a 2 meses atrás eu precisava do cartão para u...       neg
# 108                              eu tenho os dois kkkk       neg
# 109                                      nem te aceita       neg
# ..                                                 ...       ...
# 597                                        ata entendi       neg
# 598   o app de vocês tá bugado viu onde se pede ext...       neg
# 599                         o problema foi solucionado       neg
# 600                         o problema foi solucionado       neg
# 601                         o problema foi solucionado       neg
# 603   o cartão next tem possibilidade de gerar cart...       neg
# 606   finalmente tive o crédito aprovado mas tenho ...       neg
# 608   e  ambas empresas do grupo  dão show de preca...       neg
# 610   ô next agora até o cupom do ifood vocês remov...       neg
# 611   então achei um banco que me satisfaz melhor v...       neg
# 613              chamo lá e ninguém responde nem a bia       neg
# 620                               banco lixo do caraio       neg
# 621   eita atendimento ruim o chat continua horríve...       neg
# 624   o app sempre da erroou a sessão expira do nad...       neg
# 626  ei  estou com sérios problemas com o meu cartã...       neg
# 628   péssimo atendimento estou suplicando pra canc...       neg
# 629   péssimo atendimento estou suplicando pra canc...       neg
# 630   péssimo atendimento estou suplicando pra canc...       neg
# 631  eu amo meu banco  mas é dificil o contato por ...       neg
# 642                                         ajuda euuu       neg
# 644  gente o  é horrível aplicativo ruim horas pra ...       neg
# 645   qual a mensagem de halloween chegou a notific...       neg
# 649   quais os perks de trazer o salário pro next s...       neg
# 650                já foi enviadoobrigado pela atenção       neg
# 657    já estou há 10 min na ligação ouvindo musiqu...       neg
# 661                                                sim       neg
# 662   desculpa minha ignorância mas não sei do que ...       neg
# 663                                              dm 😡🤬       neg
# 665                           vejam minha dm por favor       neg
# 670   queria fazer portabilidade do meu salário pro...       neg
#
# [218 rows x 2 columns]

# %%
# WordCloud
plt.style.use('seaborn')
data_neg_filtered = " ".join(tweet for tweet in data_neg_filtered['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user_neg.png")
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Negative Tweets WordCloud')
# Out:
# Text(0.5,1,'Negative Tweets WordCloud')

# %% [markdown]
# *Top 10 most used words in negative tweets*

# %%
count_neg = sorted(word_count(data_neg_filtered).items(), key = itemgetter(1), reverse = True)
wordcount_neg = pd.DataFrame(count_neg, columns=['word', 'counts'])
top10_neg = wordcount_neg[:10]
top10_neg
# Out:
#           word  counts
# 0       cartão      36
# 1         next      20
# 2        conta      19
# 3  atendimento      14
# 4     cancelar      12
# 5        banco      12
# 6       fatura       9
# 7        ainda       9
# 8          ter       9
# 9     tentando       9

# %%
# Dataset
plt.style.use('seaborn')
height = top10_neg.counts
bars = top10_neg.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words in negative tweets')
 
# Show graphic
plt.show()

# %%
# Save into a file
fig.savefig("most_used_negative_words.png")
