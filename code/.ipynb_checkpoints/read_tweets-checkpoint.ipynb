# %% [markdown]
# *Import library's*

# %%
import numpy as np
import pandas as pd
from textblob import TextBlob as tb
import tweepy
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from textblob.classifiers import NaiveBayesClassifier
import os, re, nltk, string
from bs4 import BeautifulSoup
from collections import OrderedDict
from operator import itemgetter

# %% [markdown]
# *Twitter authentication*

# %%
consumer_key = 'Jg95VukOglg6RIqRrqt6GYRoa'
consumer_secret = 'ZvH3Oz7jFN0OvDMXGtRriTqOOykGnUgqxAU0wNKWhMElII0ivq'
access_token = '971179238396227584-KkOSGzCwhzv0lokz55Dkp1wTjyurnkW'
access_token_secret = 'y2NNUWU1tlhQYMOps49aSKgckRqTu7T7dPWpyNbMeXvAA'

# %%
def get_all_tweets(screen_name):
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth)
    alltweets = []
    new_tweets = api.search(screen_name)
    alltweets.extend(new_tweets)
    oldest = alltweets[-1].id - 1
    while len(new_tweets) > 0:
        new_tweets = api.search(screen_name, count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest = alltweets[-1].id - 1
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
    return outtweets

# %% [markdown]
# *Get all tweets*

# %%
public_tweets = get_all_tweets('@falanext')
df = pd.DataFrame(public_tweets, columns=['id','created_at','text'])
df
# Out:
#                       id          created_at  \
# 0    1061687810036502528 2018-11-11 18:31:13
# 1    1061681021782056961 2018-11-11 18:04:15
# 2    1061680126667165696 2018-11-11 18:00:41
# 3    1061678190790356992 2018-11-11 17:53:00
# 4    1061674730829291520 2018-11-11 17:39:15
# 5    1061672129337401346 2018-11-11 17:28:55
# 6    1061659780127842304 2018-11-11 16:39:50
# 7    1061647643561078786 2018-11-11 15:51:37
# 8    1061645332084416513 2018-11-11 15:42:26
# 9    1061622875055112197 2018-11-11 14:13:12
# 10   1061620948334505985 2018-11-11 14:05:32
# 11   1061620872836976640 2018-11-11 14:05:14
# 12   1061620275580682241 2018-11-11 14:02:52
# 13   1061620017433899008 2018-11-11 14:01:50
# 14   1061618073973727232 2018-11-11 13:54:07
# 15   1061612090211885057 2018-11-11 13:30:20
# 16   1061608214264008704 2018-11-11 13:14:56
# 17   1061599583652982786 2018-11-11 12:40:38
# 18   1061599343386464256 2018-11-11 12:39:41
# 19   1061598920311226369 2018-11-11 12:38:00
# 20   1061561599520071680 2018-11-11 10:09:42
# 21   1061554201069842432 2018-11-11 09:40:18
# 22   1061515087947685888 2018-11-11 07:04:53
# 23   1061502427675979782 2018-11-11 06:14:35
# 24   1061482544103940096 2018-11-11 04:55:34
# 25   1061473152067424256 2018-11-11 04:18:15
# 26   1061457120145666048 2018-11-11 03:14:33
# 27   1061453786525454338 2018-11-11 03:01:18
# 28   1061453512725487616 2018-11-11 03:00:12
# 29   1061452717229514752 2018-11-11 02:57:03
# ..                   ...                 ...
# 629  1058074378116698119 2018-11-01 19:12:44
# 630  1058074249947213827 2018-11-01 19:12:13
# 631  1058073509203714048 2018-11-01 19:09:17
# 632  1058071031255105538 2018-11-01 18:59:26
# 633  1058063518551957510 2018-11-01 18:29:35
# 634  1058063469994491905 2018-11-01 18:29:23
# 635  1058063315031769089 2018-11-01 18:28:46
# 636  1058057420658954240 2018-11-01 18:05:21
# 637  1058056787700662272 2018-11-01 18:02:50
# 638  1058055909786705921 2018-11-01 17:59:21
# 639  1058054420779466752 2018-11-01 17:53:26
# 640  1058053488553480199 2018-11-01 17:49:44
# 641  1058052142416707584 2018-11-01 17:44:23
# 642  1058039884735307776 2018-11-01 16:55:40
# 643  1058039157124149254 2018-11-01 16:52:47
# 644  1058038717288497152 2018-11-01 16:51:02
# 645  1058038400224296960 2018-11-01 16:49:46
# 646  1058030729416900608 2018-11-01 16:19:17
# 647  1058026076142821378 2018-11-01 16:00:48
# 648  1058024938060300288 2018-11-01 15:56:17
# 649  1058024183718952960 2018-11-01 15:53:17
# 650  1058023858165506048 2018-11-01 15:51:59
# 651  1058021270292447233 2018-11-01 15:41:42
# 652  1058020876044656640 2018-11-01 15:40:08
# 653  1058017967269666817 2018-11-01 15:28:35
# 654  1058017244050087936 2018-11-01 15:25:42
# 655  1058015604928667649 2018-11-01 15:19:11
# 656  1058010888534478848 2018-11-01 15:00:27
# 657  1058010191176839168 2018-11-01 14:57:41
# 658  1057994609299742720 2018-11-01 13:55:46
#
#                                                   text
# 0    b'@falanext S\xc3\xb3 que eu tenho que pagar 9...
# 1                         b'@falanext me deixa em paz'
# 2    b'\xc3\x89 inacredit\xc3\xa1vel essa cultura d...
# 3                 b'@falanext Li e respondi. Obrigada'
# 4                       b'@falanext Ontem mesmo kkkkk'
# 5    b'@falanext boa tarde. Tem como me enviarem o ...
# 6                 b'@lombardiw @falanext me patrocina'
# 7    b'@falanext demora assim mesmo pra abrir a con...
# 8    b'banco @falanext quantas horas tenho que fica...
# 9    b'@Uber_Brasil @falanext Ol\xc3\xa1. Est\xc3\x...
# 10   b'@imaginemarcos @falanext Se eu n\xc3\xa3o co...
# 11   b'@imaginemarcos @falanext Sim! Amanh\xc3\xa3 ...
# 12   b'@imaginemarcos @falanext Eles me liberaram 6...
# 13   b'@falanext manda minha fatura logo pelo amor ...
# 14   b'@falanext N\xc3\xa3o precisa eu t\xc3\xa1 em...
# 15   b'@falanext Poxa, ent\xc3\xa3o vou ficar sem m...
# 16   b'@falanext @whoisraphss Pode sim. Fui desbloq...
# 17   b'@mmacedo94 @falanext Fim de semana o atendim...
# 18   b'@DrMateusCaldas @falanext Obrigado. T\xc3\xa...
# 19          b'@mmacedo94 @falanext S\xc3\xb3 segunda!'
# 20   b'O @falanext parece um bom banco mas o atendi...
# 21   b'@falanext @DrMateusCaldas O meu venceu ontem...
# 22   b'RT @falanext: next tem conta + cart\xc3\xa3o...
# 23   b'T\xc3\xb4 doido que meu cart\xc3\xa3o @falan...
# 24   b'@falanext e @iFood foi a melhor parceria do ...
# 25   b'@falanext Oi Pederia min informa sobre o eu ...
# 26   b'@giuliasntana @amysantiags @falanext Voc\xc3...
# 27   b'@amysantiags @falanext hauahauaah eu literal...
# 28   b'@giuliasntana @falanext HAUAHUAUAUAUUA \xc3\...
# 29   b'@falanext @amysantiags EU DEI UM GRITO\nNext...
# ..                                                 ...
# 629  b'@falanext Faz uns mimos pra gente de baixa r...
# 630  b'Nunca fa\xc3\xa7am este cart\xc3\xa3o @falan...
# 631                         b'@falanext Ata, entendi.'
# 632  b'@falanext o app de voc\xc3\xaas t\xc3\xa1 bu...
# 633            b'@falanext O problema foi solucionado'
# 634            b'@falanext O problema foi solucionado'
# 635            b'@falanext O problema foi solucionado'
# 636  b'@falanext me respondam pelo amor de Deus eu ...
# 637  b'@falanext o cart\xc3\xa3o next tem possibili...
# 638                   b'@falanext E nada de Apple pay'
# 639  b'@falanext ja faz 2 dias que tento entrar em ...
# 640  b'@falanext Finalmente tive o cr\xc3\xa9dito a...
# 641                      b'@falanext Chamei l\xc3\xa1'
# 642  b'@falanext e @meudigio ambas empresas do Grup...
# 643  b'@konther @falanext O nextifood10 n ta funcio...
# 644  b'@falanext \xc3\xb4 Next, agora at\xc3\xa9 o ...
# 645  b'@falanext Ent\xc3\xa3o, achei um banco que m...
# 646  b'@falanext j\xc3\xa1 desbloqueei meu cart\xc3...
# 647  b'@falanext Chamo l\xc3\xa1 e ningu\xc3\xa9m r...
# 648  b'@falanext n\xc3\xa3o me ignora n\xc3\xa3o p\...
# 649  b'Ol\xc3\xa1 @falanext como faz para cancelar ...
# 650  b'@falanext Ol\xc3\xa1, meu cart\xc3\xa3o \xc3...
# 651                  b'@isaluanaq @falanext Fala memo'
# 652  b'@falanext Essa \xc3\xa9 a mesma Next do Stev...
# 653        b'@falanext o chat est\xc3\xa1 fora do ar?'
# 654       b'@isaluanaq @falanext banco lixo do caraio'
# 655  b'@falanext Eita atendimento ruim. O chat cont...
# 656  b'esse @falanext ta me tirando\npior atendimen...
# 657  b'RT @falanext: J\xc3\xa1 pode come\xc3\xa7ar ...
# 658  b'@falanext O App sempre da erro,ou a sess\xc3...
#
# [659 rows x 3 columns]

# %% [markdown]
# *Data Cleaning*

# %%
def cleanTweets(tweetsDF):
    table = str.maketrans(dict.fromkeys(string.punctuation.replace('@','')))
    # essa regex significa:
    # tudo que conter @ OU http OU terminador de linha seguido de uma palavra OU um espaco OU qualquer outro terminador
    # de linha.
    rePattern1 = '(@|http|\\n)(\w+|\s|\S)'
    formattedTweets = []
    for line in tweetsDF['text']:
        formattedStr = line.decode('utf-8').lower()
        formattedStr = formattedStr.translate(table)
        formattedStr = re.sub(rePattern1, "", formattedStr)  
        formattedTweets.append(formattedStr)
    return formattedTweets

formattedTweets = cleanTweets(df)
data = pd.DataFrame(formattedTweets, columns=['text'])
data
# Out:
#                                                   text
# 0     só que eu tenho que pagar 995 por mês pra ter...
# 1                                      me deixa em paz
# 2    é inacreditável essa cultura de retargeting do...
# 3                               li e respondi obrigada
# 4                                    ontem mesmo kkkkk
# 5     boa tarde tem como me enviarem o código de ra...
# 6                                         me patrocina
# 7                 demora assim mesmo pra abrir a conta
# 8    banco  quantas horas tenho que ficar no telefo...
# 9      olá está ocorrendo isso quando tento inserir...
# 10     se eu não conseguir ver o sam smith por caus...
# 11     sim amanhã vou ligar lá pra pedir pra eles l...
# 12     eles me liberaram 600 e o ingresso do lolla ...
# 13    manda minha fatura logo pelo amor de deus qro...
# 14    não precisa eu tá em casa pra assinar né  pod...
# 15    poxa então vou ficar sem meu ingresso para o ...
# 16     pode sim fui desbloquear meu cartão e aparec...
# 17     fim de semana o atendimento é pequeno igual ...
# 18     obrigado tá melhor que a central do next que...
# 19                                          só segunda
# 20   o  parece um bom banco mas o atendimento por c...
# 21     o meu venceu ontem tinha saldo e ainda não f...
# 22   rt  next tem conta  cartão de crédito grátis e...
# 23   tô doido que meu cartão  chega logo não vejo a...
# 24    e  foi a melhor parceria do ano amando meus m...
# 25    oi pederia min informa sobre o eu cartão q nu...
# 26      você recomenda o next mesmo parece bem atra...
# 27     hauahauaah eu literalmente ligo pro 0800 pra...
# 28                              hauahuauauauua é isso
# 29     eu dei um grito eu amo vocês mas se vocês se...
# ..                                                 ...
# 629   faz uns mimos pra gente de baixa renda pôsou ...
# 630  nunca façam este cartão   péssimo atendimento ...
# 631                                        ata entendi
# 632   o app de vocês tá bugado viu onde se pede ext...
# 633                         o problema foi solucionado
# 634                         o problema foi solucionado
# 635                         o problema foi solucionado
# 636   me respondam pelo amor de deus eu preciso pag...
# 637   o cartão next tem possibilidade de gerar cart...
# 638                                e nada de apple pay
# 639   ja faz 2 dias que tento entrar em contato com...
# 640   finalmente tive o crédito aprovado mas tenho ...
# 641                                          chamei lá
# 642   e  ambas empresas do grupo  dão show de preca...
# 643               o nextifood10 n ta funcionando mais
# 644   ô next agora até o cupom do ifood vocês remov...
# 645   então achei um banco que me satisfaz melhor v...
# 646   já desbloqueei meu cartão e gostaria de saber...
# 647              chamo lá e ninguém responde nem a bia
# 648                               não me ignora não pô
# 649               olá  como faz para cancelar o cartão
# 650   olá meu cartão é somente débito cadestrei ele...
# 651                                          fala memo
# 652                  essa é a mesma next do steve jobs
# 653                             o chat está fora do ar
# 654                               banco lixo do caraio
# 655   eita atendimento ruim o chat continua horríve...
# 656  esse  ta me tirando atendimento do universo ng...
# 657  rt  já pode começar a fazer os planos pra abri...
# 658   o app sempre da erroou a sessão expira do nad...
#
# [659 rows x 1 columns]

# %% [markdown]
# *Stopwords in portuguese*

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')
# Inclusão de novas stopwords 
stopwords.append('tô')
stopwords.append('tá')
stopwords.append('pra')
stopwords.append('pro')
stopwords.append('é')
stopwords.append('aí')
stopwords.append('ser')
stopwords.append('pq')
stopwords.append('já')
stopwords.append('nao')
stopwords.append('rt')
stopwords.append('porque')
stopwords.append('vai')
stopwords.append('vou')
stopwords.append('faço')
stopwords.append('dm')
stopwords.append('q')

# %% [markdown]
# *WordCloud*

# %%
text = " ".join(tweet for tweet in data['text'])
plt.style.use('seaborn')
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user.png")
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Tweets WordCloud')
# Out:
# Text(0.5,1,'Tweets WordCloud')

# %% [markdown]
# *Basic statistics about the data*

# %%
def word_count(str):
    counts = OrderedDict()
    words = str.split()
    for word in words:
        if word not in stopwords:
            if word in counts:
                counts[word] += 1
            else:
                counts[word] = 1
    return counts

print("There are {} words in the combination of all tweets.".format(len(text)))

counts = sorted(word_count(text).items(), key = itemgetter(1), reverse = True)
display(counts[:10])
# Out:
# There are 43392 words in the combination of all tweets.
# [('cartão', 110),
#  ('conta', 62),
#  ('next', 62),
#  ('app', 38),
#  ('banco', 36),
#  ('atendimento', 34),
#  ('crédito', 31),
#  ('ainda', 27),
#  ('chat', 25),
#  ('nada', 24)]

# %% [markdown]
# *Transform occurrences in a dataframe*

# %%
wordcount = pd.DataFrame(counts, columns=['word', 'counts'])
top10 = wordcount[:10]
top10
# Out:
#           word  counts
# 0       cartão     110
# 1        conta      62
# 2         next      62
# 3          app      38
# 4        banco      36
# 5  atendimento      34
# 6      crédito      31
# 7        ainda      27
# 8         chat      25
# 9         nada      24

# %% [markdown]
# *Top 10 most used words*

# %%
# Dataset
plt.style.use('seaborn')
height = top10.counts
bars = top10.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words')
 
# Show graphic
plt.show()

# %%
# Save graph into a file
fig.savefig('most_used_words.png', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# *ReLi Lexicon - portuguese sentimental analysis*

# %%
base_path = '/Users/gayr/documents/gabriela/mba/tcc/ReLi-Lex'
allData = []
files = [os.path.join(base_path, f) for f in os.listdir(base_path)]
for file in files:
    t = 'pos' if '_Positivos' in file else 'neg'
    with open(file, 'r', encoding = 'latin-1') as content_file:
        content = content_file.read()
        all = re.findall('\[.*?\]',content)
        for w in all:
            allData.append((w[1:-1], t))
allDataDF = pd.DataFrame(allData, columns=['word', 'sentiment'])
allDataDF
# Out:
#                 word sentiment
# 0        aborrecente       neg
# 1         anacrônico       neg
# 2          arrombado       neg
# 3              besta       neg
# 4            bizarro       neg
# 5               bobo       neg
# 6              burro       neg
# 7          cansativo       neg
# 8              chato       neg
# 9           chocante       neg
# 10             chulo       neg
# 11            clichê       neg
# 12           confuso       neg
# 13     decepcionante       neg
# 14        defeituoso       neg
# 15        deplorável       neg
# 16        depressivo       neg
# 17        deprimente       neg
# 18      desagradável       neg
# 19         desconexo       neg
# 20       desgastante       neg
# 21   desinteressante       neg
# 22     desnecessário       neg
# 23       desprezível       neg
# 24           difícil       neg
# 25       dispensável       neg
# 26           doentio       neg
# 27           egoísta       neg
# 28         enfadonho       neg
# 29           enjoado       neg
# ..               ...       ...
# 580      destacar-se       pos
# 581         divertir       pos
# 582        emocionar       pos
# 583         emplacar       pos
# 584         empolgar       pos
# 585         encantar       pos
# 586       enternecer       pos
# 587         entreter       pos
# 588        facilitar       pos
# 589         fascinar       pos
# 590            fluir       pos
# 591           gostar       pos
# 592      identificar       pos
# 593     impressionar       pos
# 594           inovar       pos
# 595       recomendar       pos
# 596     sensibilizar       pos
# 597       simpatizar       pos
# 598        valorizar       pos
# 599           vibrar       pos
# 600           viciar       pos
# 601         apavorar       pos
# 602          brilhar       pos
# 603          comover       pos
# 604          devorar       pos
# 605          prender       pos
# 606              rir       pos
# 607         saborear       pos
# 608      surpreender       pos
# 609            tocar       pos
#
# [610 rows x 2 columns]

# %% [markdown]
# *Validate the model and avoid overfit*

# %% [markdown]
# Functions

# %%
# Split arrays or matrices into random train and test subsets
from sklearn.model_selection import train_test_split
# A random forest classifier
from sklearn.ensemble import RandomForestClassifier
# A naive bayes classifier
from sklearn.naive_bayes import MultinomialNB
# A boosting classifier
from sklearn.ensemble import AdaBoostClassifier
# Encode labels with value between 0 and n_classes-1
from sklearn.preprocessing import LabelEncoder
# Accuracy classification score
from sklearn.metrics import accuracy_score
# This classifier is useful as a simple baseline to compare with other (real) classifiers
from sklearn.dummy import DummyClassifier
# Out:
# C:\Users\GAYR\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# Original Variables

# %%
X_original = allDataDF.word
Y_original = allDataDF.sentiment

# %% [markdown]
# O sklearn precisa que as variáveis independentes sejam contínuas - por esse motivo precisaremos transformar palavras em números

# %%
le_x = LabelEncoder()
X_labelEncoded = le_x.fit_transform(X_original)
le_y = LabelEncoder()
Y_labelEncoded = le_y.fit_transform(Y_original)

# %%
zippedEncoded = list(zip(X_labelEncoded, Y_labelEncoded))
dfEncoded = pd.DataFrame(zippedEncoded, columns = ['word', 'sentiment'])

# %% [markdown]
# Cross Validation - Divisão da amostra entre treino e teste - scikitlearn

# %%
X_labelEncodedDF = dfEncoded.word
Y_labelEncodedDF = dfEncoded.sentiment
X_train, X_test, y_train, y_test = train_test_split(X_labelEncodedDF, Y_labelEncodedDF, test_size=0.30, random_state = 13)

# %% [markdown]
# *Classification Models*

# %% [markdown]
# Random Forest Classifier

# %%
rf = RandomForestClassifier(n_estimators = 100)
rf.fit(X_train.values.reshape(-1, 1), y_train)
y_pred = rf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Naive Bayes Classifier

# %%
nb = MultinomialNB()
nb.fit(X_train.values.reshape(-1, 1), y_train)
y_nb_pred = nb.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Boosting Classifier

# %%
clf = AdaBoostClassifier(n_estimators=100)
clf.fit(X_train.values.reshape(-1, 1), y_train)
y_clf_pred = clf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Dummy Model

# %%
dm = DummyClassifier()
dm.fit(X_train.values.reshape(-1, 1), y_train)
y_dummy_pred = dm.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# *Model´s Accuracy*

# %%
print('Accuracy random forest on test dataset: {}'.format(round(accuracy_score(y_test, y_pred), 2)))
print('Accuracy naive bayes on test dataset: {}'.format(round(accuracy_score(y_test, y_nb_pred), 2)))
print('Accuracy boosting on test dataset: {}'.format(round(accuracy_score(y_test, y_clf_pred), 2)))
print('Accuracy dummy model on test dataset: {}'.format(round(accuracy_score(y_test, y_dummy_pred), 2)))
# Out:
# Accuracy random forest on test dataset: 0.7
# Accuracy naive bayes on test dataset: 0.63
# Accuracy boosting on test dataset: 0.66
# Accuracy dummy model on test dataset: 0.52

# %% [markdown]
# A seguir, iremos utilizar o algoritmo para classificação Random Forest para a análise de sentimentos, devido ao melhor nível de acurácia apresentado.

# %%
# tweetsDataLabelEncoder = LabelEncoder()
tweet_text = data.text
tweetsEncoded = le_x.fit_transform(tweet_text)
y_pred_total = rf.predict(tweetsEncoded.reshape(-1, 1))
y_pred_total_decoded = le_y.inverse_transform(y_pred_total)
data['sentiment'] = y_pred_total_decoded
data
# Out:
# C:\Users\GAYR\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#                                                   text sentiment
# 0     só que eu tenho que pagar 995 por mês pra ter...       neg
# 1                                      me deixa em paz       pos
# 2    é inacreditável essa cultura de retargeting do...       pos
# 3                               li e respondi obrigada       pos
# 4                                    ontem mesmo kkkkk       pos
# 5     boa tarde tem como me enviarem o código de ra...       neg
# 6                                         me patrocina       pos
# 7                 demora assim mesmo pra abrir a conta       pos
# 8    banco  quantas horas tenho que ficar no telefo...       pos
# 9      olá está ocorrendo isso quando tento inserir...       neg
# 10     se eu não conseguir ver o sam smith por caus...       neg
# 11     sim amanhã vou ligar lá pra pedir pra eles l...       pos
# 12     eles me liberaram 600 e o ingresso do lolla ...       neg
# 13    manda minha fatura logo pelo amor de deus qro...       pos
# 14    não precisa eu tá em casa pra assinar né  pod...       pos
# 15    poxa então vou ficar sem meu ingresso para o ...       neg
# 16     pode sim fui desbloquear meu cartão e aparec...       pos
# 17     fim de semana o atendimento é pequeno igual ...       pos
# 18     obrigado tá melhor que a central do next que...       neg
# 19                                          só segunda       pos
# 20   o  parece um bom banco mas o atendimento por c...       pos
# 21     o meu venceu ontem tinha saldo e ainda não f...       pos
# 22   rt  next tem conta  cartão de crédito grátis e...       pos
# 23   tô doido que meu cartão  chega logo não vejo a...       pos
# 24    e  foi a melhor parceria do ano amando meus m...       neg
# 25    oi pederia min informa sobre o eu cartão q nu...       pos
# 26      você recomenda o next mesmo parece bem atra...       pos
# 27     hauahauaah eu literalmente ligo pro 0800 pra...       pos
# 28                              hauahuauauauua é isso        pos
# 29     eu dei um grito eu amo vocês mas se vocês se...       pos
# ..                                                 ...       ...
# 629   faz uns mimos pra gente de baixa renda pôsou ...       pos
# 630  nunca façam este cartão   péssimo atendimento ...       pos
# 631                                        ata entendi       pos
# 632   o app de vocês tá bugado viu onde se pede ext...       pos
# 633                         o problema foi solucionado       pos
# 634                         o problema foi solucionado       pos
# 635                         o problema foi solucionado       pos
# 636   me respondam pelo amor de deus eu preciso pag...       neg
# 637   o cartão next tem possibilidade de gerar cart...       pos
# 638                                e nada de apple pay       pos
# 639   ja faz 2 dias que tento entrar em contato com...       pos
# 640   finalmente tive o crédito aprovado mas tenho ...       pos
# 641                                          chamei lá       pos
# 642   e  ambas empresas do grupo  dão show de preca...       neg
# 643               o nextifood10 n ta funcionando mais        neg
# 644   ô next agora até o cupom do ifood vocês remov...       neg
# 645   então achei um banco que me satisfaz melhor v...       neg
# 646   já desbloqueei meu cartão e gostaria de saber...       neg
# 647              chamo lá e ninguém responde nem a bia       pos
# 648                               não me ignora não pô       neg
# 649               olá  como faz para cancelar o cartão       pos
# 650   olá meu cartão é somente débito cadestrei ele...       pos
# 651                                          fala memo       pos
# 652                  essa é a mesma next do steve jobs       neg
# 653                             o chat está fora do ar       pos
# 654                               banco lixo do caraio       neg
# 655   eita atendimento ruim o chat continua horríve...       pos
# 656  esse  ta me tirando atendimento do universo ng...       pos
# 657  rt  já pode começar a fazer os planos pra abri...       pos
# 658   o app sempre da erroou a sessão expira do nad...       neg
#
# [659 rows x 2 columns]

# %% [markdown]
# *Counting positives and negatives*

# %%
df = data.groupby('sentiment').count()
df
# Out:
#            text
# sentiment
# neg         212
# pos         447

# %% [markdown]
# *Sentimental Analysis Graph based on Naive-Bayes Classification*

# %%
plt.style.use('seaborn')
pie_pos = df.loc['pos']
pie_neg = df.loc['neg']
fig = plt.figure()

slices = [pie_neg, pie_pos]
tweets = ['Negative', 'Positive']
columns = ['Red', 'Green']

plt.title('Tweets sentimental analysis')
 
plt.pie(slices, labels = tweets, colors = columns, startangle = 90, shadow = True, explode = (0.1, 0), autopct='%1.0f%%')

plt.show()

# %%
# Save graph into a file
fig.savefig("tweets_sentimental_analysis.png")

# %% [markdown]
# *Positive WordCloud*

# %%
# filtrar dataframe com tweets positivos
data_pos_filtered = data[data['sentiment'] == 'pos']

# %%
# WordCloud
plt.style.use('seaborn')
data_pos_filtered = " ".join(tweet for tweet in data_pos_filtered['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user_pos.png")
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Positive Tweets WordCloud')
# Out:
# Text(0.5,1,'Positive Tweets WordCloud')

# %% [markdown]
# *Top 10 most used words in positive tweets*

# %%
count_pos = sorted(word_count(data_pos_filtered).items(), key = itemgetter(1), reverse = True)
wordcount_pos = pd.DataFrame(count_pos, columns=['word', 'counts'])
top10_pos = wordcount_pos[:10]
top10_pos
# Out:
#           word  counts
# 0       cartão      73
# 1         next      47
# 2        conta      44
# 3        banco      27
# 4          app      26
# 5  atendimento      23
# 6      crédito      23
# 7        ainda      19
# 8         nada      19
# 9         chat      17

# %%
# Dataset
plt.style.use('seaborn')
height = top10_pos.counts
bars = top10_pos.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words in positive tweets')
 
# Show graphic
plt.show()

# %%
# Save graph into a file
fig.savefig("most_used_positive_words.png")

# %% [markdown]
# *Negative WordCloud*

# %%
# filtrar dataframe com tweets positivos
data_neg_filtered = data[data['sentiment'] == 'neg']
data_neg_filtered
# Out:
#                                                   text sentiment
# 0     só que eu tenho que pagar 995 por mês pra ter...       neg
# 5     boa tarde tem como me enviarem o código de ra...       neg
# 9      olá está ocorrendo isso quando tento inserir...       neg
# 10     se eu não conseguir ver o sam smith por caus...       neg
# 12     eles me liberaram 600 e o ingresso do lolla ...       neg
# 15    poxa então vou ficar sem meu ingresso para o ...       neg
# 18     obrigado tá melhor que a central do next que...       neg
# 24    e  foi a melhor parceria do ano amando meus m...       neg
# 31          alou  aprova minha conta aí pra eu ir pro        neg
# 32    próxima semana ainda vocês me prometeram que ...       neg
# 38    oi como faço para aumentar o limite quero com...       neg
# 46                                                atoa       neg
# 49    o atendimento pelo aplicativo é muito ruim qu...       neg
# 54                                                  😈        neg
# 55    espero q sim estou sendo cobrada por tarifas ...       neg
# 56                               responde meu problema       neg
# 57   não tô conseguindo acessar minha conta do   er...       neg
# 65   alô  cadê meu limite de crédito que não libera...       neg
# 69         vão ignorar um cliente de vocês serio isso        neg
# 71                                  hahahhahahahahahha       neg
# 84     e a segunda via que vc nao consegue pedir de...       neg
# 92       eu só queria mudar minha senha do cartão poxa       neg
# 94     vezes não dá para fazer compra com cartão dé...       neg
# 96     absurdo cadê o respeito e a responsabilidade...       neg
# 98                                              bolado       neg
# 100     acabei de ter um encontro com a gata obrigadoo       neg
# 102  mais um dia de problema com o  segundo dia que...       neg
# 105                                            olha dm       neg
# 108               puta falta de sacanagem desses caras       neg
# 109           vocês bem que podiam entregar meu cartão       neg
# ..                                                 ...       ...
# 562                                      ariana feat         neg
# 568  pq to pensando seriamente cancelar o meu cartã...       neg
# 574   amanhã é dia de enem manda um voucher de desc...       neg
# 578  oficialmente desistindo do   não consegui entr...       neg
# 585   eu não uso o cartão next com outro objetivo a...       neg
# 589        seguros associados ao meu cartão de crédito       neg
# 591   pessoal eu amo vcs mas to precisando de uma a...       neg
# 592   queria diminuir umas parcelas de umas compras...       neg
# 595                                                  a       neg
# 597                     vou chamar na dm gente brigado       neg
# 598                                          valeu  ✌🏻       neg
# 605   aparentemente tem 30 dias pra cancelar defini...       neg
# 607                        como abro o chat pelo app         neg
# 608   boa noite quando abri minha conta no next não...       neg
# 617                             medo de quando começar       neg
# 618                          tô com ódio no coração já       neg
# 621                      sou mais o  responde por dm 😎       neg
# 625   mas no meu perfil já mostra que há cartão de ...       neg
# 626                          aguardando resposta na dm       neg
# 628   a minha intenção foi em fazer por causa do ca...       neg
# 636   me respondam pelo amor de deus eu preciso pag...       neg
# 642   e  ambas empresas do grupo  dão show de preca...       neg
# 643               o nextifood10 n ta funcionando mais        neg
# 644   ô next agora até o cupom do ifood vocês remov...       neg
# 645   então achei um banco que me satisfaz melhor v...       neg
# 646   já desbloqueei meu cartão e gostaria de saber...       neg
# 648                               não me ignora não pô       neg
# 652                  essa é a mesma next do steve jobs       neg
# 654                               banco lixo do caraio       neg
# 658   o app sempre da erroou a sessão expira do nad...       neg
#
# [212 rows x 2 columns]

# %%
# WordCloud
plt.style.use('seaborn')
data_neg_filtered = " ".join(tweet for tweet in data_neg_filtered['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user_neg.png")
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Negative Tweets WordCloud')
# Out:
# Text(0.5,1,'Negative Tweets WordCloud')

# %% [markdown]
# *Top 10 most used words in negative tweets*

# %%
count_neg = sorted(word_count(data_neg_filtered).items(), key = itemgetter(1), reverse = True)
wordcount_neg = pd.DataFrame(count_neg, columns=['word', 'counts'])
top10_neg = wordcount_neg[:10]
top10_neg
# Out:
#           word  counts
# 0       cartão      37
# 1        conta      18
# 2         next      15
# 3          app      12
# 4     cancelar      11
# 5  atendimento      11
# 6      preciso      11
# 7        ajuda      10
# 8        banco       9
# 9         hoje       9

# %%
# Dataset
plt.style.use('seaborn')
height = top10_neg.counts
bars = top10_neg.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words in negative tweets')
 
# Show graphic
plt.show()

# %%
# Save into a file
fig.savefig("most_used_negative_words.png")
