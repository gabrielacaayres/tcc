# %% [markdown]
# *Import library's*

# %%
import numpy as np
import pandas as pd
from textblob import TextBlob as tb
import tweepy
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from textblob.classifiers import NaiveBayesClassifier
import os, re, nltk, string
from bs4 import BeautifulSoup
from collections import OrderedDict
from operator import itemgetter

# %% [markdown]
# *Twitter authentication*

# %%
consumer_key = 'Jg95VukOglg6RIqRrqt6GYRoa'
consumer_secret = 'ZvH3Oz7jFN0OvDMXGtRriTqOOykGnUgqxAU0wNKWhMElII0ivq'
access_token = '971179238396227584-KkOSGzCwhzv0lokz55Dkp1wTjyurnkW'
access_token_secret = 'y2NNUWU1tlhQYMOps49aSKgckRqTu7T7dPWpyNbMeXvAA'

# %%
def get_all_tweets(screen_name):
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth)
    alltweets = []
    new_tweets = api.search(screen_name)
    alltweets.extend(new_tweets)
    oldest = alltweets[-1].id - 1
    while len(new_tweets) > 0:
        new_tweets = api.search(screen_name, count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest = alltweets[-1].id - 1
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
    return outtweets

# %% [markdown]
# *Get all tweets*

# %%
public_tweets = get_all_tweets('@falanext')
df = pd.DataFrame(public_tweets, columns=['id','created_at','text'])
df
# Out:
#                       id          created_at  \
# 0    1062175587790397446 2018-11-13 02:49:29
# 1    1062172325980897280 2018-11-13 02:36:31
# 2    1062168462804615169 2018-11-13 02:21:10
# 3    1062164858878287872 2018-11-13 02:06:51
# 4    1062164332149116928 2018-11-13 02:04:45
# 5    1062155276831330304 2018-11-13 01:28:46
# 6    1062154211440422913 2018-11-13 01:24:32
# 7    1062154193832689665 2018-11-13 01:24:28
# 8    1062154160760602624 2018-11-13 01:24:20
# 9    1062154116632399872 2018-11-13 01:24:09
# 10   1062154103302881280 2018-11-13 01:24:06
# 11   1062150008169000966 2018-11-13 01:07:50
# 12   1062147236044460032 2018-11-13 00:56:49
# 13   1062144012461793285 2018-11-13 00:44:00
# 14   1062138261215371264 2018-11-13 00:21:09
# 15   1062134426170245120 2018-11-13 00:05:55
# 16   1062127270213705728 2018-11-12 23:37:29
# 17   1062125812781105153 2018-11-12 23:31:41
# 18   1062125067830730757 2018-11-12 23:28:44
# 19   1062120697848365057 2018-11-12 23:11:22
# 20   1062118466868690944 2018-11-12 23:02:30
# 21   1062118076966232065 2018-11-12 23:00:57
# 22   1062116768137859073 2018-11-12 22:55:45
# 23   1062116407066968064 2018-11-12 22:54:19
# 24   1062115635172384768 2018-11-12 22:51:15
# 25   1062115257164984322 2018-11-12 22:49:45
# 26   1062115136641613825 2018-11-12 22:49:16
# 27   1062110564414038016 2018-11-12 22:31:06
# 28   1062103932107976705 2018-11-12 22:04:45
# 29   1062102483319832576 2018-11-12 21:58:59
# ..                   ...                 ...
# 679  1059065169349959680 2018-11-04 12:49:47
# 680  1059054183675060224 2018-11-04 12:06:08
# 681  1059046111464308738 2018-11-04 11:34:03
# 682  1058928973671997440 2018-11-04 03:48:35
# 683  1058809216566210560 2018-11-03 19:52:43
# 684  1058807411555909634 2018-11-03 19:45:33
# 685  1058807283654778882 2018-11-03 19:45:02
# 686  1058807147771953153 2018-11-03 19:44:30
# 687  1058807084874108929 2018-11-03 19:44:15
# 688  1058807010341408771 2018-11-03 19:43:57
# 689  1058806903646707712 2018-11-03 19:43:32
# 690  1058793967616253953 2018-11-03 18:52:07
# 691  1058774386625404930 2018-11-03 17:34:19
# 692  1058756847799283714 2018-11-03 16:24:37
# 693  1058741404225204224 2018-11-03 15:23:15
# 694  1058719964692168704 2018-11-03 13:58:04
# 695  1058716805882146816 2018-11-03 13:45:31
# 696  1058705545169920000 2018-11-03 13:00:46
# 697  1058702722533388288 2018-11-03 12:49:33
# 698  1058682277956337664 2018-11-03 11:28:19
# 699  1058677211564335105 2018-11-03 11:08:11
# 700  1058596391931523072 2018-11-03 05:47:02
# 701  1058518703220895744 2018-11-03 00:38:19
# 702  1058490294780526598 2018-11-02 22:45:26
# 703  1058487971010277377 2018-11-02 22:36:12
# 704  1058473562850447360 2018-11-02 21:38:57
# 705  1058446325212213249 2018-11-02 19:50:43
# 706  1058435045256507394 2018-11-02 19:05:54
# 707  1058417939299360768 2018-11-02 17:57:55
# 708  1058395614810124288 2018-11-02 16:29:13
#
#                                                   text
# 0    b'RT @falanext: J\xc3\xa1 pode come\xc3\xa7ar ...
# 1    b'@falanext Me refiro a transferir dinheiro pr...
# 2    b'@falanext J\xc3\xa1 paguei minha fatura faz ...
# 3    b'@falanext Depois de 1h30 no telefone, sim, c...
# 4    b'@falanext eu preciso entender o que acontece...
# 5    b'@falanext Mandei direct \xf0\x9f\x92\x95 obr...
# 6                             b'@falanext ???????????'
# 7             b'@falanext pode responder a dm????????'
# 8                            b'@falanext ????????????'
# 9                                    b'@falanext ????'
# 10                               b'@falanext ????????'
# 11   b'Agr sou a mulher mais feliz do mundo c cart\...
# 12   b'@falanext Fiz cancelamento nenhum t\xc3\xb4 ...
# 13   b'@falanext pode me tirar uma d\xc3\xbavida ma...
# 14   b'@falanext O cart\xc3\xa3o da minha esposa ai...
# 15   b'@falanext Quero fun\xc3\xa7\xc3\xa3o cr\xc3\...
# 16   b'@falanext Esta perguntando se eu tenho inter...
# 17   b'@falanext Oi! O que acontece \xc3\xa9: trans...
# 18   b'O @falanext bem que podia me ajudar nesse fe...
# 19   b'@falanext  sabe o que s\xc3\xa3o 12min esper...
# 20   b'@falanext eu s\xc3\xb3 queria que a central ...
# 21   b'41min aguardando no atendimento do @falanext...
# 22                              b'@falanext Obrigado.'
# 23   b'Minha fatura ainda n\xc3\xa3o foi debitado. ...
# 24   b'@falanext gente me da o m\xc3\xadnimo de ate...
# 25                     b'@falanext Vai cair 20 ou 22?'
# 26                b'@falanext https://t.co/lS2XtNtzfK'
# 27   b'@falanext Ser correntista NEXT \xc3\xa9 um d...
# 28   b'@falanext oi amadas tudo bem com vcs aqui n\...
# 29   b'@assiniwho @falanext Nao debitaram minha fat...
# ..                                                 ...
# 679                                b'@falanext Mandei'
# 680                      b'@falanext Faz um tempo....'
# 681   b'ariana feat @falanext https://t.co/ckJOYRQ248'
# 682  b'RT @falanext: next tem conta + cart\xc3\xa3o...
# 683  b'queria ser client do @falanext pra ter os 15...
# 684  b'vou marcar o @falanext  em tudo p ver se ele...
# 685  b'Se algu\xc3\xa9m me perguntar ou pedir indic...
# 686  b'Qualidade de atendimento ao cliente do @fala...
# 687  b'Pq to pensando seriamente cancelar o meu car...
# 688  b'Ligo, ligo no @falanext  e ningu\xc3\xa9m me...
# 689  b'Estava mega animado com o meu cart\xc3\xa3o ...
# 690  b'@falanext quando que o meu cart\xc3\xa3o vai...
# 691          b'@falanext eu ganhei 2 ingressos gratis'
# 692  b'@falanext Oi, enviei uma solicita\xc3\xa7\xc...
# 693  b'@falanext amanh\xc3\xa3 \xc3\xa9 dia de Enem...
# 694  b'@falanext o que est\xc3\xa1 acontecendo? Can...
# 695  b'RT @falanext: J\xc3\xa1 pode come\xc3\xa7ar ...
# 696  b'A @nubank q \xc3\xa9 o mais chatinho do role...
# 697  b'Oficialmente desistindo do @falanext , n\xc3...
# 698  b'@falanext j\xc3\xa1 fiquem ligados que hoje ...
# 699  b'@falanext Bom dia! perdi meu cart\xc3\xa3o e...
# 700             b'@falanext e o line? @LollapaloozaBr'
# 701  b'Assim que receber mensagem que o meu @falane...
# 702  b'@falanext exausta de tentar anexar a minha d...
# 703  b'@falanext Tudo bem ent\xc3\xa3o ficarei liga...
# 704  b'@falanext Eu n\xc3\xa3o uso o cart\xc3\xa3o ...
# 705  b'Se o @falanext n\xc3\xa3o me der limite inic...
# 706    b'@falanext Chamei, n\xc3\xa3o obtive resposta'
# 707            b'Alo @falanext me aceita logo caralho'
# 708  b'@falanext Fui ao caixa e o cart\xc3\xa3o de ...
#
# [709 rows x 3 columns]

# %% [markdown]
# *Data Cleaning*

# %%
def cleanTweets(tweetsDF):
    table = str.maketrans(dict.fromkeys(string.punctuation.replace('@','')))
    # essa regex significa:
    # tudo que conter @ OU http OU terminador de linha seguido de uma palavra OU um espaco OU qualquer outro terminador
    # de linha.
    rePattern1 = '(@|http|\\n)(\w+|\s|\S)'
    formattedTweets = []
    for line in tweetsDF['text']:
        formattedStr = line.decode('utf-8').lower()
        formattedStr = formattedStr.translate(table)
        formattedStr = re.sub(rePattern1, "", formattedStr)  
        formattedTweets.append(formattedStr)
    return formattedTweets

formattedTweets = cleanTweets(df)
data = pd.DataFrame(formattedTweets, columns=['text'])
data
# Out:
#                                                   text
# 0    rt  já pode começar a fazer os planos pra abri...
# 1     me refiro a transferir dinheiro pra minha con...
# 2     já paguei minha fatura faz uns 5 dias e nada ...
# 3              depois de 1h30 no telefone sim consegui
# 4     eu preciso entender o que aconteceu com a min...
# 5                mandei direct 💕 obrigado pela atenção
# 6
# 7                                  pode responder a dm
# 8
# 9
# 10
# 11   agr sou a mulher mais feliz do mundo c cartão ...
# 12    fiz cancelamento nenhum tô com cartão ativo t...
# 13               pode me tirar uma dúvida mandei na dm
# 14           o cartão da minha esposa ainda não chegou
# 15    quero função crédito todo mês deposito e uso ...
# 16    esta perguntando se eu tenho interesse em apl...
# 17    oi o que acontece é transferi uma quantia da ...
# 18   o  bem que podia me ajudar nesse feriado né tá...
# 19     sabe o que são 12min esperando por uma chama...
# 20    eu só queria que a central de relacionamento ...
# 21   41min aguardando no atendimento do  e até agor...
# 22                                            obrigado
# 23   minha fatura ainda não foi debitado vencimento...
# 24    gente me da o mínimo de atenção pelo amor de ...
# 25                                   vai cair 20 ou 22
# 26
# 27    ser correntista next é um desgosto a entrega ...
# 28    oi amadas tudo bem com vcs aqui não está nada...
# 29     nao debitaram minha fatura da conta nao foi ...
# ..                                                 ...
# 679                                             mandei
# 680                                       faz um tempo
# 681                                      ariana feat
# 682  rt  next tem conta  cartão de crédito grátis e...
# 683  queria ser client do  pra ter os 15 de descont...
# 684  vou marcar o   em tudo p ver se eles me notam ...
# 685  se alguém me perguntar ou pedir indicação eu n...
# 686  qualidade de atendimento ao cliente do  é péssima
# 687  pq to pensando seriamente cancelar o meu cartã...
# 688  ligo ligo no   e ninguém me atende o jeito é l...
# 689  estava mega animado com o meu cartão da  só qu...
# 690                 quando que o meu cartão vai chegar
# 691                       eu ganhei 2 ingressos gratis
# 692   oi enviei uma solicitação de abertura de cont...
# 693   amanhã é dia de enem manda um voucher de desc...
# 694   o que está acontecendo cancelaram meu cartão ...
# 695  rt  já pode começar a fazer os planos pra abri...
# 696  a  q é o mais chatinho do role já me aprovou e...
# 697  oficialmente desistindo do   não consegui entr...
# 698   já fiquem ligados que hoje é dia do rolezinho...
# 699   bom dia perdi meu cartão e queria solicitar o...
# 700                                          e o line
# 701  assim que receber mensagem que o meu  foi apro...
# 702   exausta de tentar anexar a minha declaração d...
# 703                    tudo bem então ficarei ligado 👍
# 704   eu não uso o cartão next com outro objetivo a...
# 705  se o  não me der limite inicial de 1k vou fica...
# 706                         chamei não obtive resposta
# 707                        alo  me aceita logo caralho
# 708   fui ao caixa e o cartão de crédito estava lib...
#
# [709 rows x 1 columns]

# %% [markdown]
# *Stopwords in portuguese*

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')
# Inclusão de novas stopwords 
stopwords.append('tô')
stopwords.append('tá')
stopwords.append('pra')
stopwords.append('pro')
stopwords.append('é')
stopwords.append('aí')
stopwords.append('ser')
stopwords.append('pq')
stopwords.append('já')
stopwords.append('nao')
stopwords.append('rt')
stopwords.append('porque')
stopwords.append('vai')
stopwords.append('vou')
stopwords.append('faço')
stopwords.append('dm')
stopwords.append('q')

# %% [markdown]
# *WordCloud*

# %%
text = " ".join(tweet for tweet in data['text'])
plt.style.use('seaborn')
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user.png")
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Tweets WordCloud - atendimento')
# Out:
# Text(0.5,1,'Tweets WordCloud - atendimento')

# %% [markdown]
# *Basic statistics about the data*

# %%
def word_count(str):
    counts = OrderedDict()
    words = str.split()
    for word in words:
        if word not in stopwords:
            if word in counts:
                counts[word] += 1
            else:
                counts[word] = 1
    return counts

print("There are {} words in the combination of all tweets.".format(len(text)))

counts = sorted(word_count(text).items(), key = itemgetter(1), reverse = True)
display(counts[:10])
# Out:
# There are 47358 words in the combination of all tweets.
# [('cartão', 116),
#  ('next', 70),
#  ('conta', 70),
#  ('app', 41),
#  ('banco', 39),
#  ('atendimento', 37),
#  ('crédito', 34),
#  ('ainda', 32),
#  ('nada', 28),
#  ('dia', 27)]

# %% [markdown]
# *Transform occurrences in a dataframe*

# %%
wordcount = pd.DataFrame(counts, columns=['word', 'counts'])
top10 = wordcount[:10]
top10
# Out:
#           word  counts
# 0       cartão     116
# 1         next      70
# 2        conta      70
# 3          app      41
# 4        banco      39
# 5  atendimento      37
# 6      crédito      34
# 7        ainda      32
# 8         nada      28
# 9          dia      27

# %% [markdown]
# *Top 10 most used words*

# %%
# Dataset
plt.style.use('seaborn')
height = top10.counts
bars = top10.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words')
 
# Show graphic
plt.show()

# %%
# Save graph into a file
fig.savefig('most_used_words.png', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# *ReLi Lexicon - portuguese sentimental analysis*

# %%
base_path = '/Users/gayr/documents/gabriela/mba/tcc/ReLi-Lex'
allData = []
files = [os.path.join(base_path, f) for f in os.listdir(base_path)]
for file in files:
    t = 'pos' if '_Positivos' in file else 'neg'
    with open(file, 'r', encoding = 'latin-1') as content_file:
        content = content_file.read()
        all = re.findall('\[.*?\]',content)
        for w in all:
            allData.append((w[1:-1], t))
allDataDF = pd.DataFrame(allData, columns=['word', 'sentiment'])
allDataDF
# Out:
#                 word sentiment
# 0        aborrecente       neg
# 1         anacrônico       neg
# 2          arrombado       neg
# 3              besta       neg
# 4            bizarro       neg
# 5               bobo       neg
# 6              burro       neg
# 7          cansativo       neg
# 8              chato       neg
# 9           chocante       neg
# 10             chulo       neg
# 11            clichê       neg
# 12           confuso       neg
# 13     decepcionante       neg
# 14        defeituoso       neg
# 15        deplorável       neg
# 16        depressivo       neg
# 17        deprimente       neg
# 18      desagradável       neg
# 19         desconexo       neg
# 20       desgastante       neg
# 21   desinteressante       neg
# 22     desnecessário       neg
# 23       desprezível       neg
# 24           difícil       neg
# 25       dispensável       neg
# 26           doentio       neg
# 27           egoísta       neg
# 28         enfadonho       neg
# 29           enjoado       neg
# ..               ...       ...
# 580      destacar-se       pos
# 581         divertir       pos
# 582        emocionar       pos
# 583         emplacar       pos
# 584         empolgar       pos
# 585         encantar       pos
# 586       enternecer       pos
# 587         entreter       pos
# 588        facilitar       pos
# 589         fascinar       pos
# 590            fluir       pos
# 591           gostar       pos
# 592      identificar       pos
# 593     impressionar       pos
# 594           inovar       pos
# 595       recomendar       pos
# 596     sensibilizar       pos
# 597       simpatizar       pos
# 598        valorizar       pos
# 599           vibrar       pos
# 600           viciar       pos
# 601         apavorar       pos
# 602          brilhar       pos
# 603          comover       pos
# 604          devorar       pos
# 605          prender       pos
# 606              rir       pos
# 607         saborear       pos
# 608      surpreender       pos
# 609            tocar       pos
#
# [610 rows x 2 columns]

# %% [markdown]
# *Validate the model and avoid overfit*

# %% [markdown]
# Functions

# %%
# Split arrays or matrices into random train and test subsets
from sklearn.model_selection import train_test_split
# A random forest classifier
from sklearn.ensemble import RandomForestClassifier
# A naive bayes classifier
from sklearn.naive_bayes import MultinomialNB
# A boosting classifier
from sklearn.ensemble import AdaBoostClassifier
# Encode labels with value between 0 and n_classes-1
from sklearn.preprocessing import LabelEncoder
# Accuracy classification score
from sklearn.metrics import accuracy_score
# This classifier is useful as a simple baseline to compare with other (real) classifiers
from sklearn.dummy import DummyClassifier
# Out:
# C:\Users\GAYR\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# Original Variables

# %%
X_original = allDataDF.word
Y_original = allDataDF.sentiment

# %% [markdown]
# O sklearn precisa que as variáveis independentes sejam contínuas - por esse motivo precisaremos transformar palavras em números

# %%
le_x = LabelEncoder()
X_labelEncoded = le_x.fit_transform(X_original)
le_y = LabelEncoder()
Y_labelEncoded = le_y.fit_transform(Y_original)

# %%
zippedEncoded = list(zip(X_labelEncoded, Y_labelEncoded))
dfEncoded = pd.DataFrame(zippedEncoded, columns = ['word', 'sentiment'])

# %% [markdown]
# Cross Validation - Divisão da amostra entre treino e teste - scikitlearn

# %%
X_labelEncodedDF = dfEncoded.word
Y_labelEncodedDF = dfEncoded.sentiment
X_train, X_test, y_train, y_test = train_test_split(X_labelEncodedDF, Y_labelEncodedDF, test_size=0.30, random_state = 13)

# %% [markdown]
# *Classification Models*

# %% [markdown]
# Random Forest Classifier

# %%
rf = RandomForestClassifier(n_estimators = 100)
rf.fit(X_train.values.reshape(-1, 1), y_train)
y_pred = rf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Naive Bayes Classifier

# %%
nb = MultinomialNB()
nb.fit(X_train.values.reshape(-1, 1), y_train)
y_nb_pred = nb.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Boosting Classifier

# %%
clf = AdaBoostClassifier(n_estimators=100)
clf.fit(X_train.values.reshape(-1, 1), y_train)
y_clf_pred = clf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Dummy Model

# %%
dm = DummyClassifier()
dm.fit(X_train.values.reshape(-1, 1), y_train)
y_dummy_pred = dm.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# *Model´s Accuracy*

# %%
print('Accuracy random forest on test dataset: {}'.format(round(accuracy_score(y_test, y_pred), 2)))
print('Accuracy naive bayes on test dataset: {}'.format(round(accuracy_score(y_test, y_nb_pred), 2)))
print('Accuracy boosting on test dataset: {}'.format(round(accuracy_score(y_test, y_clf_pred), 2)))
print('Accuracy dummy model on test dataset: {}'.format(round(accuracy_score(y_test, y_dummy_pred), 2)))
# Out:
# Accuracy random forest on test dataset: 0.7
# Accuracy naive bayes on test dataset: 0.63
# Accuracy boosting on test dataset: 0.66
# Accuracy dummy model on test dataset: 0.54

# %% [markdown]
# A seguir, iremos utilizar o algoritmo para classificação Random Forest para a análise de sentimentos, devido ao melhor nível de acurácia apresentado.

# %%
# tweetsDataLabelEncoder = LabelEncoder()
tweet_text = data.text
tweetsEncoded = le_x.fit_transform(tweet_text)
y_pred_total = rf.predict(tweetsEncoded.reshape(-1, 1))
y_pred_total_decoded = le_y.inverse_transform(y_pred_total)
data['sentiment'] = y_pred_total_decoded
display(data[:10])
# Out:
# C:\Users\GAYR\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#                                                 text sentiment
# 0  rt  já pode começar a fazer os planos pra abri...       pos
# 1   me refiro a transferir dinheiro pra minha con...       pos
# 2   já paguei minha fatura faz uns 5 dias e nada ...       pos
# 3            depois de 1h30 no telefone sim consegui       pos
# 4   eu preciso entender o que aconteceu com a min...       pos
# 5              mandei direct 💕 obrigado pela atenção       neg
# 6                                                          pos
# 7                                pode responder a dm       neg
# 8                                                          pos
# 9                                                          pos

# %% [markdown]
# *Counting positives and negatives*

# %%
df = data.groupby('sentiment').count()
df
# Out:
#            text
# sentiment
# neg         217
# pos         492

# %% [markdown]
# *Sentimental Analysis Graph based on Naive-Bayes Classification*

# %%
plt.style.use('seaborn')
pie_pos = df.loc['pos']
pie_neg = df.loc['neg']
fig = plt.figure()

slices = [pie_neg, pie_pos]
tweets = ['Negative', 'Positive']
columns = ['Red', 'Green']

plt.title('Tweets sentimental analysis')
 
plt.pie(slices, labels = tweets, colors = columns, startangle = 90, shadow = True, explode = (0.1, 0), autopct='%1.0f%%')

plt.show()

# %%
# Save graph into a file
fig.savefig("tweets_sentimental_analysis.png")

# %% [markdown]
# *Positive WordCloud*

# %%
# filtrar dataframe com tweets positivos
data_pos_filtered = data[data['sentiment'] == 'pos']

# %%
# WordCloud
plt.style.use('seaborn')
data_pos_filtered = " ".join(tweet for tweet in data_pos_filtered['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user_pos.png")
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Positive Tweets WordCloud')
# Out:
# Text(0.5,1,'Positive Tweets WordCloud')

# %% [markdown]
# *Top 10 most used words in positive tweets*

# %%
count_pos = sorted(word_count(data_pos_filtered).items(), key = itemgetter(1), reverse = True)
wordcount_pos = pd.DataFrame(count_pos, columns=['word', 'counts'])
top10_pos = wordcount_pos[:10]
top10_pos
# Out:
#           word  counts
# 0       cartão      82
# 1        conta      54
# 2         next      53
# 3  atendimento      29
# 4        banco      28
# 5          app      27
# 6      crédito      24
# 7          dia      22
# 8        ainda      21
# 9        falar      21

# %%
# Dataset
plt.style.use('seaborn')
height = top10_pos.counts
bars = top10_pos.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words in positive tweets')
 
# Show graphic
plt.show()

# %%
# Save graph into a file
fig.savefig("most_used_positive_words.png")

# %% [markdown]
# *Negative WordCloud*

# %%
# filtrar dataframe com tweets positivos
data_neg_filtered = data[data['sentiment'] == 'neg']
data_neg_filtered
# Out:
#                                                   text sentiment
# 5                mandei direct 💕 obrigado pela atenção       neg
# 7                                  pode responder a dm       neg
# 11   agr sou a mulher mais feliz do mundo c cartão ...       neg
# 13               pode me tirar uma dúvida mandei na dm       neg
# 21   41min aguardando no atendimento do  e até agor...       neg
# 24    gente me da o mínimo de atenção pelo amor de ...       neg
# 27    ser correntista next é um desgosto a entrega ...       neg
# 28    oi amadas tudo bem com vcs aqui não está nada...       neg
# 30                                   ahhhh kkk entendi       neg
# 32                achei q vc ja tivesse um deles kkkkk       neg
# 36                      será que da pra responder a dm       neg
# 41                                resolveu obrigado ❤️       neg
# 43    ainda não verifiquei mas vou tentar e já retorno       neg
# 45    quero cartão só pra receber meu salário crédi...       neg
# 49   alô  vocês demoram muito pra debitar a fatura ...       neg
# 57                                         thank you         neg
# 58                              to precisando de ajuda       neg
# 62                              esperando o  responder       neg
# 64                                           mandei dm       neg
# 65     um sistema de apego confuso bem pra te deixa...       neg
# 74    por que vcs não tem número de rastreamento do...       neg
# 75      minha conta aceitava mais nada cancelei a c...       neg
# 82     aqui o app diz q a senha do meu celular ñ es...       neg
# 83   no  vc não sabe como pagar a fatura e se sabe ...       neg
# 85   gente eu tenho o  e até o momento não tenho do...       neg
# 87    gente que banco ruim é esse não consigo saber...       neg
# 89    eu ligo neste número toca uma música e a liga...       neg
# 90                               bora me atender aí bb       neg
# 94                            vai ver minha dm não poc       neg
# 95    ainda esse ano hein bebê vamos jogar isso pra...       neg
# ..                                                 ...       ...
# 595         meu cartão da  chegou tão fofa a embalagem       neg
# 596   e se serve como sugestão  procurem parcerias ...       neg
# 601   então vocês renomeiam o sac de vocês pra pode...       neg
# 603   tao lindo mas com o atendimento mais lixoso d...       neg
# 604   acabei de receber o cartão obrigado gostei da...       neg
# 608  aí eu vou e fico mais uma hora na fila da dona...       neg
# 609   meu neném fui furtada e preciso bloquear o me...       neg
# 612   quero alterar meu endereço para que o cartão ...       neg
# 615                                   preciso de ajuda       neg
# 618                                    complicado viu        neg
# 625             toda vez q precisei de ajuda foi assim       neg
# 630  como processo a  e  mesmo atendimento deles le...       neg
# 641   adoro o serviço de vocês mas hj tá difícil mu...       neg
# 643   então no caso eu tenho que transferir da poup...       neg
# 646                       sim abriram 3 abriram contas       neg
# 649   parabéns pelo péssimo atendimento eu só sou a...       neg
# 651    espera até você precisar usar o chat deles kkkk       neg
# 660   poxa 2° problema com vcs já agr meu cartão n ...       neg
# 662   vocês têm previsão de liberar os depositos im...       neg
# 663   tenho sim to esperando a segunda via mas o ou...       neg
# 664   tenho sim as duas funções e a mensagem que ap...       neg
# 670      hahahahaha na verdade ele ta tendendo pro  em       neg
# 676   pq o app sempre falha pra conectar toda hora ...       neg
# 677           quando vcs vão vê aprovar pro crédito em       neg
# 678    esse whatsapp funciona ninguém responde por ...       neg
# 690                 quando que o meu cartão vai chegar       neg
# 693   amanhã é dia de enem manda um voucher de desc...       neg
# 700                                          e o line        neg
# 701  assim que receber mensagem que o meu  foi apro...       neg
# 707                        alo  me aceita logo caralho       neg
#
# [217 rows x 2 columns]

# %%
# WordCloud
plt.style.use('seaborn')
data_neg_filtered = " ".join(tweet for tweet in data_neg_filtered['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user_neg.png")
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Negative Tweets WordCloud')
# Out:
# Text(0.5,1,'Negative Tweets WordCloud')

# %% [markdown]
# *Top 10 most used words in negative tweets*

# %%
count_neg = sorted(word_count(data_neg_filtered).items(), key = itemgetter(1), reverse = True)
wordcount_neg = pd.DataFrame(count_neg, columns=['word', 'counts'])
top10_neg = wordcount_neg[:10]
top10_neg
# Out:
#       word  counts
# 0   cartão      34
# 1     next      17
# 2    conta      16
# 3      app      14
# 4     nada      11
# 5    ainda      11
# 6    banco      11
# 7  crédito      10
# 8      sim      10
# 9   mandei       9

# %%
# Dataset
plt.style.use('seaborn')
height = top10_neg.counts
bars = top10_neg.word
y_pos = np.arange(len(bars))
fig = plt.figure()
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words in negative tweets')
 
# Show graphic
plt.show()

# %%
# Save into a file
fig.savefig("most_used_negative_words.png")
