# %% [markdown]
# *Import library's*

# %%
import numpy as np
import pandas as pd
from textblob import TextBlob as tb
import tweepy
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from textblob.classifiers import NaiveBayesClassifier
import os, re, nltk, string
from bs4 import BeautifulSoup
from collections import OrderedDict
from operator import itemgetter

# %% [markdown]
# *Twitter authentication*

# %%
consumer_key = 'Jg95VukOglg6RIqRrqt6GYRoa'
consumer_secret = 'ZvH3Oz7jFN0OvDMXGtRriTqOOykGnUgqxAU0wNKWhMElII0ivq'
access_token = '971179238396227584-KkOSGzCwhzv0lokz55Dkp1wTjyurnkW'
access_token_secret = 'y2NNUWU1tlhQYMOps49aSKgckRqTu7T7dPWpyNbMeXvAA'

# %%
def get_all_tweets(searchString, maxResult = 200):
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth)
    new_tweets = api.search(searchString, count = maxResult)
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in new_tweets]
    return outtweets

# %% [markdown]
# *Get all tweets*

# %%
public_tweets = get_all_tweets('@falanext')
df = pd.DataFrame(public_tweets, columns=['id','created_at','text'])
df
# Out:
#                      id          created_at  \
# 0   1060657517129359360 2018-11-08 22:17:12
# 1   1060657119781941255 2018-11-08 22:15:38
# 2   1060656900289761290 2018-11-08 22:14:45
# 3   1060656524333342724 2018-11-08 22:13:16
# 4   1060655395545473026 2018-11-08 22:08:46
# 5   1060653014443327493 2018-11-08 21:59:19
# 6   1060650400964141059 2018-11-08 21:48:56
# 7   1060648442811334656 2018-11-08 21:41:09
# 8   1060648071573487616 2018-11-08 21:39:40
# 9   1060647970029400064 2018-11-08 21:39:16
# 10  1060647029972578304 2018-11-08 21:35:32
# 11  1060646679790133250 2018-11-08 21:34:08
# 12  1060646105178890240 2018-11-08 21:31:51
# 13  1060645288166256641 2018-11-08 21:28:37
# 14  1060644380426620928 2018-11-08 21:25:00
# ..                  ...                 ...
# 85  1060507079578923008 2018-11-08 12:19:25
# 86  1060504488103079936 2018-11-08 12:09:07
# 87  1060503052103442432 2018-11-08 12:03:25
# 88  1060501376080453632 2018-11-08 11:56:45
# 89  1060475872203993089 2018-11-08 10:15:25
# 90  1060463384460779520 2018-11-08 09:25:47
# 91  1060451351602384896 2018-11-08 08:37:59
# 92  1060436971057803264 2018-11-08 07:40:50
# 93  1060405110986158080 2018-11-08 05:34:14
# 94  1060364314362679296 2018-11-08 02:52:07
# 95  1060361105271386113 2018-11-08 02:39:22
# 96  1060357509473542146 2018-11-08 02:25:05
# 97  1060355254317912064 2018-11-08 02:16:07
# 98  1060351105786359809 2018-11-08 01:59:38
# 99  1060348450875863040 2018-11-08 01:49:05
#
#                                                  text
# 0   b'J\xc3\xa1 tentei fazer login o dia todo e s\...
# 1   b'Liguei no SAC duas vezes e s\xc3\xb3 toca a ...
# 2   b'O que eu fa\xc3\xa7o pro banco @falanext sol...
# 3   b'@falanext como fa\xc3\xa7o para atualizar me...
# 4   b'eu estou a duas semanas entrar em contato co...
# 5   b'o @falanext respondeu o Ivo mas n\xc3\xa3o m...
# 6   b'@falanext Preciso de ajuda no quesito limite...
# 7   b'@falanext Eu j\xc3\xa1 tentei o ajuda do app...
# 8   b'@falanext tem que liberar antecipa\xc3\xa7\x...
# 9       b'@falanext preciso da ajuda de voc\xc3\xaas'
# 10  b'@getawaycarol @falanext N\xc3\xa3o recebi me...
# 11  b'mal entrei no banco e ja to passando nervoso...
# 12  b'al\xc3\xb4 @falanext muito obrigada pelo mim...
# 13  b'caralho o @falanext s\xc3\xb3 me decepciona,...
# 14  b'@falanext galera estou precisando de uma aju...
# ..                                                ...
# 85  b'@falanext J\xc3\xa1 liguei, e enviei print p...
# 86                                    b'@falanext dm'
# 87  b'@falanext preciso de assist\xc3\xaancia. Fac...
# 88  b'Oi @falanext tutopom? N\xc3\xa3o consigo des...
# 89  b'@manhagol @falanext Coloquei 1000 no Nubank,...
# 90  b'@falanext que erro \xc3\xa9 esse que est\xc3...
# 91  b'@falanext @andrellipe_ @falanext Rola ainda ...
# 92  b'@falanext meu cartao nao foi entregue pq nao...
# 93                        b'@falanext D\xc3\xa9bito!'
# 94  b'@falanext vcs tao sem moral p me chamar de v...
# 95  b'Meu cart\xc3\xa3o da @falanext chegou e eu t...
# 96           b'@falanext Tem taxa de juros e iof? rs'
# 97  b's\xc3\xb3 queria saber not\xc3\xadcias do me...
# 98  b'@falanext n\xc3\xa3o consegui usar meu cart\...
# 99  b'apliquei pra abrir conta no @falanext com re...
#
# [100 rows x 3 columns]

# %% [markdown]
# *Data Cleaning*

# %%
def cleanTweets(tweetsDF):
    table = str.maketrans(dict.fromkeys(string.punctuation.replace('@','')))
    # essa regex significa:
    # tudo que conter @ OU http OU terminador de linha seguido de uma palavra OU um espaco OU qualquer outro terminador
    # de linha.
    rePattern1 = '(@|http|\\n)(\w+|\s|\S)'
    formattedTweets = []
    for line in tweetsDF['text']:
        formattedStr = line.decode('utf-8').lower()
        formattedStr = formattedStr.translate(table)
        formattedStr = re.sub(rePattern1, "", formattedStr)  
        formattedTweets.append(formattedStr)
    return formattedTweets

formattedTweets = cleanTweets(df)
data = pd.DataFrame(formattedTweets, columns=['text'])
data
# Out:
#                                                  text
# 0   já tentei fazer login o dia todo e só aparece ...
# 1   liguei no sac duas vezes e só toca a musica e ...
# 2   o que eu faço pro banco  solucionar meus probl...
# 3    como faço para atualizar meu email cadastrado...
# 4   eu estou a duas semanas entrar em contato com ...
# 5   o  respondeu o ivo mas não me respondeu lastim...
# 6       preciso de ajuda no quesito limite de crédito
# 7    eu já tentei o ajuda do app me responderam de...
# 8    tem que liberar antecipação de pagamento sem ...
# 9                           preciso da ajuda de vocês
# 10    não recebi meu cartão até hoje kk e eu quero...
# 11  mal entrei no banco e ja to passando nervoso a...
# 12  alô  muito obrigada pelo mimo do cinema viu po...
# 13  caralho o  só me decepciona ainda não tive nen...
# 14   galera estou precisando de uma ajuda com o ap...
# ..                                                ...
# 85                 já liguei e enviei print por email
# 86                                                 dm
# 87   preciso de assistência face e telefones não r...
# 88  oi  tutopom não consigo desbloquear aquele bel...
# 89       coloquei 1000 no nubank me deram 50 hahahaha
# 90   que erro é esse que está dando no app        ...
# 91     rola ainda esse ano  só falta essa função p...
# 92   meu cartao nao foi entregue pq nao tinha ning...
# 93                                             débito
# 94            vcs tao sem moral p me chamar de vini v
# 95       meu cartão da  chegou e eu to assustadissima
# 96                         tem taxa de juros e iof rs
# 97            só queria saber notícias do meu cartão
# 98   não consegui usar meu cartão no débito tem al...
# 99  apliquei pra abrir conta no  com renda de 100 ...
#
# [100 rows x 1 columns]

# %% [markdown]
# *Stopwords in portuguese*

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')
# Inclusão de novas stopwords 
stopwords.append('tô')
stopwords.append('pra')
stopwords.append('pro')
stopwords.append('é')
stopwords.append('aí')
stopwords.append('ser')

# %% [markdown]
# *WordCloud*

# %%
text = " ".join(tweet for tweet in data['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user.png")
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# *Basic statistics about the data*

# %%
def word_count(str):
    counts = OrderedDict()
    words = str.split()
    for word in words:
        if word not in stopwords:
            if word in counts:
                counts[word] += 1
            else:
                counts[word] = 1
    return counts

print("There are {} words in the combination of all tweets.".format(len(text)))

counts = sorted(word_count(text).items(), key = itemgetter(1), reverse = True)
display(counts[:10])
# Out:
# There are 6986 words in the combination of all tweets.
# [('conta', 15),
#  ('cartão', 13),
#  ('banco', 10),
#  ('ajuda', 8),
#  ('next', 8),
#  ('nada', 7),
#  ('consigo', 6),
#  ('preciso', 6),
#  ('app', 6),
#  ('dm', 6)]

# %% [markdown]
# *Transform occurrences in a dataframe*

# %%
wordcount = pd.DataFrame(counts, columns=['word', 'counts'])
top10 = wordcount[:10]
top10
# Out:
#       word  counts
# 0    conta      15
# 1   cartão      13
# 2    banco      10
# 3    ajuda       8
# 4     next       8
# 5     nada       7
# 6  consigo       6
# 7  preciso       6
# 8      app       6
# 9       dm       6

# %% [markdown]
# *Top 10 most used words*

# %%
# Dataset
height = top10.counts
bars = top10.word
y_pos = np.arange(len(bars))
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words')
 
# Show graphic
plt.show()

# %% [markdown]
# *ReLi Lexicon - portuguese sentimental analysis*

# %%
base_path = '/Users/gayr/documents/gabriela/mba/tcc/ReLi-Lex'
allData = []
files = [os.path.join(base_path, f) for f in os.listdir(base_path)]
for file in files:
    t = 'pos' if '_Positivos' in file else 'neg'
    with open(file, 'r', encoding = 'latin-1') as content_file:
        content = content_file.read()
        all = re.findall('\[.*?\]',content)
        for w in all:
            allData.append((w[1:-1], t))
allDataDF = pd.DataFrame(allData, columns=['word', 'sentiment'])
allDataDF
# Out:
#               word sentiment
# 0      aborrecente       neg
# 1       anacrônico       neg
# 2        arrombado       neg
# 3            besta       neg
# 4          bizarro       neg
# 5             bobo       neg
# 6            burro       neg
# 7        cansativo       neg
# 8            chato       neg
# 9         chocante       neg
# 10           chulo       neg
# 11          clichê       neg
# 12         confuso       neg
# 13   decepcionante       neg
# 14      defeituoso       neg
# ..             ...       ...
# 595     recomendar       pos
# 596   sensibilizar       pos
# 597     simpatizar       pos
# 598      valorizar       pos
# 599         vibrar       pos
# 600         viciar       pos
# 601       apavorar       pos
# 602        brilhar       pos
# 603        comover       pos
# 604        devorar       pos
# 605        prender       pos
# 606            rir       pos
# 607       saborear       pos
# 608    surpreender       pos
# 609          tocar       pos
#
# [610 rows x 2 columns]

# %% [markdown]
# *Validate the model and avoid overfit*

# %% [markdown]
# Functions

# %%
# Split arrays or matrices into random train and test subsets
from sklearn.model_selection import train_test_split
# A random forest classifier
from sklearn.ensemble import RandomForestClassifier
# Encode labels with value between 0 and n_classes-1
from sklearn.preprocessing import LabelEncoder
# Accuracy classification score
from sklearn.metrics import accuracy_score
# This classifier is useful as a simple baseline to compare with other (real) classifiers
from sklearn.dummy import DummyClassifier

# %% [markdown]
# Original Variables

# %%
X_original = allDataDF.word
Y_original = allDataDF.sentiment

# %% [markdown]
# O Naive Bayes do sklearn precisa que as variáveis independentes sejam contínuas - por esse motivo precisaremos transformar palavras em números

# %%
le_x = LabelEncoder()
X_labelEncoded = le_x.fit_transform(X_original)
le_y = LabelEncoder()
Y_labelEncoded = le_y.fit_transform(Y_original)

# %% [markdown]
# O que faz o zip? Entender melhor...

# %%
zippedEncoded = list(zip(X_labelEncoded, Y_labelEncoded))
dfEncoded = pd.DataFrame(zippedEncoded, columns = ['word', 'sentiment'])

# %% [markdown]
# Cross Validation - Divisão da amostra entre treino e teste - scikitlearn

# %%
X_labelEncodedDF = dfEncoded.word
Y_labelEncodedDF = dfEncoded.sentiment
X_train, X_test, y_train, y_test = train_test_split(X_labelEncodedDF, Y_labelEncodedDF, test_size=0.30, random_state = 13)

# %% [markdown]
# Random Forest Classifier

# %%
rf = RandomForestClassifier(n_estimators = 100)
rf.fit(X_train.values.reshape(-1, 1), y_train)
y_pred = rf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Naive Bayes Classifier

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(X_train.values.reshape(-1, 1), y_train)
y_nb_pred = rf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Dummy Model

# %%
dm = DummyClassifier()
dm.fit(X_train.values.reshape(-1, 1), y_train)
y_dummy_pred = dm.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Acurácia dos modelos

# %%
print('Accuracy random forest on test dataset: {}'.format(round(accuracy_score(y_test, y_pred), 2)))
print('Accuracy naive bayes on test dataset: {}'.format(round(accuracy_score(y_test, y_nb_pred), 2)))
print('Accuracy dummy model on test dataset: {}'.format(round(accuracy_score(y_test, y_dummy_pred), 2)))
# Out:
# Accuracy random forest on test dataset: 0.7
# Accuracy naive bayes on test dataset: 0.7
# Accuracy dummy model on test dataset: 0.52

# %% [markdown]
# O nível de acurácia do Random Forest foi igual a Naive Bayes e melhor que o Dummy, por esse motivo iremos utilizar o Random Forest para a análise de sentimentos

# %%
# tweetsDataLabelEncoder = LabelEncoder()
tweetText = data.text
tweetsEncoded = le_x.fit_transform(tweetText)
y_pred_total = rf.predict(tweetsEncoded.reshape(-1, 1))
y_pred_total_decoded = le_y.inverse_transform(y_pred_total)
data.sentiment = y_pred_total_decoded
display(data)
# Out:
# C:\Users\GAYR\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#                                                  text sentiment
# 0   já tentei fazer login o dia todo e só aparece ...       neg
# 1   liguei no sac duas vezes e só toca a musica e ...       neg
# 2   o que eu faço pro banco  solucionar meus probl...       pos
# 3    como faço para atualizar meu email cadastrado...       pos
# 4   eu estou a duas semanas entrar em contato com ...       neg
# 5   o  respondeu o ivo mas não me respondeu lastim...       pos
# 6       preciso de ajuda no quesito limite de crédito       neg
# 7    eu já tentei o ajuda do app me responderam de...       pos
# 8    tem que liberar antecipação de pagamento sem ...       pos
# 9                           preciso da ajuda de vocês       neg
# 10    não recebi meu cartão até hoje kk e eu quero...       pos
# 11  mal entrei no banco e ja to passando nervoso a...       neg
# 12  alô  muito obrigada pelo mimo do cinema viu po...       neg
# 13  caralho o  só me decepciona ainda não tive nen...       neg
# 14   galera estou precisando de uma ajuda com o ap...       pos
# ..                                                ...       ...
# 85                 já liguei e enviei print por email       pos
# 86                                                 dm       pos
# 87   preciso de assistência face e telefones não r...       pos
# 88  oi  tutopom não consigo desbloquear aquele bel...       pos
# 89       coloquei 1000 no nubank me deram 50 hahahaha       pos
# 90   que erro é esse que está dando no app        ...       pos
# 91     rola ainda esse ano  só falta essa função p...       pos
# 92   meu cartao nao foi entregue pq nao tinha ning...       pos
# 93                                             débito       pos
# 94            vcs tao sem moral p me chamar de vini v       pos
# 95       meu cartão da  chegou e eu to assustadissima       pos
# 96                         tem taxa de juros e iof rs       pos
# 97            só queria saber notícias do meu cartão        pos
# 98   não consegui usar meu cartão no débito tem al...       pos
# 99  apliquei pra abrir conta no  com renda de 100 ...       neg
#
# [100 rows x 2 columns]

# %% [markdown]
# *Counting positives and negatives*

# %%
df = display(data.groupby('sentiment').count())
df
# Out:
#            text
# sentiment
# neg          27
# pos          73

# %% [markdown]
# *Sentimental Analysis Graph based on Naive-Bayes Classification*

# %%
pie_pos = df.sentiment['pos']
pie_neg = df.loc['neg']
pie_na = df.loc['N/A']

slices = [pie_na, pie_neg, pie_pos]
tweets = ['N/A', 'Negative', 'Positive']
columns = ['LightGrey', 'Red', 'Green']
 
plt.pie(slices, labels = tweets, colors = columns, startangle = 90, shadow = True, explode = (0, 0.1, 0), autopct='%1.0f%%')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-147-d4e97fdc2408> in <module>()
# ----> 1 pie_pos = df.sentiment['pos']
#       2 pie_neg = df.loc['neg']
#       3 pie_na = df.loc['N/A']
#       4
#       5 slices = [pie_na, pie_neg, pie_pos]
#
# AttributeError: 'NoneType' object has no attribute 'sentiment'

# %% [markdown]
# *Positive WordCloud*

# %% [markdown]
# *Negative WordCloud*
