# %% [markdown]
# *Import library's*

# %%
import numpy as np
import pandas as pd
from textblob import TextBlob as tb
import tweepy
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from textblob.classifiers import NaiveBayesClassifier
import os, re, nltk, string
from bs4 import BeautifulSoup
from collections import OrderedDict
from operator import itemgetter

# %% [markdown]
# *Twitter authentication*

# %%
consumer_key = 'Jg95VukOglg6RIqRrqt6GYRoa'
consumer_secret = 'ZvH3Oz7jFN0OvDMXGtRriTqOOykGnUgqxAU0wNKWhMElII0ivq'
access_token = '971179238396227584-KkOSGzCwhzv0lokz55Dkp1wTjyurnkW'
access_token_secret = 'y2NNUWU1tlhQYMOps49aSKgckRqTu7T7dPWpyNbMeXvAA'

# %%
def get_all_tweets(searchString, maxResult = 200):
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth)
    new_tweets = api.search(searchString, count = maxResult)
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in new_tweets]
    return outtweets

# %% [markdown]
# *Get all tweets*

# %%
public_tweets = get_all_tweets('@falanext')
df = pd.DataFrame(public_tweets, columns=['id','created_at','text'])
df
# Out:
#                      id          created_at  \
# 0   1060971417095888901 2018-11-09 19:04:32
# 1   1060971027675652096 2018-11-09 19:02:59
# 2   1060967890327953410 2018-11-09 18:50:31
# 3   1060964694717030400 2018-11-09 18:37:49
# 4   1060962212586631168 2018-11-09 18:27:57
# 5   1060960568503353346 2018-11-09 18:21:25
# 6   1060954023791128576 2018-11-09 17:55:25
# 7   1060953644072361985 2018-11-09 17:53:54
# 8   1060948826893307905 2018-11-09 17:34:46
# 9   1060947367099281408 2018-11-09 17:28:58
# 10  1060933325337059331 2018-11-09 16:33:10
# 11  1060932823136325633 2018-11-09 16:31:10
# 12  1060932335846199297 2018-11-09 16:29:14
# 13  1060932201393635329 2018-11-09 16:28:42
# 14  1060932003586027521 2018-11-09 16:27:55
# 15  1060931815958085633 2018-11-09 16:27:10
# 16  1060928506769694720 2018-11-09 16:14:01
# 17  1060925636926205952 2018-11-09 16:02:37
# 18  1060925342439882752 2018-11-09 16:01:27
# 19  1060912456262914049 2018-11-09 15:10:15
# 20  1060910759255912448 2018-11-09 15:03:30
# 21  1060910548299235328 2018-11-09 15:02:40
# 22  1060909951055470593 2018-11-09 15:00:17
# 23  1060909211381567488 2018-11-09 14:57:21
# 24  1060908939901059073 2018-11-09 14:56:16
# 25  1060900497996025857 2018-11-09 14:22:43
# 26  1060896012636692482 2018-11-09 14:04:54
# 27  1060895935159525377 2018-11-09 14:04:36
# 28  1060894136973344768 2018-11-09 13:57:27
# 29  1060893709271736320 2018-11-09 13:55:45
# ..                  ...                 ...
# 70  1060693123725180928 2018-11-09 00:38:42
# 71  1060691885637931008 2018-11-09 00:33:46
# 72  1060690750097240064 2018-11-09 00:29:16
# 73  1060686411412725760 2018-11-09 00:12:01
# 74  1060686347109888001 2018-11-09 00:11:46
# 75  1060685335024275457 2018-11-09 00:07:45
# 76  1060681780246835200 2018-11-08 23:53:37
# 77  1060681623266643968 2018-11-08 23:53:00
# 78  1060678186449690625 2018-11-08 23:39:20
# 79  1060677409530408960 2018-11-08 23:36:15
# 80  1060675561494929409 2018-11-08 23:28:54
# 81  1060674870160306178 2018-11-08 23:26:10
# 82  1060672215404986368 2018-11-08 23:15:37
# 83  1060669997670903808 2018-11-08 23:06:48
# 84  1060669426373222400 2018-11-08 23:04:32
# 85  1060662472624037888 2018-11-08 22:36:54
# 86  1060661755007983616 2018-11-08 22:34:03
# 87  1060657517129359360 2018-11-08 22:17:12
# 88  1060657119781941255 2018-11-08 22:15:38
# 89  1060656900289761290 2018-11-08 22:14:45
# 90  1060656524333342724 2018-11-08 22:13:16
# 91  1060655395545473026 2018-11-08 22:08:46
# 92  1060653014443327493 2018-11-08 21:59:19
# 93  1060650400964141059 2018-11-08 21:48:56
# 94  1060648442811334656 2018-11-08 21:41:09
# 95  1060648071573487616 2018-11-08 21:39:40
# 96  1060647970029400064 2018-11-08 21:39:16
# 97  1060647029972578304 2018-11-08 21:35:32
# 98  1060646679790133250 2018-11-08 21:34:08
# 99  1060646105178890240 2018-11-08 21:31:51
#
#                                                  text
# 0   b'@falanext Voc\xc3\xaas bem que podiam entreg...
# 1   b'@falanext mas j\xc3\xa1 faz uns dias n\xc3\x...
# 2   b'@Guiabolso voc\xc3\xaas tem support pro @fal...
# 3   b'como eu sei que a fun\xc3\xa7\xc3\xa3o cart\...
# 4   b'@falanext 1ted por m\xc3\xaas vcs me quebram...
# 5           b'@falanext oi meu anjo me ajuda aqui...'
# 6   b'@itsbru @nubank @falanext @falanext falam p ...
# 7   b'Ei @falanext  precisamos bater um papo, por\...
# 8   b'@falanext Ainda n\xc3\xa3o.... Liguei hoje t...
# 9   b'@falanext s\xc3\xb3 fica assim https://t.co/...
# 10     b'@edusemmonica @falanext Next \xc3\xa9 um cu'
# 11  b'@LuksRP @nubank @Bancointer @BancoCentralBR ...
# 12        b'@wheresmath @Bradesco @falanext kkkkkkkk'
# 13  b'@Iamjoaoopedro @Bradesco @falanext https://t...
# 14  b'@wheresmath @Bradesco @falanext ainda to no ...
# 15  b'@Iamjoaoopedro @Bradesco @falanext miseric\x...
# 16  b'@Bradesco PELO AMOR DE DEUS AJUDA A GALERA D...
# 17  b'@nubank @Bancointer @BancoCentralBR @Bancodo...
# 18  b'22 min no telefone esperando atendimento do ...
# 19  b'@falanext PQ VC TA ME IGNORANDO \xf0\x9f\x98...
# 20  b'@falanext Fiquei mais de 20 minutos esperand...
# 21  b'@falanext Bel\xc3\xaa, liberem logo porque \...
# 22  b'@falanext Eu respondi assim que me enviaram....
# 23  b'@falanext MANO QUE RAIVA, \xc3\xa9imposs\xc3...
# 24            b'@falanext pq vcs n\xc3\xa3o atendem?'
# 25  b'@guidinomon @falanext Migo bem in\xc3\xbatil...
# 26  b'@falanext galera eu ainda estou esperando o ...
# 27  b'@falanext A 2 meses atr\xc3\xa1s eu precisav...
# 28  b'@droganalu @gujuin @nubank @falanext Vou pen...
# 29              b'@gujuin @nubank @falanext ~inveja~'
# ..                                                ...
# 70  b'Abro o @falanext e ele me da 2 ingressos gr\...
# 71               b'@falanext https://t.co/qcTQ6SDzFp'
# 72  b'@falanext vcs esqueceram meu cart\xc3\xa3o e...
# 73          b'@falanext Abri um chamado. Pode ir DM?'
# 74  b'RT @falanext: @jmdesaron Nos desculpe o inco...
# 75  b'Eae @falanext , obrigado pelo email de propo...
# 76  b'@mathbrgs @yagoalvesantos @falanext @nubank ...
# 77  b'@falanext consegui hj ap\xc3\xb3s 5 hrs de e...
# 78                        b'@falanext Olha minha DM?'
# 79  b'@falanext o comprovante de endere\xc3\xa7o m...
# 80  b'@digomend @YouTubeBrasil @Wix Mas voc\xc3\xa...
# 81  b'Mano, vou cancelar minha conta no Next, sinc...
# 82  b'Aos demais bancos, hora de aprender com o @f...
# 83  b'@falanext to a 24h sem poder logar no aplica...
# 84  b'Ganhei 2 ingressos da Cinemark \xe2\x9d\xa4\...
# 85  b'@caraifeo @falanext n\xc3\xa3o acredito \xf0...
# 86  b'30 minutos no telefone para pedir um limite ...
# 87  b'J\xc3\xa1 tentei fazer login o dia todo e s\...
# 88  b'Liguei no SAC duas vezes e s\xc3\xb3 toca a ...
# 89  b'O que eu fa\xc3\xa7o pro banco @falanext sol...
# 90  b'@falanext como fa\xc3\xa7o para atualizar me...
# 91  b'eu estou a duas semanas entrar em contato co...
# 92  b'o @falanext respondeu o Ivo mas n\xc3\xa3o m...
# 93  b'@falanext Preciso de ajuda no quesito limite...
# 94  b'@falanext Eu j\xc3\xa1 tentei o ajuda do app...
# 95  b'@falanext tem que liberar antecipa\xc3\xa7\x...
# 96      b'@falanext preciso da ajuda de voc\xc3\xaas'
# 97  b'@getawaycarol @falanext N\xc3\xa3o recebi me...
# 98  b'mal entrei no banco e ja to passando nervoso...
# 99  b'al\xc3\xb4 @falanext muito obrigada pelo mim...
#
# [100 rows x 3 columns]

# %% [markdown]
# *Data Cleaning*

# %%
def cleanTweets(tweetsDF):
    table = str.maketrans(dict.fromkeys(string.punctuation.replace('@','')))
    # essa regex significa:
    # tudo que conter @ OU http OU terminador de linha seguido de uma palavra OU um espaco OU qualquer outro terminador
    # de linha.
    rePattern1 = '(@|http|\\n)(\w+|\s|\S)'
    formattedTweets = []
    for line in tweetsDF['text']:
        formattedStr = line.decode('utf-8').lower()
        formattedStr = formattedStr.translate(table)
        formattedStr = re.sub(rePattern1, "", formattedStr)  
        formattedTweets.append(formattedStr)
    return formattedTweets

formattedTweets = cleanTweets(df)
data = pd.DataFrame(formattedTweets, columns=['text'])
data
# Out:
#                                                  text
# 0            vocês bem que podiam entregar meu cartão
# 1    mas já faz uns dias né até agora ainda não co...
# 2    vocês tem support pro   to fazendo minha migr...
# 3   como eu sei que a função cartão de crédito tá ...
# 4    1ted por mês vcs me quebram né parceiro se nã...
# 5                           oi meu anjo me ajuda aqui
# 6       falam p deus e o mundo que são bons só que...
# 7   ei   precisamos bater um papo porém não tô con...
# 8    ainda não liguei hoje também e não me atender...
# 9                                      só fica assim
# 10                                       next é um cu
# 11                                         oi lucas…
# 12                                           kkkkkkkk
# 13
# 14                             ainda to no aguardo 😴
# 15                                       misericórdia
# 16   pelo amor de deus ajuda a galera do next pq n...
# 17
# 18  22 min no telefone esperando atendimento do  e...
# 19                            pq vc ta me ignorando 😭
# 20   fiquei mais de 20 minutos esperando me atende...
# 21   belê liberem logo porque é muito pratico usar...
# 22   eu respondi assim que me enviaram tô apostand...
# 23   mano que raiva éimpossível entrar em contato ...
# 24                                 pq vcs não atendem
# 25                     migo bem inútil na vdd kkkkkkk
# 26   galera eu ainda estou esperando o retorno de ...
# 27   a 2 meses atrás eu precisava do cartão para u...
# 28        vou pensar assim pq o nubank não me aceitou
# 29                                             inveja
# ..                                                ...
# 70  abro o  e ele me da 2 ingressos grátis vou lev...
# 71
# 72             vcs esqueceram meu cartão em churrasco
# 73                         abri um chamado pode ir dm
# 74  rt   nos desculpe o inconveniente posso te aju...
# 75  eae   obrigado pelo email de proposta de abert...
# 76      serviços como inter e nubank não devem ser...
# 77   consegui hj após 5 hrs de espera porém não se...
# 78                                      olha minha dm
# 79   o comprovante de endereço mão tá no meu nome ...
# 80     mas você acha realmente pior que  e o   ess...
# 81  mano vou cancelar minha conta no next sinceram...
# 82  aos demais bancos hora de aprender com o  como...
# 83   to a 24h sem poder logar no aplicativo com es...
# 84  ganhei 2 ingressos da cinemark ❤️❤️obrigado pe...
# 85                                   não acredito 😡😡😡
# 86  30 minutos no telefone para pedir um limite ma...
# 87  já tentei fazer login o dia todo e só aparece ...
# 88  liguei no sac duas vezes e só toca a musica e ...
# 89  o que eu faço pro banco  solucionar meus probl...
# 90   como faço para atualizar meu email cadastrado...
# 91  eu estou a duas semanas entrar em contato com ...
# 92  o  respondeu o ivo mas não me respondeu lastim...
# 93      preciso de ajuda no quesito limite de crédito
# 94   eu já tentei o ajuda do app me responderam de...
# 95   tem que liberar antecipação de pagamento sem ...
# 96                          preciso da ajuda de vocês
# 97    não recebi meu cartão até hoje kk e eu quero...
# 98  mal entrei no banco e ja to passando nervoso a...
# 99  alô  muito obrigada pelo mimo do cinema viu po...
#
# [100 rows x 1 columns]

# %% [markdown]
# *Stopwords in portuguese*

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')
# Inclusão de novas stopwords 
stopwords.append('tô')
stopwords.append('pra')
stopwords.append('pro')
stopwords.append('é')
stopwords.append('aí')
stopwords.append('ser')

# %% [markdown]
# *WordCloud*

# %%
text = " ".join(tweet for tweet in data['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user.png")
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# *Basic statistics about the data*

# %%
def word_count(str):
    counts = OrderedDict()
    words = str.split()
    for word in words:
        if word not in stopwords:
            if word in counts:
                counts[word] += 1
            else:
                counts[word] = 1
    return counts

print("There are {} words in the combination of all tweets.".format(len(text)))

counts = sorted(word_count(text).items(), key = itemgetter(1), reverse = True)
display(counts[:10])
# Out:
# There are 6488 words in the combination of all tweets.
# [('cartão', 12),
#  ('next', 11),
#  ('app', 8),
#  ('conta', 8),
#  ('ajuda', 7),
#  ('banco', 7),
#  ('ainda', 6),
#  ('pq', 5),
#  ('esperando', 5),
#  ('minutos', 5)]

# %% [markdown]
# *Transform occurrences in a dataframe*

# %%
wordcount = pd.DataFrame(counts, columns=['word', 'counts'])
top10 = wordcount[:10]
top10
# Out:
#         word  counts
# 0     cartão      12
# 1       next      11
# 2        app       8
# 3      conta       8
# 4      ajuda       7
# 5      banco       7
# 6      ainda       6
# 7         pq       5
# 8  esperando       5
# 9    minutos       5

# %% [markdown]
# *Top 10 most used words*

# %%
# Dataset
height = top10.counts
bars = top10.word
y_pos = np.arange(len(bars))
 
# Create horizontal bars
plt.barh(y_pos, height)

# Create names on the y-axis
plt.yticks(y_pos, bars)

# Create title
plt.title('Top 10 most used words')
 
# Show graphic
plt.show()

# %% [markdown]
# *ReLi Lexicon - portuguese sentimental analysis*

# %%
base_path = '/Users/gayr/documents/gabriela/mba/tcc/ReLi-Lex'
allData = []
files = [os.path.join(base_path, f) for f in os.listdir(base_path)]
for file in files:
    t = 'pos' if '_Positivos' in file else 'neg'
    with open(file, 'r', encoding = 'latin-1') as content_file:
        content = content_file.read()
        all = re.findall('\[.*?\]',content)
        for w in all:
            allData.append((w[1:-1], t))
allDataDF = pd.DataFrame(allData, columns=['word', 'sentiment'])
allDataDF
# Out:
#                 word sentiment
# 0        aborrecente       neg
# 1         anacrônico       neg
# 2          arrombado       neg
# 3              besta       neg
# 4            bizarro       neg
# 5               bobo       neg
# 6              burro       neg
# 7          cansativo       neg
# 8              chato       neg
# 9           chocante       neg
# 10             chulo       neg
# 11            clichê       neg
# 12           confuso       neg
# 13     decepcionante       neg
# 14        defeituoso       neg
# 15        deplorável       neg
# 16        depressivo       neg
# 17        deprimente       neg
# 18      desagradável       neg
# 19         desconexo       neg
# 20       desgastante       neg
# 21   desinteressante       neg
# 22     desnecessário       neg
# 23       desprezível       neg
# 24           difícil       neg
# 25       dispensável       neg
# 26           doentio       neg
# 27           egoísta       neg
# 28         enfadonho       neg
# 29           enjoado       neg
# ..               ...       ...
# 580      destacar-se       pos
# 581         divertir       pos
# 582        emocionar       pos
# 583         emplacar       pos
# 584         empolgar       pos
# 585         encantar       pos
# 586       enternecer       pos
# 587         entreter       pos
# 588        facilitar       pos
# 589         fascinar       pos
# 590            fluir       pos
# 591           gostar       pos
# 592      identificar       pos
# 593     impressionar       pos
# 594           inovar       pos
# 595       recomendar       pos
# 596     sensibilizar       pos
# 597       simpatizar       pos
# 598        valorizar       pos
# 599           vibrar       pos
# 600           viciar       pos
# 601         apavorar       pos
# 602          brilhar       pos
# 603          comover       pos
# 604          devorar       pos
# 605          prender       pos
# 606              rir       pos
# 607         saborear       pos
# 608      surpreender       pos
# 609            tocar       pos
#
# [610 rows x 2 columns]

# %% [markdown]
# *Validate the model and avoid overfit*

# %% [markdown]
# Functions

# %%
# Split arrays or matrices into random train and test subsets
from sklearn.model_selection import train_test_split
# A random forest classifier
from sklearn.ensemble import RandomForestClassifier
# Encode labels with value between 0 and n_classes-1
from sklearn.preprocessing import LabelEncoder
# Accuracy classification score
from sklearn.metrics import accuracy_score
# This classifier is useful as a simple baseline to compare with other (real) classifiers
from sklearn.dummy import DummyClassifier

# %% [markdown]
# Original Variables

# %%
X_original = allDataDF.word
Y_original = allDataDF.sentiment

# %% [markdown]
# O Naive Bayes do sklearn precisa que as variáveis independentes sejam contínuas - por esse motivo precisaremos transformar palavras em números

# %%
le_x = LabelEncoder()
X_labelEncoded = le_x.fit_transform(X_original)
le_y = LabelEncoder()
Y_labelEncoded = le_y.fit_transform(Y_original)

# %% [markdown]
# O que faz o zip? Entender melhor...

# %%
zippedEncoded = list(zip(X_labelEncoded, Y_labelEncoded))
dfEncoded = pd.DataFrame(zippedEncoded, columns = ['word', 'sentiment'])

# %% [markdown]
# Cross Validation - Divisão da amostra entre treino e teste - scikitlearn

# %%
X_labelEncodedDF = dfEncoded.word
Y_labelEncodedDF = dfEncoded.sentiment
X_train, X_test, y_train, y_test = train_test_split(X_labelEncodedDF, Y_labelEncodedDF, test_size=0.30, random_state = 13)

# %% [markdown]
# Random Forest Classifier

# %%
rf = RandomForestClassifier(n_estimators = 100)
rf.fit(X_train.values.reshape(-1, 1), y_train)
y_pred = rf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Naive Bayes Classifier

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(X_train.values.reshape(-1, 1), y_train)
y_nb_pred = rf.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Dummy Model

# %%
dm = DummyClassifier()
dm.fit(X_train.values.reshape(-1, 1), y_train)
y_dummy_pred = dm.predict(X_test.values.reshape(-1, 1))

# %% [markdown]
# Acurácia dos modelos

# %%
print('Accuracy random forest on test dataset: {}'.format(round(accuracy_score(y_test, y_pred), 2)))
print('Accuracy naive bayes on test dataset: {}'.format(round(accuracy_score(y_test, y_nb_pred), 2)))
print('Accuracy dummy model on test dataset: {}'.format(round(accuracy_score(y_test, y_dummy_pred), 2)))
# Out:
# Accuracy random forest on test dataset: 0.7
# Accuracy naive bayes on test dataset: 0.7
# Accuracy dummy model on test dataset: 0.48

# %% [markdown]
# O nível de acurácia do Random Forest foi igual a Naive Bayes e melhor que o Dummy, por esse motivo iremos utilizar o Random Forest para a análise de sentimentos

# %%
# tweetsDataLabelEncoder = LabelEncoder()
tweet_text = data.text
tweetsEncoded = le_x.fit_transform(tweet_text)
y_pred_total = rf.predict(tweetsEncoded.reshape(-1, 1))
y_pred_total_decoded = le_y.inverse_transform(y_pred_total)
data['sentiment'] = y_pred_total_decoded
data
# Out:
# C:\Users\GAYR\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#                                                  text sentiment
# 0            vocês bem que podiam entregar meu cartão       neg
# 1    mas já faz uns dias né até agora ainda não co...       pos
# 2    vocês tem support pro   to fazendo minha migr...       neg
# 3   como eu sei que a função cartão de crédito tá ...       pos
# 4    1ted por mês vcs me quebram né parceiro se nã...       pos
# 5                           oi meu anjo me ajuda aqui       pos
# 6       falam p deus e o mundo que são bons só que...       pos
# 7   ei   precisamos bater um papo porém não tô con...       neg
# 8    ainda não liguei hoje também e não me atender...       pos
# 9                                      só fica assim        neg
# 10                                       next é um cu       pos
# 11                                         oi lucas…        pos
# 12                                           kkkkkkkk       pos
# 13                                                          pos
# 14                             ainda to no aguardo 😴        pos
# 15                                       misericórdia       neg
# 16   pelo amor de deus ajuda a galera do next pq n...       pos
# 17                                                          pos
# 18  22 min no telefone esperando atendimento do  e...       pos
# 19                            pq vc ta me ignorando 😭       pos
# 20   fiquei mais de 20 minutos esperando me atende...       pos
# 21   belê liberem logo porque é muito pratico usar...       pos
# 22   eu respondi assim que me enviaram tô apostand...       pos
# 23   mano que raiva éimpossível entrar em contato ...       pos
# 24                                 pq vcs não atendem       pos
# 25                     migo bem inútil na vdd kkkkkkk       pos
# 26   galera eu ainda estou esperando o retorno de ...       pos
# 27   a 2 meses atrás eu precisava do cartão para u...       pos
# 28        vou pensar assim pq o nubank não me aceitou       pos
# 29                                             inveja       pos
# ..                                                ...       ...
# 70  abro o  e ele me da 2 ingressos grátis vou lev...       neg
# 71                                                          pos
# 72             vcs esqueceram meu cartão em churrasco       neg
# 73                         abri um chamado pode ir dm       pos
# 74  rt   nos desculpe o inconveniente posso te aju...       neg
# 75  eae   obrigado pelo email de proposta de abert...       neg
# 76      serviços como inter e nubank não devem ser...       pos
# 77   consegui hj após 5 hrs de espera porém não se...       pos
# 78                                      olha minha dm       pos
# 79   o comprovante de endereço mão tá no meu nome ...       pos
# 80     mas você acha realmente pior que  e o   ess...       pos
# 81  mano vou cancelar minha conta no next sinceram...       pos
# 82  aos demais bancos hora de aprender com o  como...       pos
# 83   to a 24h sem poder logar no aplicativo com es...       neg
# 84  ganhei 2 ingressos da cinemark ❤️❤️obrigado pe...       pos
# 85                                   não acredito 😡😡😡       pos
# 86  30 minutos no telefone para pedir um limite ma...       neg
# 87  já tentei fazer login o dia todo e só aparece ...       pos
# 88  liguei no sac duas vezes e só toca a musica e ...       pos
# 89  o que eu faço pro banco  solucionar meus probl...       neg
# 90   como faço para atualizar meu email cadastrado...       pos
# 91  eu estou a duas semanas entrar em contato com ...       pos
# 92  o  respondeu o ivo mas não me respondeu lastim...       pos
# 93      preciso de ajuda no quesito limite de crédito       pos
# 94   eu já tentei o ajuda do app me responderam de...       pos
# 95   tem que liberar antecipação de pagamento sem ...       neg
# 96                          preciso da ajuda de vocês       pos
# 97    não recebi meu cartão até hoje kk e eu quero...       pos
# 98  mal entrei no banco e ja to passando nervoso a...       pos
# 99  alô  muito obrigada pelo mimo do cinema viu po...       pos
#
# [100 rows x 2 columns]

# %% [markdown]
# *Counting positives and negatives*

# %%
df = data.groupby('sentiment').count()
df
# Out:
#            text
# sentiment
# neg          26
# pos          74

# %% [markdown]
# *Sentimental Analysis Graph based on Naive-Bayes Classification*

# %%
pie_pos = df.loc['pos']
pie_neg = df.loc['neg']

slices = [pie_neg, pie_pos]
tweets = ['Negative', 'Positive']
columns = ['Red', 'Green']
 
plt.pie(slices, labels = tweets, colors = columns, startangle = 90, shadow = True, explode = (0.1, 0), autopct='%1.0f%%')

plt.show()

# %% [markdown]
# *Positive WordCloud*

# %%
#filtrar dataframe com tweets positivos
data_pos_filtered = data[data['sentiment'] == 'pos']
data_pos_filtered = " ".join(tweet for tweet in data['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user.png")
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# *Negative WordCloud*

# %%
#filtrar dataframe com tweets positivos
data_neg_filtered = data[data['sentiment'] == 'neg']
data_neg_filtered = " ".join(tweet for tweet in data['text'])
wordcloud = WordCloud(max_font_size = 50, stopwords = stopwords, background_color = 'white').generate(text)
wordcloud.to_file("nouns_user.png")
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
